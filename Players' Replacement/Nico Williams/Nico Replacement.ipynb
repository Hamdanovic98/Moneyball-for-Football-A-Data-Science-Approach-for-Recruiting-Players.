# %%
import pandas as pd
import numpy as np
from PIL import Image
from mplsoccer import PyPizza, add_image, FontManager
import urllib.request

# %%
# Display the current settings
print("Current maximum number of rows: ", pd.get_option('display.max_rows'))
print("Current maximum number of columns: ", pd.get_option('display.max_columns'))

# Set new maximum number of rows and columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# Display the updated settings
print("Updated maximum number of rows: ", pd.get_option('display.max_rows'))
print("Updated maximum number of columns: ", pd.get_option('display.max_columns'))
# Out:
# Current maximum number of rows:  60
# Current maximum number of columns:  20
# Updated maximum number of rows:  500
# Updated maximum number of columns:  500

# %%
final_player = pd.read_csv('../final_players_2024.csv')
player_2024=pd.read_csv('../Full_Players_2024.csv')
player_2023=pd.read_csv('../Full_Players_2023.csv')
player_2022=pd.read_csv('../Full_Players_2022.csv')
player_2021=pd.read_csv('../Full_Players_2021.csv')
newbie=pd.read_csv('../newbie_players_2024.csv')
# Fill missing values with 0 in place
final_player.fillna(0, inplace=True)
newbie.fillna(0,inplace=True)
player_2024.fillna(0,inplace=True)
player_2023.fillna(0, inplace=True)
player_2022.fillna(0, inplace=True)
player_2021.fillna(0, inplace=True)
final_player
# Out:
#       Unnamed: 0               Player   Nation    Pos  \
# 0              0    Maximilian Arnold   de GER     MF
# 1              1      Nathaniel Clyne  eng ENG     DF
# 2              2      Trevoh Chalobah  eng ENG     DF
# 3              3       Atakan Karazor   de GER     MF
# 4              4           Saša Lukić   rs SRB     MF
# ...          ...                  ...      ...    ...
# 1491        2490  Filippo Terracciano   it ITA  DF,FW
# 1492        2495       Jonathan Viera   es ESP     MF
# 1493        2496       Alan Virginius   fr FRA     FW
# 1494        2505       Bryan Zaragoza   es ESP  FW,MF
# 1495        2507         Nadir Zortea   it ITA     DF
#
#                             Squad  \
# 0                       Wolfsburg
# 1                  Crystal Palace
# 2                 Chelsea+Lorient
# 3                       Stuttgart
# 4     Fulham+Fulham+Torino+Torino
# ...                           ...
# 1491          Hellas Verona+Milan
# 1492           Las Palmas+Almería
# 1493          Lille+Clermont Foot
# 1494        Granada+Bayern Munich
# 1495           Frosinone+Atalanta
#
#                                                    Comp  Age    Born     MP  \
# 0                                         de Bundesliga  0.0  1994.0  126.0
# 1                                    eng Premier League  0.0  1991.0   70.0
# 2                         eng Premier League+fr Ligue 1  0.0  1999.0   87.0
# 3                                         de Bundesliga  0.0  1996.0  105.0
# 4     eng Premier League+eng Premier League+it Serie...  0.0  1996.0  119.0
# ...                                                 ...  ...     ...    ...
# 1491                                         it Serie A  0.0  2003.0   21.0
# 1492                                         es La Liga  0.0  1989.0   21.0
# 1493                                         fr Ligue 1  0.0  2003.0   16.0
# 1494                           es La Liga+de Bundesliga  0.0  2001.0   28.0
# 1495                                         it Serie A  0.0  1999.0   19.0
#
#       Starts    Min    90s  Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  \
# 0      123.0  10852  120.5         0.11       0.22        0.09          0.19
# 1       61.0   5474   60.8         0.00       0.03        0.00          0.03
# 2       69.0   6246   69.5         0.09       0.13        0.09          0.13
# 3       86.0   7520   83.5         0.00       0.07        0.00          0.07
# 4       88.0   7817   86.9         0.13       0.17        0.08          0.13
# ...      ...    ...    ...          ...        ...         ...           ...
# 1491    15.0   1372   15.2         0.00       0.07        0.00          0.07
# 1492    19.0   1529   17.0         0.12       0.35        0.00          0.24
# 1493    13.0   1005   11.2         0.00       0.18        0.00          0.18
# 1494    19.0   1821   20.2         0.30       0.40        0.25          0.35
# 1495    14.0   1407   15.7         0.13       0.45        0.13          0.45
#
#       xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 0         0.08          0.23        0.05            0.20                61.0
# 1         0.01          0.04        0.01            0.04                40.0
# 2         0.05          0.07        0.05            0.07                76.0
# 3         0.02          0.08        0.02            0.07                85.0
# 4         0.11          0.19        0.08            0.16                95.0
# ...        ...           ...         ...             ...                 ...
# 1491      0.02          0.02        0.02            0.02                31.0
# 1492      0.21          0.59        0.12            0.36                41.0
# 1493      0.12          0.15        0.12            0.15                24.0
# 1494      0.21          0.32        0.17            0.27               145.0
# 1495      0.03          0.19        0.03            0.19                52.0
#
#       Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 0              44.0           72.13              12.0              19.67
# 1              21.0           52.50              15.0              37.50
# 2              57.0           75.00              18.0              23.68
# 3              39.0           45.88              34.0              40.00
# 4              61.0           64.21              32.0              33.68
# ...             ...             ...               ...                ...
# 1491           13.0           42.00              10.0              32.00
# 1492           19.0           46.00              17.0              41.00
# 1493           12.0           50.00              12.0              50.00
# 1494           61.0           42.00              73.0              50.00
# 1495           22.0           42.00              25.0              48.00
#
#       Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 0              65.36                    3.26                   14.75
# 1              52.93                    2.60                   18.47
# 2              74.58                    5.78                   29.41
# 3              67.92                    4.19                   18.86
# 4              55.08                    1.76                    9.66
# ...              ...                     ...                     ...
# 1491           59.74                    2.50                   18.68
# 1492           70.24                    0.24                    7.00
# 1493           28.66                    0.62                    3.57
# 1494           39.46                    0.05                    3.71
# 1495           53.69                    2.04                   11.46
#
#       Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                      38.68                   12.59                    0.27
# 1                      24.89                    9.85                    0.28
# 2                      38.42                    7.32                    0.82
# 3                      41.14                    8.41                    0.44
# 4                      32.96                   13.18                    1.44
# ...                      ...                     ...                     ...
# 1491                   29.80                   11.84                    0.53
# 1492                   40.47                   23.59                    2.41
# 1493                   12.23                   13.12                    3.75
# 1494                   14.26                   22.33                    4.41
# 1495                   22.10                   20.57                    1.66
#
#       Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                         65.32                       0.51
# 1                         52.93                       0.66
# 2                         74.58                       1.10
# 3                         67.92                       1.02
# 4                         55.03                       1.09
# ...                         ...                        ...
# 1491                      59.74                       2.04
# 1492                      70.12                       2.41
# 1493                      28.66                       2.14
# 1494                      39.41                       7.18
# 1495                      53.69                       3.31
#
#       Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                     0.36                     0.10           33.24
# 1                     0.34                     0.24           24.21
# 2                     0.82                     0.26           41.61
# 3                     0.47                     0.41           33.56
# 4                     0.70                     0.37           31.82
# ...                    ...                      ...             ...
# 1491                  0.86                     0.66           32.70
# 1492                  1.12                     1.00           46.53
# 1493                  1.07                     1.07           20.36
# 1494                  3.02                     3.61           27.72
# 1495                  1.40                     1.59           26.11
#
#       Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                    149.70                                70.52
# 1                    108.88                                52.86
# 2                    160.91                                82.55
# 3                    126.19                                56.40
# 4                    178.62                                90.16
# ...                     ...                                  ...
# 1491                 192.96                                92.76
# 1492                 225.47                               125.76
# 1493                 148.93                                76.79
# 1494                 247.23                               141.68
# 1495                 148.09                                70.64
#
#       Progressive_Carries_per_90  1/3_Carries_per_90  \
#
#
#       Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                             2.76               1.97                 0.02
# 1                             2.48               2.04                 0.02
# 2                             3.62               2.96                 0.04
# 3                             3.62               2.21                 0.02
# 4                             2.53               1.04                 0.01
# ...                            ...                ...                  ...
# 1491                          3.42               1.18                 0.00
# 1492                          1.71               0.12                 0.00
# 1493                          1.16               0.62                 0.00
# 1494                          1.34               0.15                 0.00
# 1495                          1.97               2.04                 0.06
#
#       Dribblers_Tackle_W%  Seasons at top 5  Seasons in PL  Seasons in Liga  \
# 0                   44.35                 4              0                0
# 1                   58.67                 4              4                0
# 2                   62.97                 4              3                0
# 3                   50.95                 4              0                0
# 4                   42.89                 4              2                0
# ...                   ...               ...            ...              ...
# 1491                53.00                 1              0                0
# 1492                39.00                 1              0                1
# 1493                33.00                 1              0                0
# 1494                42.00                 1              0                1
# 1495                42.00                 1              0                0
#
#       Seasons in Serie A  Seasons in Ligue 1  Seasons in Bundesliga
# 0                      0                   0                      4
# 1                      0                   0                      0
# 2                      0                   1                      0
# 3                      0                   0                      4
# 4                      3                   0                      0
# ...                  ...                 ...                    ...
# 1491                   1                   0                      0
# 1492                   0                   0                      0
# 1493                   0                   1                      0
# 1494                   0                   0                      1
# 1495                   1                   0                      0
#
# [1496 rows x 137 columns]

# %%
Nico=player_2024[player_2024['Player']=='Nico Williams']
Nico
# Out:
#       Unnamed: 0         Player  Nation Pos          Squad        Comp  Age  \
# 1363        2768  Nico Williams  es ESP  FW  Athletic Club  es La Liga  0.0
#
#         Born  MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 1363  2002.0  31      29  2263  25.1          0.2       0.64         0.2
#
#       G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 1363          0.64      0.24          0.46        0.24            0.46
#
#       Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 1363               193.0           86.0            44.6              92.0
#
#       Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 1363               47.7           47.93                    0.56
#
#       Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 1363                    4.46                   14.82                   29.72
#
#       Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 1363                     5.9                      47.93
#
#       Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  \
# 1363                       7.69                  3.43
#
#       Tackled_Take_Ons_per_90  Carries_per_90  Total_Distance_per_90  \
# 1363                     3.67           31.87                 257.65
#
#       Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 1363                               148.84                         5.7
#
#       1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 1363                3.07                         2.47                3.03
#
#       Dispossessed_per_90  Passes_Received_per_90  \
# 1363                 2.03                   33.82
#
#       Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 1363                               12.03                        4.81
#
#       Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 1363                     0.95                   2.87                   0.72
#
#       Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 1363                  0.76              0.24                     0.24
#
#       Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 1363                    0.0                    0.6                   0.08
#
#       Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 1363                  0.16              0.04                     0.08
#
#       Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 1363                    0.0             579.0             828.0
#
#       Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 1363               69.9          9035.0          2545.0             321.0
#
#       Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 1363             374.0               85.8              196.0
#
#       Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 1363              265.0                74.0             43.0            101.0
#
#       Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 1363              42.6            0.44        0.23        0.3          0.21
#
#       Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 1363               1.87               1.04                        1.91
#
#       Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 1363                         0.88                       2.63
#
#       Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 1363                    32.99                    29.44
#
#       Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 1363                     3.39                     0.64                  0.32
#
#       Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 1363             0.12             6.1                    0.44
#
#       Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 1363                 2.27                    1.43                     0.32
#
#       Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 1363                      0.0              23.07               0.16
#
#       Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 1363                   1.87               2.23                   0.76
#
#       Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 1363            0.09                      0.26           0.11    -1.0
#
#       Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 1363      -1.0                       47.1                 0.24
#
#       Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 1363              0.04                       0.04                    0.76
#
#       Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 1363                1.47             0.48                  0.12
#
#       Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 1363                0.48                      0.12
#
#       Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 1363                           0.04                    5.22
#
#       Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 1363                0.32                 0.36            1.24
#
#       Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 1363                    0.36                     0.6                    0.28
#
#       Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 1363                      0.52                         1.43
#
#       Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 1363                          0.92           0.72                  0.08
#
#       Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 1363                          1.35               0.16                 0.04
#
#       Dribblers_Tackle_W%
# 1363                 36.1

# %%
import pandas as pd





params=['Goals_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90', 'xG_per90', 'xG+xAG_per90', 'npxG_per90',
        'npxG+xAG_per90', 'Take_Ons_Attempted', 'Take_Ons_Succ', 'Take_Ons_Succ%', 'Tackled_Take_Ons', 
        'Tackled_Take_Ons%', 'Touches_per_90', 'Touches_Def_Pen_per_90', 'Touches_Def_3rd_per_90', 
        'Touches_Mid_3rd_per_90', 'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
        'Take_Ons_Attempted_per_90', 'Take_Ons_Succ_per_90', 'Tackled_Take_Ons_per_90', 'Carries_per_90', 
        'Total_Distance_per_90', 'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90', 
        '1/3_Carries_per_90', 'Carries_Penalty_Area_per_90', 'Miscontrols_per_90', 'Dispossessed_per_90', 
        'Passes_Received_per_90', 'Progressive_Passes_Received_per_90', 'Shot_Creating_Action_per90', 
        'Goal_Creating_Action_90', 'Pass_Live_Shot_per_90', 'Pass_Dead_Shot_per_90', 'Take_Ons_Shot_per_90', 
        'Shot-Shot_per_90', 'Fouls_drawn_Shot_per_90', 'Defensive_Shot_per_90', 'Pass_Live_Goal_per_90',
        'Pass_Dead_Goal_per_90', 'Take_Ons_Goal_per_90', 'Shot_Goal_per_90', 'Fouls_Drawn_Goal_per_90', 
        'Defensive_Goal_per_90', 'Passes_Total_Cmp', 'Passes_Total_Att', 'Passes_Total_Cmp%', 'Passes_TotDist', 
        'Passes_PrgDist', 'Passes_Short_Cmp', 'Passes_Short_Att', 'Passes_Short_Cmp%', 'Passes_Medium_Cmp', 
        'Passes_Medium_Att', 'Passes_Medium_Cmp%', 'Passes_Long_Cmp', 'Passes_Long_Att', 'Passes_Long_Cmp%', 
        'Assists_per_90', 'xAG_per_90', 'xA_per_90', 'A-xAG_per_90', 'Key_Passes_per_90', 'Passes_1/3_per_90', 
        'Passes_Penalty_Area_per_90', 'Crosses_Penalty_Area_per_90', 'Progressive_Passes_per_90', 
        'Passes_Attempted_per_90', 'Live_Ball_Passes_per_90', 'Dead_Ball_Passes_per_90', 'Free_Kick_Passes_per_90',
        'Through_Balls_per_90', 'Switches_per_90', 'Crosses_per_90', 'Throw_Ins_Taken_per_90', 
        'Corner_Kicks_per_90', 'In_Corner_Kicks_per_90', 'Out_Corner_Kicks_per_90', 'Str_Corner_Kicks_per_90',
        'Passes_Cmp_per_90', 'Passes_Off_per_90', 'Passes_Blocked_per_90', 'Shots_total_per90', 
        'Shots_on_target_per90', 'Goals_per_shot', 'Goals_per_shot_on_target', 'Npxg_per_shot', 'Xg_net', 
        'Npxg_net', 'Percentage_of_Aerials_Won', 'Yellow_Cards_per_90', 'Red_Cards_per_90', 
        'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90', 'Fouls_Drawn_per_90', 'Offsides_per_90', 
        'Interceptions_per_90', 'Tackles_Won_per_90', 'Penalty_Kicks_Won_per_90', 'Penalty_Kicks_Conceded_per_90',
        'Ball_Recoveries_per_90', 'Aerials_Won_per_90', 'Aerials_Lost_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_2024_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of Harry Kane's stats from the percentile ranks DataFrame
nico_2024_percentile_ranks = round(players_2024_percentile_ranks.iloc[[1363]],0)

# Print the percentile ranks for Declan Rice
print(nico_2024_percentile_ranks)
# Out:
#       Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  \
# 1363         76.0       93.0        78.0          94.0      81.0
#
#       xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 1363          86.0        83.0            88.0               100.0
#
#       Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 1363           99.0            42.0             100.0               63.0
#
#       Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 1363            28.0                     9.0                    16.0
#
#       Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 1363                    11.0                    96.0                    95.0
#
#       Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 1363                       28.0                      100.0
#
#       Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 1363                  99.0                    100.0            53.0
#
#       Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 1363                   84.0                                 92.0
#
#       Progressive_Carries_per_90  1/3_Carries_per_90  \
# 1363                        99.0                96.0
#
#       Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 1363                         98.0                93.0                 94.0
#
#       Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 1363                    45.0                                99.0
#
#       Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 1363                        96.0                    100.0
#
#       Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 1363                   92.0                   91.0                  98.0
#
#       Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 1363              78.0                     85.0                   24.0
#
#       Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 1363                   99.0                   93.0                  98.0
#
#       Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 1363              76.0                     94.0                   46.0
#
#       Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 1363              40.0              47.0               13.0            37.0
#
#       Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 1363            34.0              49.0              50.0               36.0
#
#       Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 1363               35.0               37.0                18.0
#
#       Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 1363             40.0             52.0              12.0            99.0
#
#       xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 1363        92.0       98.0         100.0               90.0
#
#       Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 1363               11.0                        94.0
#
#       Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 1363                         98.0                       26.0
#
#       Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 1363                     22.0                     21.0
#
#       Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 1363                     61.0                     41.0                  89.0
#
#       Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 1363             32.0            96.0                    54.0
#
#       Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 1363                 92.0                    96.0                     84.0
#
#       Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 1363                     47.0               20.0               54.0
#
#       Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 1363                   96.0               82.0                   81.0
#
#       Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 1363            57.0                      53.0           70.0    19.0
#
#       Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 1363      19.0                       47.0                 63.0
#
#       Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 1363              88.0                       95.0                    20.0
#
#       Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 1363                72.0             88.0                   4.0
#
#       Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 1363                13.0                      99.0
#
#       Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 1363                           83.0                    65.0
#
#       Aerials_Won_per_90  Aerials_Lost_per_90
# 1363                 9.0                  3.0

# %%
# Extract the percentile ranks, transpose, and sort them in descending order
nico_2024_percentile_ranks_sorted = nico_2024_percentile_ranks.T.sort_values(by=1363, ascending=False)

# Get the top 20 parameters
top_30_params = nico_2024_percentile_ranks.index[:30]
top_30_params_values = nico_2024_percentile_ranks_sorted[1363].head(30)

# Display the top 20 parameters and their values
print("Top 30 Parameters:")
print(top_30_params)
print("Values:")
print(top_30_params_values)
# Out:
# Top 30 Parameters:
# Index([1363], dtype='int64')
# Values:
# Goal_Creating_Action_90               100.0
# Tackled_Take_Ons                      100.0
# A-xAG_per_90                          100.0
# Tackled_Take_Ons_per_90               100.0
# Take_Ons_Attempted_per_90             100.0
# Take_Ons_Attempted                    100.0
# Progressive_Carries_per_90             99.0
# Progressive_Passes_Received_per_90     99.0
# Take_Ons_Succ_per_90                   99.0
# Pass_Live_Goal_per_90                  99.0
# Penalty_Kicks_Won_per_90               99.0
# Assists_per_90                         99.0
# Take_Ons_Succ                          99.0
# Carries_Penalty_Area_per_90            98.0
# Take_Ons_Shot_per_90                   98.0
# Crosses_Penalty_Area_per_90            98.0
# xA_per_90                              98.0
# Take_Ons_Goal_per_90                   98.0
# 1/3_Carries_per_90                     96.0
# Touches_Att_3rd_per_90                 96.0
# Passes_Blocked_per_90                  96.0
# In_Corner_Kicks_per_90                 96.0
# Crosses_per_90                         96.0
# Shot_Creating_Action_per90             96.0
# Second_Yellow_Card_per_90              95.0
# Touches_Att_Pen_per_90                 95.0
# Dispossessed_per_90                    94.0
# Fouls_Drawn_Goal_per_90                94.0
# Passes_Penalty_Area_per_90             94.0
# G+A-PK_per90                           94.0
# Name: 1363, dtype: float64

# %%
import pandas as pd





params = [
    'Goal_Creating_Action_90', 
    'Tackled_Take_Ons', 
    'Take_Ons_Attempted_per_90', 
    'Progressive_Carries_per_90', 
    'Assists_per_90', 
    'Take_Ons_Succ_per_90', 
    'Crosses_Penalty_Area_per_90', 
    'Shot_Creating_Action_per90', 
    'Passes_Penalty_Area_per_90', 
    'Touches_Att_Pen_per_90', 
    'xA_per_90', 
    'Take_Ons_Goal_per_90', 
    'Carries_Penalty_Area_per_90', 
    'Progressive_Passes_Received_per_90', 
    'Take_Ons_Shot_per_90'
]


# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of Nico's stats from the percentile ranks DataFrame
nico_percentile_ranks = round(players_percentile_ranks.iloc[[1363]],0)

# Print the percentile ranks for Harry Kane
print(nico_percentile_ranks)
# Out:
#       Goal_Creating_Action_90  Tackled_Take_Ons  Take_Ons_Attempted_per_90  \
# 1363                    100.0             100.0                      100.0
#
#       Progressive_Carries_per_90  Assists_per_90  Take_Ons_Succ_per_90  \
# 1363                        99.0            99.0                  99.0
#
#       Crosses_Penalty_Area_per_90  Shot_Creating_Action_per90  \
# 1363                         98.0                        96.0
#
#       Passes_Penalty_Area_per_90  Touches_Att_Pen_per_90  xA_per_90  \
# 1363                        94.0                    95.0       98.0
#
#       Take_Ons_Goal_per_90  Carries_Penalty_Area_per_90  \
# 1363                  98.0                         98.0
#
#       Progressive_Passes_Received_per_90  Take_Ons_Shot_per_90
# 1363                                99.0                  98.0

# %%
nico_percentile_ranks_list = nico_percentile_ranks.values.flatten().tolist()

nico_percentile_ranks_list
# Out:
# [100.0,
#  100.0,
#  100.0,
#  99.0,
#  99.0,
#  99.0,
#  98.0,
#  96.0,
#  94.0,
#  95.0,
#  98.0,
#  98.0,
#  98.0,
#  99.0,
#  98.0]

# %%
image_path = "Nico.jpeg"
fdj_cropped = Image.open(image_path)

# %%
split_params = [param.replace('_', '\n') for param in params]

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    nico_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Nico Williams - Athletic Club", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"La Liga Stats Percentile Rank vs Top-Five Leagues  Forwards | 2023-24 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Nico_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
from sklearn.decomposition import PCA
import numpy as np

# Identify features to minimize
negative_features = ['Yellow_Cards_per_90', 'Red_Cards_per_90', 'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90',
                     'Aerials_Lost_per_90','Miscontrols_per_90','Dispossessed_per_90','Penalty_Kicks_Conceded_per_90']

# Reverse the sign of negative features
for feature in negative_features:
    if feature in player_2024.columns:
        player_2024[feature]=-player_2024[feature]

# %%
# Normalize data
numerical_player_2024 = player_2024[params].replace([np.inf, -np.inf], 0)
normalized_player_2024 = (numerical_player_2024 - numerical_player_2024.mean()) / numerical_player_2024.std()

# Apply PCA
pca = PCA()
pca.fit(normalized_player_2024)
explained_variances = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variances >= 0.95) + 1

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
transformed_players = pca.fit_transform(normalized_player_2024)

# Convert transformed data back to DataFrame
transformed_df = pd.DataFrame(transformed_players, index=player_2024.index)

# %%
# Get nico's row and compute cosine similarity
nico_index = player_2024.index[player_2024['Player'] == 'Nico Williams'][0]
nico_data = transformed_df.loc[nico_index].values.reshape(1, -1)

# Remove nico from the dataset for comparison
transformed_df = transformed_df.drop(index=nico_index)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(transformed_df, nico_data).flatten()
transformed_df['similarity_to_nico_2024'] = similarity_scores

# Get top 10 players most similar to de Ligt
top_similar_players_indices = transformed_df.sort_values('similarity_to_nico_2024', ascending=False).index
top_similar_players = player_2024.loc[top_similar_players_indices]

# %%
# Visualize the results
player_2024['similarity_to_nico_2024'] = transformed_df['similarity_to_nico_2024']
player_2024_sorted = player_2024.sort_values(by='similarity_to_nico_2024', ascending=False)
player_2024_sorted
# Out:
#       Unnamed: 0             Player   Nation    Pos          Squad  \
# 1158        2367              Sávio   br BRA  FW,MF         Girona
# 1049        2162  Christian Pulisic   us USA  FW,MF          Milan
# 1378        2792       Lamine Yamal   es ESP     FW      Barcelona
# 1401        2834      Edon Zhegrova   xk KVX     FW          Lille
# 97           192       Dilane Bakwa   fr FRA  FW,MF     Strasbourg
# ...          ...                ...      ...    ...            ...
# 655         1343  Lukas Klostermann   de GER     DF     RB Leipzig
# 1245        2553    James Tarkowski  eng ENG     DF        Everton
# 617         1270  Mathias Jørgensen   dk DEN     DF      Brentford
# 176          363       Edoardo Bove   it ITA     MF           Roma
# 1363        2768      Nico Williams   es ESP     FW  Athletic Club
#
#                     Comp  Age    Born  MP  Starts   Min   90s  Goals_per90  \
# 1158          es La Liga  0.0  2004.0  37      35  2976  33.1         0.27
# 1049          it Serie A  0.0  1998.0  36      32  2602  28.9         0.42
# 1378          es La Liga  0.0  2007.0  37      22  2201  24.5         0.20
# 1401          fr Ligue 1  0.0  1999.0  33      25  2288  25.4         0.24
# 97            fr Ligue 1  0.0  2002.0  31      25  2177  24.2         0.12
# ...                  ...  ...     ...  ..     ...   ...   ...          ...
# 655        de Bundesliga  0.0  1996.0  25      16  1436  16.0         0.06
# 1245  eng Premier League  0.0  1992.0  38      38  3419  38.0         0.03
# 617   eng Premier League  0.0  1990.0  14      12  1087  12.1         0.08
# 176           it Serie A  0.0  2002.0  31      18  1780  19.8         0.00
# 1363          es La Liga  0.0  2002.0  31      29  2263  25.1         0.20
#
#       G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 1158       0.57        0.27          0.57      0.18          0.42        0.18
# 1049       0.69        0.42          0.69      0.28          0.44        0.28
# 1378       0.41        0.20          0.41      0.21          0.47        0.21
# 1401       0.47        0.24          0.47      0.24          0.49        0.24
# 97         0.37        0.12          0.37      0.13          0.39        0.13
# ...         ...         ...           ...       ...           ...         ...
# 655        0.06        0.06          0.06      0.05          0.07        0.05
# 1245       0.05        0.03          0.05      0.07          0.13        0.07
# 617        0.08        0.08          0.08      0.06          0.14        0.06
# 176        0.10        0.00          0.10      0.10          0.14        0.10
# 1363       0.64        0.20          0.64      0.24          0.46        0.24
#
#       npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%
# 1049                        4.53                2.15
# 1378                        5.02                3.18
# 1401                        4.33                3.07
# 97                          3.88                3.14
# ...                          ...                 ...
# 655                         0.88                0.56
# 1245                        0.39                0.32
# 617                         0.41                0.33
# 176                         1.06                1.21
# 1363                        5.70                3.07
#
#       Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 1158                         2.42               -2.96                -1.48
# 1049                         1.59               -2.42                -1.14
# 1378                         2.33               -2.20                -1.06
# 1401                         2.13               -2.17                -1.97
# 97                           0.99               -2.02                -1.57
# ...                           ...                 ...                  ...
# 655                          0.00               -0.25                -0.00
# 1245                         0.00               -0.42                -0.42
# 617                          0.00               -0.33                -0.08
# 176                          0.10               -1.36                -1.36
# 1363                         2.47               -3.03                -2.03
#
#       Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 1158                   34.32                               11.24
# 1049                   38.48                               10.14
# 1378                   47.22                               14.29
# 1401                   38.82                               12.68
# 97                     31.24                                8.43
# ...                      ...                                 ...
# 655                    58.50                                0.81
# 1245                   28.32                                0.53
# 617                    30.74                                0.33
# 176                    33.43                                2.37
# 1363                   33.82                               12.03
#
#       Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 1158                        3.57                     0.76
# 1049                        3.11                     0.59
# 1378                        4.41                     0.74
# 1401                        4.84                     0.59
# 97                          4.42                     0.41
# ...                          ...                      ...
# 655                         0.88                     0.00
# 1245                        1.16                     0.08
# 617                         0.99                     0.00
# 176                         2.02                     0.10
# 1363                        4.81                     0.95
#
#       Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 1158                   2.57                   0.03                  0.45
# 1049                   2.04                   0.31                  0.28
# 1378                   2.61                   0.20                  0.69
# 1401                   2.48                   0.79                  0.98
# 97                     2.23                   1.12                  0.54
# ...                     ...                    ...                   ...
# 655                    0.81                   0.00                  0.00
# 1245                   1.00                   0.00                  0.03
# 617                    0.91                   0.00                  0.00
# 176                    1.72                   0.00                  0.05
# 1363                   2.87                   0.72                  0.76
#
#       Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 1158              0.21                     0.30                   0.00
# 1049              0.21                     0.21                   0.07
# 1378              0.37                     0.33                   0.20
# 1401              0.39                     0.20                   0.00
# 97                0.21                     0.29                   0.04
# ...                ...                      ...                    ...
# 655               0.06                     0.00                   0.00
# 1245              0.11                     0.00                   0.03
# 617               0.08                     0.00                   0.00
# 176               0.00                     0.25                   0.00
# 1363              0.24                     0.24                   0.00
#
#       Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 1158                   0.57                   0.00                  0.12
# 1049                   0.45                   0.00                  0.07
# 1378                   0.49                   0.00                  0.08
# 1401                   0.35                   0.04                  0.20
# 97                     0.17                   0.17                  0.04
# ...                     ...                    ...                   ...
# 655                    0.00                   0.00                  0.00
# 1245                   0.08                   0.00                  0.00
# 617                    0.00                   0.00                  0.00
# 176                    0.10                   0.00                  0.00
# 1363                   0.60                   0.08                  0.16
#
#       Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 1158              0.00                     0.06                   0.00
# 1049              0.00                     0.03                   0.03
# 1378              0.04                     0.08                   0.04
# 1401              0.00                     0.00                   0.00
# 97                0.04                     0.00                   0.00
# ...                ...                      ...                    ...
# 655               0.00                     0.00                   0.00
# 1245              0.00                     0.00                   0.00
# 617               0.00                     0.00                   0.00
# 176               0.00                     0.00                   0.00
# 1363              0.04                     0.08                   0.00
#
#       Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 1158             812.0            1064.0               76.3         11860.0
# 1049             832.0            1074.0               77.5         11830.0
# 1378             903.0            1132.0               79.8         12868.0
# 1401             764.0            1043.0               73.3         12061.0
# 97               587.0             862.0               68.1         10108.0
# ...                ...               ...                ...             ...
# 655             1035.0            1155.0               89.6         19235.0
# 1245            1195.0            1550.0               77.1         25219.0
# 617              446.0             593.0               75.2          7338.0
# 176              649.0             780.0               83.2          9698.0
# 1363             579.0             828.0               69.9          9035.0
#
#       Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 1158          2710.0             469.0             529.0               88.7
# 1049          2542.0             483.0             555.0               87.0
# 1378          3009.0             572.0             650.0               88.0
# 1401          3392.0             408.0             473.0               86.3
# 97            3121.0             282.0             345.0               81.7
# ...              ...               ...               ...                ...
# 655           6293.0             340.0             372.0               91.4
# 1245         10527.0             396.0             474.0               83.5
# 617           3528.0             227.0             262.0               86.6
# 176           2639.0             378.0             423.0               89.4
# 1363          2545.0             321.0             374.0               85.8
#
#       Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 1158              265.0              345.0                76.8
# 1049              282.0              348.0                81.0
# 1378              262.0              337.0                77.7
# 1401              296.0              394.0                75.1
# 97                214.0              299.0                71.6
# ...                 ...                ...                 ...
# 655               610.0              647.0                94.3
# 1245              588.0              683.0                86.1
# 617               186.0              238.0                78.2
# 176               225.0              258.0                87.2
# 1363              196.0              265.0                74.0
#
#       Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 1158             42.0             78.0              53.8            0.30
# 1049             32.0             63.0              50.8            0.28
# 1378             44.0             77.0              57.1            0.20
# 1401             42.0            115.0              36.5            0.24
# 97               64.0            153.0              41.8            0.25
# ...               ...              ...               ...             ...
# 655              77.0            112.0              68.8            0.00
# 1245            196.0            335.0              58.5            0.03
# 617              27.0             62.0              43.5            0.00
# 176              31.0             48.0              64.6            0.10
# 1363             43.0            101.0              42.6            0.44
#
#       xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 1158        0.24       0.30          0.06               1.57
# 1049        0.17       0.16          0.11               1.52
# 1378        0.25       0.27         -0.05               1.55
# 1401        0.24       0.31         -0.01               1.81
# 97          0.26       0.19         -0.01               2.02
# ...          ...        ...           ...                ...
# 655         0.02       0.06         -0.02               0.31
# 1245        0.07       0.07         -0.04               0.58
# 617         0.07       0.04         -0.07               0.58
# 176         0.04       0.06          0.07               0.81
# 1363        0.23       0.30          0.21               1.87
#
#       Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 1158               0.85                        1.81
# 1049               1.45                        1.49
# 1378               1.59                        2.12
# 1401               1.69                        2.09
# 97                 2.07                        1.49
# ...                 ...                         ...
# 655                4.81                        0.44
# 1245               3.34                        0.61
# 617                4.30                        0.74
# 176                2.98                        0.96
# 1363               1.04                        1.91
#
#       Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 1158                         0.42                       2.81
# 1049                         0.62                       3.01
# 1378                         0.65                       3.27
# 1401                         0.51                       3.54
# 97                           0.41                       3.80
# ...                           ...                        ...
# 655                          0.00                       5.62
# 1245                         0.08                       3.42
# 617                          0.08                       4.13
# 176                          0.05                       4.44
# 1363                         0.88                       2.63
#
#       Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 1158                    32.15                    31.48
# 1049                    37.16                    35.81
# 1378                    46.20                    44.53
# 1401                    41.06                    35.63
# 97                      35.62                    29.13
# ...                       ...                      ...
# 655                     72.19                    70.38
# 1245                    40.79                    39.08
# 617                     49.01                    43.47
# 176                     39.39                    38.59
# 1363                    32.99                    29.44
#
#       Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 1158                     0.51                     0.06                  0.03
# 1049                     1.25                     0.10                  0.10
# 1378                     1.47                     0.16                  0.24
# 1401                     5.39                     0.94                  0.04
# 97                       6.36                     2.02                  0.37
# ...                       ...                      ...                   ...
# 655                      1.75                     0.88                  0.19
# 1245                     1.37                     1.18                  0.03
# 617                      5.29                     0.25                  0.08
# 176                      0.56                     0.51                  0.15
# 1363                     3.39                     0.64                  0.32
#
#       Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 1158             0.27            3.63                    0.33
# 1049             0.07            3.49                    0.42
# 1378             0.24            3.55                    0.57
# 1401             0.12            6.85                    1.10
# 97               0.21            6.40                    1.36
# ...               ...             ...                     ...
# 655              0.25            0.50                    0.88
# 1245             0.58            0.16                    0.16
# 617              0.00            0.66                    5.04
# 176              0.15            0.40                    0.05
# 1363             0.12            6.10                    0.44
#
#       Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 1158                 0.12                    0.09                     0.00
# 1049                 0.73                    0.17                     0.45
# 1378                 0.73                    0.24                     0.16
# 1401                 3.35                    1.34                     1.18
# 97                   2.98                    1.78                     0.91
# ...                   ...                     ...                      ...
# 655                  0.00                    0.00                     0.00
# 1245                 0.00                    0.00                     0.00
# 617                  0.00                    0.00                     0.00
# 176                  0.00                    0.00                     0.00
# 1363                 2.27                    1.43                     0.32
#
#       Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 1158                     0.00              24.53               0.15
# 1049                     0.00              28.79               0.10
# 1378                     0.04              36.86               0.20
# 1401                     0.00              30.08               0.04
# 97                       0.04              24.26               0.12
# ...                       ...                ...                ...
# 655                      0.00              64.69               0.06
# 1245                     0.00              31.45               0.34
# 617                      0.00              36.86               0.25
# 176                      0.00              32.78               0.25
# 1363                     0.00              23.07               0.16
#
#       Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 1158                   1.27               1.36                   0.60
# 1049                   1.66               2.25                   1.07
# 1378                   0.90               2.37                   0.86
# 1401                   1.30               3.23                   1.14
# 97                     1.16               1.82                   0.50
# ...                     ...                ...                    ...
# 655                    0.50               0.38                   0.13
# 1245                   0.26               0.66                   0.11
# 617                    0.91               0.66                   0.17
# 176                    0.96               0.96                   0.30
# 1363                   1.87               2.23                   0.76
#
#       Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 1158            0.20                      0.45           0.13     2.9
# 1049            0.18                      0.39           0.12     4.0
# 1378            0.09                      0.24           0.09    -0.2
# 1401            0.07                      0.21           0.08    -0.2
# 97              0.07                      0.25           0.07    -0.2
# ...              ...                       ...            ...     ...
# 655             0.17                      0.50           0.12     0.3
# 1245            0.04                      0.25           0.10    -1.6
# 617             0.13                      0.50           0.09     0.3
# 176             0.00                      0.00           0.10    -2.0
# 1363            0.09                      0.26           0.11    -1.0
#
#       Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 1158       2.9                       23.5                -0.15
# 1049       4.0                       38.1                -0.07
# 1378      -0.2                       15.4                -0.12
# 1401      -0.2                       35.3                -0.12
# 97        -0.2                       35.3                -0.17
# ...        ...                        ...                  ...
# 655        0.3                       33.3                -0.19
# 1245      -1.6                       69.7                -0.29
# 617        0.3                       53.1                -0.33
# 176       -2.0                       45.3                -0.10
# 1363      -1.0                       47.1                -0.24
#
#       Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 1158             -0.00                      -0.00                   -0.91
# 1049             -0.00                      -0.00                   -0.66
# 1378             -0.00                      -0.00                   -0.94
# 1401             -0.04                      -0.00                   -0.91
# 97               -0.04                      -0.00                   -1.32
# ...                ...                        ...                     ...
# 655              -0.00                      -0.00                   -0.69
# 1245             -0.00                      -0.00                   -1.18
# 617              -0.00                      -0.00                   -0.91
# 176              -0.00                      -0.00                   -1.57
# 1363             -0.04                      -0.04                   -0.76
#
#       Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 1158                1.99             0.48                  0.54
# 1049                1.56             0.14                  0.35
# 1378                2.12             0.16                  0.78
# 1401                1.22             0.43                  0.31
# 97                  3.10             0.12                  0.83
# ...                  ...              ...                   ...
# 655                 0.31             0.06                  0.81
# 1245                0.66             0.03                  1.47
# 617                 0.50             0.25                  0.99
# 176                 1.87             0.05                  0.56
# 1363                1.47             0.48                  0.12
#
#       Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 1158                0.76                      0.06
# 1049                0.90                      0.03
# 1378                1.51                      0.08
# 1401                0.71                      0.00
# 97                  0.91                      0.00
# ...                  ...                       ...
# 655                 0.62                      0.00
# 1245                1.11                      0.00
# 617                 0.99                      0.00
# 176                 1.57                      0.00
# 1363                0.48                      0.12
#
#       Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 1158                          -0.00                    5.17
# 1049                          -0.00                    3.46
# 1378                          -0.00                    4.16
# 1401                          -0.00                    3.98
# 97                            -0.00                    4.71
# ...                             ...                     ...
# 655                           -0.00                    5.06
# 1245                          -0.03                    4.89
# 617                           -0.00                    5.54
# 176                           -0.00                    4.80
# 1363                          -0.04                    5.22
#
#       Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 1158                0.12                -0.39            1.27
# 1049                0.55                -0.90            1.21
# 1378                0.08                -0.45            2.49
# 1401                0.24                -0.43            1.26
# 97                  0.50                -0.91            1.24
# ...                  ...                  ...             ...
# 655                 1.00                -2.00            0.94
# 1245                3.68                -1.61            1.61
# 617                 2.15                -1.90            1.40
# 176                 1.46                -1.77            3.03
# 1363                0.32                -0.36            1.24
#
#       Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 1158                    0.42                    0.66                    0.18
# 1049                    0.48                    0.38                    0.35
# 1378                    1.31                    0.61                    0.57
# 1401                    0.35                    0.59                    0.31
# 97                      0.50                    0.54                    0.21
# ...                      ...                     ...                     ...
# 655                     0.44                    0.44                    0.06
# 1245                    1.21                    0.37                    0.03
# 617                     1.24                    0.08                    0.08
# 176                     0.81                    1.57                    0.66
# 1363                    0.36                    0.60                    0.28
#
#       Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 1158                      0.48                         0.85
# 1049                      0.59                         1.04
# 1378                      0.73                         1.96
# 1401                      0.55                         1.42
# 97                        0.45                         1.65
# ...                        ...                          ...
# 655                       0.25                         0.81
# 1245                      0.71                         1.26
# 617                       0.91                         1.57
# 176                       1.36                         2.32
# 1363                      0.52                         1.43
#
#       Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 1158                          0.36           1.03                  0.00
# 1049                          0.45           0.69                  0.03
# 1378                          1.22           1.31                  0.00
# 1401                          0.87           0.67                  0.04
# 97                            1.20           1.07                  0.04
# ...                            ...            ...                   ...
# 655                           0.56           1.56                  0.75
# 1245                          0.55           2.16                  1.47
# 617                           0.66           0.74                  0.41
# 176                           0.96           1.06                  0.05
# 1363                          0.92           0.72                  0.08
#
#       Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 1158                          1.81               0.33                 0.03
# 1049                          1.56               0.35                 0.03
# 1378                          3.27               0.45                 0.00
# 1401                          1.57               0.31                 0.00
# 97                            2.07               0.45                 0.00
# ...                            ...                ...                  ...
# 655                           1.75               4.00                 0.06
# 1245                          3.08               5.03                 0.05
# 617                           2.40               3.31                 0.00
# 176                           3.59               0.56                 0.05
# 1363                          1.35               0.16                 0.04
#
#       Dribblers_Tackle_W%  similarity_to_nico_2024
# 1158                 57.1                 0.976686
# 1049                 56.7                 0.964652
# 1378                 37.5                 0.962012
# 1401                 38.9                 0.957096
# 97                   27.5                 0.953258
# ...                   ...                      ...
# 655                  30.8                -0.969929
# 1245                 56.3                -0.970646
# 617                  57.9                -0.975266
# 176                  58.7                -0.976630
# 1363                 36.1                      NaN
#
# [1498 rows x 132 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=12)

# Use a dark background
plt.style.use('dark_background')

# Sort the player_2024 DataFrame by similarity_to_deligt_2024 in descending order
player_2024_sorted = player_2024.sort_values(by='similarity_to_nico_2024', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart, but reverse the order of the data
bars = ax.barh(player_2024_sorted['Player'].head(15)[::-1], (player_2024_sorted['similarity_to_nico_2024'].head(15)*100)[::-1],
               color=plt.cm.viridis(np.linspace(0, 1, 10)))

# Add labels and title
ax.set_xlabel('Similarity Percentage', fontproperties=font_prop)
ax.set_ylabel('Player', fontproperties=font_prop)
ax.set_title('Who is most similar to Nico Williams from top 5 leagues based on the 2023-24 Season?', fontproperties=font_prop)

# Set the y-axis tick labels with the custom font
ax.set_yticklabels(player_2024_sorted['Player'].head(15)[::-1], fontproperties=font_prop)

# Remove gridlines
ax.grid(False)

# Make the top and right spines invisible
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make the left and bottom spines white
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

# Change the color of ticks to white
ax.tick_params(colors='white')

# Change the color of labels to white
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')

# Add percentage labels to the bars
for bar in bars:
    width = bar.get_width()
    y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, y_pos, f'{width:.1f}%', ha='left', va='center',
            color='white', fontproperties=font_prop)


# Save the figure
plt.savefig('Similar_2024.png' ,dpi=500,bbox_inches = 'tight',transparent=False)

plt.show()

# %%
Fuhrich=player_2024[player_2024['Player']=='Chris Führich']
Fuhrich
# Out:
#      Unnamed: 0         Player  Nation    Pos      Squad           Comp  Age  \
# 440         914  Chris Führich  de GER  FW,MF  Stuttgart  de Bundesliga  0.0
#
#        Born  MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 440  1998.0  34      33  2567  28.5         0.28       0.53        0.28
#
#      G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 440          0.53      0.23          0.51         0.2            0.49
#
#      Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 440               153.0           73.0            47.7              68.0
#
#      Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 440               44.4           58.49                    0.28
#
#      Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 440                    4.11                   22.04                   33.26
#
#      Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 440                    4.35                      58.46
#
#      Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 440                       5.37                  2.56                     2.39
#
#      Carries_per_90  Total_Distance_per_90  \
# 440           37.54                 298.35
#
#      Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 440                               156.46                        5.37
#
#      1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 440                3.72                         1.96               -1.86
#
#      Dispossessed_per_90  Passes_Received_per_90  \
# 440                -0.95                   44.46
#
#      Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 440                                9.09                         4.8
#
#      Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 440                      0.6                   3.26                    0.6
#
#      Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 440                  0.53              0.32                     0.07
#
#      Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 440                   0.04                   0.49                   0.04
#
#      Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 440                  0.07               0.0                      0.0
#
#      Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 440                    0.0            1112.0            1370.0
#
#      Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 440               81.2         15384.0          4203.0             666.0
#
#      Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 440             737.0               90.4              325.0
#
#      Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 440              391.0                83.1             52.0            121.0
#
#      Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 440              43.0            0.25        0.28       0.32         -0.04
#
#      Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 440               1.86               2.07                        2.14
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 440                         0.32                       5.09
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 440                    48.07                    43.33
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 440                      4.6                     1.02                  0.25
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 440             0.35            3.51                    1.44
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 440                 2.14                    1.09                     0.25
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 440                      0.0              39.02               0.14
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 440                   1.19               1.86                   0.84
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 440            0.15                      0.33           0.11     1.4
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 440       2.2                       22.2                -0.07
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 440              -0.0                       -0.0                   -0.21
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 440                0.35             0.11                  0.25
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 440                0.67                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 440                           -0.0                    4.18
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 440                0.14                -0.49            1.05
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 440                    0.21                    0.49                    0.35
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 440                      0.56                          1.3
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 440                          0.74           1.09                   0.0
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 440                           1.3               0.25                  0.0
#
#      Dribblers_Tackle_W%  similarity_to_nico_2024
# 440                 43.2                 0.950598

# %%
import pandas as pd





params = [
    'Goal_Creating_Action_90', 
    'Tackled_Take_Ons', 
    'Take_Ons_Attempted_per_90', 
    'Progressive_Carries_per_90', 
    'Assists_per_90', 
    'Take_Ons_Succ_per_90', 
    'Crosses_Penalty_Area_per_90', 
    'Shot_Creating_Action_per90', 
    'Passes_Penalty_Area_per_90', 
    'Touches_Att_Pen_per_90', 
    'xA_per_90', 
    'Take_Ons_Goal_per_90', 
    'Carries_Penalty_Area_per_90', 
    'Progressive_Passes_Received_per_90', 
    'Take_Ons_Shot_per_90'
]


# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
mbappe_percentile_ranks = round(players_percentile_ranks.iloc[[440]],0)

# Print the percentile ranks for Harry Kane
print(mbappe_percentile_ranks)
# Out:
#      Goal_Creating_Action_90  Tackled_Take_Ons  Take_Ons_Attempted_per_90  \
# 440                     94.0              99.0                       97.0
#
#      Progressive_Carries_per_90  Assists_per_90  Take_Ons_Succ_per_90  \
# 440                        98.0            91.0                  97.0
#
#      Crosses_Penalty_Area_per_90  Shot_Creating_Action_per90  \
# 440                         74.0                        96.0
#
#      Passes_Penalty_Area_per_90  Touches_Att_Pen_per_90  xA_per_90  \
# 440                        97.0                    85.0       98.0
#
#      Take_Ons_Goal_per_90  Carries_Penalty_Area_per_90  \
# 440                  91.0                         96.0
#
#      Progressive_Passes_Received_per_90  Take_Ons_Shot_per_90
# 440                                94.0                  96.0

# %%
mbappe_percentile_ranks_list = mbappe_percentile_ranks.values.flatten().tolist()

mbappe_percentile_ranks_list
# Out:
# [94.0,
#  99.0,
#  97.0,
#  98.0,
#  91.0,
#  97.0,
#  74.0,
#  96.0,
#  97.0,
#  85.0,
#  98.0,
#  91.0,
#  96.0,
#  94.0,
#  96.0]

# %%
image_path = "Fuhrich.jpg"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    mbappe_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Chris Führich - Vfb Stuttgart", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Bundesliga Stats Percentile Rank vs Top-Five Leagues  Forwards | 2023-24 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Fuhrich_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png
