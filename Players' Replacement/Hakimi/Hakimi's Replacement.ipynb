# %%
import pandas as pd
import numpy as np
from PIL import Image
from mplsoccer import PyPizza, add_image, FontManager
import urllib.request

# %%
# Display the current settings
print("Current maximum number of rows: ", pd.get_option('display.max_rows'))
print("Current maximum number of columns: ", pd.get_option('display.max_columns'))

# Set new maximum number of rows and columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# Display the updated settings
print("Updated maximum number of rows: ", pd.get_option('display.max_rows'))
print("Updated maximum number of columns: ", pd.get_option('display.max_columns'))
# Out:
# Current maximum number of rows:  60
# Current maximum number of columns:  20
# Updated maximum number of rows:  500
# Updated maximum number of columns:  500

# %%
final_player = pd.read_csv('../final_players.csv')
player_2024=pd.read_csv('../Full_Players_2024.csv')
player_2023=pd.read_csv('../Full_Players_2023.csv')
player_2022=pd.read_csv('../Full_Players_2022.csv')
player_2021=pd.read_csv('../Full_Players_2021.csv')
newbie=pd.read_csv('../newbie_players_2024.csv')
# Fill missing values with 0 in place
final_player.fillna(0, inplace=True)
newbie.fillna(0,inplace=True)
player_2024.fillna(0,inplace=True)
player_2023.fillna(0, inplace=True)
player_2022.fillna(0, inplace=True)
player_2021.fillna(0, inplace=True)
final_player
# Out:
#       Unnamed: 0             Player  Nation    Pos  \
# 0              0     Theo Hernández  fr FRA     DF
# 1              1    Marcel Sabitzer  at AUT     MF
# 2              2   Dejan Kulusevski  se SWE  MF,FW
# 3              3      Julian Brandt  de GER  FW,MF
# 4              4  Nikola Milenković  rs SRB     DF
# ...          ...                ...     ...    ...
# 1507        2504   Souleymane Touré  fr FRA     DF
# 1508        2506        Jere Uronen  fi FIN     DF
# 1509        2507         Yan Valery  tn TUN     DF
# 1510        2513            Vitinha  pt POR     MF
# 1511        2518  Alessandro Zanoli  it ITA     DF
#
#                                                   Squad  \
# 0                                                 Milan
# 1     RB Leipzig+RB Leipzig+Bayern Munich+Manchester...
# 2                           Juventus+Tottenham+Juventus
# 3                                              Dortmund
# 4                                            Fiorentina
# ...                                                 ...
# 1507                                  Marseille+Auxerre
# 1508                                   Brest+Schalke 04
# 1509                                 Southampton+Angers
# 1510                                Marseille+Paris S-G
# 1511                                   Sampdoria+Napoli
#
#                                                 Comp   Age    Born     MP  \
# 0                                         it Serie A  25.0  1997.0   97.0
# 1     de Bundesliga+eng Premier League+de Bundesliga  29.0  1994.0   80.0
# 2           it Serie A+eng Premier League+it Serie A  23.0  2000.0  103.0
# 3                                      de Bundesliga  27.0  1996.0   94.0
# 4                                         it Serie A  25.0  1997.0   95.0
# ...                                              ...   ...     ...    ...
# 1507                                      fr Ligue 1  19.0  2003.0   24.0
# 1508                        fr Ligue 1+de Bundesliga  28.0  1994.0   17.0
# 1509                   eng Premier League+fr Ligue 1  23.0  1999.0   31.0
# 1510                                      fr Ligue 1  22.0  2000.0   50.0
# 1511                                      it Serie A  21.0  2000.0   23.0
#
#       Starts      Min   90s  Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  \
# 0       95.0     8415  93.5         0.17       0.31        0.15          0.29
# 1       46.0    53186  47.1         0.21       0.34        0.13          0.25
# 2       61.0  1265762  67.0         0.18       0.49        0.18          0.49
# 3       68.0     5970  66.3         0.32       0.59        0.32          0.59
# 4       91.0     8097  89.9         0.07       0.09        0.07          0.09
# ...      ...      ...   ...          ...        ...         ...           ...
# 1507    18.0     1656  18.4         0.05       0.05        0.05          0.05
# 1508    12.0      976  10.8         0.00       0.09        0.00          0.09
# 1509    31.0     2542  28.2         0.00       0.00        0.00          0.00
# 1510    34.0     2910  32.4         0.12       0.22        0.12          0.22
# 1511    16.0     1552  17.2         0.12       0.29        0.12          0.29
#
#       xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 0         0.13          0.28        0.11            0.26               272.0
# 1         0.25          0.31        0.17            0.25                38.0
# 2         0.15          0.36        0.15            0.36               260.0
# 3         0.18          0.43        0.18            0.43               185.0
# 4         0.09          0.10        0.09            0.10                13.0
# ...        ...           ...         ...             ...                 ...
# 1507      0.08          0.02        0.08            0.02                19.0
# 1508      0.01          0.13        0.01            0.13                12.0
# 1509      0.03          0.07        0.03            0.07                69.0
# 1510      0.22          0.88        0.22            0.88                64.0
# 1511      0.16          0.15        0.16            0.15                45.0
#
#       Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 0             141.0            52.0             118.0               43.0
# 1              22.0            58.0              15.0               39.0
# 2             138.0            53.0             114.0               44.0
# 3             102.0            55.0              78.0               42.0
# 4              10.0            77.0               3.0               23.0
# ...             ...             ...               ...                ...
# 1507            8.0            42.0               8.0              100.0
# 1508            3.0            25.0               8.0                0.0
# 1509           33.0            48.0              28.0                0.0
# 1510           36.0            56.0              23.0               55.0
# 1511           27.0            60.0              12.0               27.0
#
#       Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 0              68.72                    2.58                   16.66
# 1              71.53                    1.78                   12.23
# 2              46.15                    0.64                    6.18
# 3              65.47                    0.73                    7.14
# 4              65.57                    6.49                   30.81
# ...              ...                     ...                     ...
# 1507           55.00                    7.77                   27.77
# 1508           59.17                    3.15                   16.11
# 1509           57.84                    4.08                   18.01
# 1510           73.67                    1.45                   10.46
# 1511           50.93                    4.30                   19.24
#
#       Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                      33.33                   19.91                    2.24
# 1                      40.19                   19.51                    2.02
# 2                      17.72                   23.27                    5.04
# 3                      29.89                   29.16                    2.85
# 4                      31.63                    3.61                    1.02
# ...                      ...                     ...                     ...
# 1507                   25.11                    2.83                    0.92
# 1508                   29.63                   13.89                    0.19
# 1509                   27.09                   13.55                    0.50
# 1510                   42.62                   21.33                    2.47
# 1511                   20.06                   12.56                    1.34
#
#       Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                         68.68                       2.91
# 1                         71.44                       0.81
# 2                         46.15                       3.88
# 3                         65.47                       2.79
# 4                         65.57                       0.15
# ...                         ...                        ...
# 1507                      55.00                       1.03
# 1508                      59.17                       1.11
# 1509                      57.84                       2.45
# 1510                      73.67                       1.98
# 1511                      50.93                       2.62
#
#       Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                     1.51                     1.26           39.18
# 1                     0.47                     0.32           38.74
# 2                     2.06                     1.70           29.58
# 3                     1.54                     1.18           38.78
# 4                     0.11                     0.03           35.61
# ...                    ...                      ...             ...
# 1507                  0.43                     0.43           38.64
# 1508                  0.28                     0.74           29.44
# 1509                  1.17                     0.99           37.66
# 1510                  1.11                     0.71           61.88
# 1511                  1.57                     0.70           26.86
#
#       Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                    278.91                               174.26
# 1                    162.38                                72.17
# 2                    207.92                               110.02
# 3                    212.82                                87.22
# 4                    160.19                                89.36
# ...                     ...                                  ...
# 1507                 217.55                               106.90
# 1508                 130.46                                56.02
# 1509                 253.30                               125.28
# 1510                 325.49                               146.39
# 1511                 164.88                                99.19
#
#       Progressive_Carries_per_90  1/3_Carries_per_90  \
# 0                           4.00                2.88
# 1                           1.27                1.38
# 2                           3.97                2.09
# 3                           2.60                1.75
# 4                           0.52                0.49
# ...                          ...                 ...
# 1507                        0.65                0.38
# 1508                        1.11                0.83
# 1509                        2.55                2.55
# 1510                        1.64                2.47
# 1511                        2.97                1.40
#
#       Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 0                            0.76                1.74                 0.75
# 1                            0.17                1.32                 0.98
# 2                            1.76                3.33                 2.06
# 3                            0.92                2.26                 1.42
# 4                            0.02                0.35                 0.09
# ...                           ...                 ...                  ...
# 1507                         0.00                0.43                 0.11
# 1508                         0.00                1.30                 0.28
# 1509                         0.21                1.28                 1.21
# 1510                         0.22                1.57                 1.27
# 1511                         0.64                0.87                 0.52
#
#       Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 0                      43.07                                5.08
# 1                      49.37                                3.82
# 2                      32.71                                8.75
# 3                      48.34                                8.01
# 4                      41.12                                0.30
# ...                      ...                                 ...
# 1507                   35.00                                0.38
# 1508                   30.46                                2.87
# 1509                   33.30                                2.62
# 1510                   58.86                                4.17
# 1511                   30.99                                3.60
#
#       Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 0                       3.040000                 0.380000
# 1                      11.670000                 1.170000
# 2                      16.760000                 3.630000
# 3                       4.610000                 0.810000
# 4                       0.710000                 0.080000
# ...                          ...                      ...
# 1507                   16.304348                 0.000000
# 1508                   13.722222                 0.305556
# 1509                   36.343972                 0.982270
# 1510                   63.049383                 8.555556
# 1511                   34.802326                 2.982558
#
#       Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 0                      1.86                   0.49                  0.15
# 1                      2.38                   0.02                  0.00
# 2                      3.00                   0.18                  0.48
# 3                      3.21                   0.92                  0.24
# 4                      0.59                   0.01                  0.01
# ...                     ...                    ...                   ...
# 1507                   0.87                   0.00                  0.05
# 1508                   1.48                   0.28                  0.09
# 1509                   0.89                   0.07                  0.18
# 1510                   2.10                   0.06                  0.09
# 1511                   1.51                   0.12                  0.41
#
#       Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 0                 0.18                     0.31                   1.86
# 1                 0.17                     0.08                   2.38
# 2                 0.28                     0.06                   3.00
# 3                 0.11                     0.12                   3.21
# 4                 0.10                     0.00                   0.59
# ...                ...                      ...                    ...
# 1507              0.05                     0.00                   0.00
# 1508              0.00                     0.19                   0.00
# 1509              0.07                     0.11                   0.00
# 1510              0.19                     0.09                   0.06
# 1511              0.06                     0.00                   0.00
#
#       Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 0                      0.29                   0.02                  0.02
# 1                      0.26                   0.00                  0.00
# 2                      0.42                   0.01                  0.09
# 3                      0.56                   0.12                  0.08
# 4                      0.05                   0.00                  0.00
# ...                     ...                    ...                   ...
# 1507                   0.00                   0.00                  0.00
# 1508                   0.09                   0.00                  0.00
# 1509                   0.04                   0.00                  0.00
# 1510                   0.25                   0.00                  0.03
# 1511                   0.12                   0.00                  0.06
#
#       Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 0                 0.03                     0.01                   0.01
# 1                 0.02                     0.00                   0.00
# 2                 0.01                     0.00                   0.00
# 3                 0.01                     0.05                   0.00
# 4                 0.02                     0.00                   0.00
# ...                ...                      ...                    ...
# 1507              0.00                     0.00                   0.00
# 1508              0.00                     0.00                   0.00
# 1509              0.00                     0.00                   0.00
# 1510              0.03                     0.03                   0.00
# 1511              0.00                     0.00                   0.00
#
#       Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 0               4322.0            5383.0               80.0         69809.0
# 1               2306.0            2878.0               80.0         35602.0
# 2               1768.0            2242.0               79.0         24626.0
# 3               2851.0            3623.0               79.0         43730.0
# 4               4419.0            5076.0               87.0         86576.0
# ...                ...               ...                ...             ...
# 1507             713.0             820.0               87.0         13368.0
# 1508             400.0             530.0               75.0          7012.0
# 1509             965.0            1315.0               73.0         16999.0
# 1510            1863.0            2054.0               91.0         27171.0
# 1511             544.0             711.0               77.0          8897.0
#
#       Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 0            23453.0            2291.0            2557.0               90.0
# 1            10553.0            1258.0            1433.0               88.0
# 2             5878.0            1073.0            1230.0               87.0
# 3            11218.0            1558.0            1794.0               87.0
# 4            28099.0            1478.0            1657.0               89.0
# ...              ...               ...               ...                ...
# 1507          4272.0             233.0             274.0               85.0
# 1508          2847.0             183.0             211.0               87.0
# 1509          6836.0             423.0             513.0               82.0
# 1510          6003.0            1006.0            1079.0               93.0
# 1511          2760.0             269.0             300.0               90.0
#
#       Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 0                1580.0             1904.0                83.0
# 1                 806.0              954.0                84.0
# 2                 532.0              651.0                82.0
# 3                 844.0             1028.0                82.0
# 4                2369.0             2573.0                92.0
# ...                 ...                ...                 ...
# 1507              380.0              404.0                94.0
# 1508              161.0              195.0                83.0
# 1509              411.0              517.0                79.0
# 1510              634.0              683.0                93.0
# 1511              224.0              284.0                79.0
#
#       Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 0               336.0            593.0              57.0            0.00
# 1               147.0            272.0              54.0            0.06
# 2                80.0            140.0              57.0            0.17
# 3               265.0            446.0              59.0            0.00
# 4               527.0            720.0              73.0            0.00
# ...               ...              ...               ...             ...
# 1507             77.0            108.0              71.0            0.00
# 1508             44.0             86.0              51.0            0.09
# 1509             99.0            216.0              46.0            0.00
# 1510             98.0            117.0              84.0            0.09
# 1511             39.0             80.0              49.0            0.17
#
#       xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 0           0.15       0.14         -0.01               1.39
# 1           0.12       0.17          0.00               1.19
# 2           0.23       0.19          0.08               2.00
# 3           0.25       0.25          0.03               2.23
# 4           0.02       0.02          0.01               0.17
# ...          ...        ...           ...                ...
# 1507        0.02       0.02         -0.02               0.43
# 1508        0.10       0.15         -0.01               0.93
# 1509        0.07       0.06         -0.07               0.43
# 1510        0.10       0.11         -0.01               0.93
# 1511        0.07       0.05          0.10               0.81
#
#       Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 0                  3.25                        1.20
# 1                  5.12                        1.51
# 2                  1.26                        1.55
# 3                  2.93                        1.66
# 4                  3.27                        0.11
# ...                 ...                         ...
# 1507               2.39                        0.22
# 1508               2.87                        1.20
# 1509               2.48                        0.60
# 1510               5.46                        0.80
# 1511               1.10                        0.76
#
#       Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 0                            0.39                       4.03
# 1                            0.24                       7.05
# 2                            0.39                       2.92
# 3                            0.29                       5.23
# 4                            0.00                       3.50
# ...                           ...                        ...
# 1507                         0.00                       2.55
# 1508                         1.11                       4.17
# 1509                         0.50                       2.98
# 1510                         0.03                       4.51
# 1511                         0.41                       2.09
#
#       Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 0                       57.57                    47.03
# 1                       61.10                    57.54
# 2                       33.46                    31.49
# 3                       54.65                    50.00
# 4                       56.46                    53.29
# ...                       ...                      ...
# 1507                    44.57                    43.42
# 1508                    49.07                    38.89
# 1509                    46.63                    38.62
# 1510                    63.40                    62.31
# 1511                    41.34                    35.12
#
#       Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 0                       10.36                     1.73                  0.06
# 1                        3.04                     1.51                  0.12
# 2                        1.85                     0.18                  0.24
# 3                        4.46                     0.67                  0.21
# 4                        3.08                     1.94                  0.00
# ...                       ...                      ...                   ...
# 1507                     1.09                     1.03                  0.00
# 1508                     9.91                     1.11                  0.00
# 1509                     7.98                     0.74                  0.00
# 1510                     0.90                     0.31                  0.25
# 1511                     6.16                     0.70                  0.00
#
#       Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 0                0.59            3.15                    7.86
# 1                0.53            1.12                    1.38
# 2                0.09            2.30                    0.25
# 3                0.45            4.86                    0.49
# 4                0.77            0.09                    1.14
# ...               ...             ...                     ...
# 1507             0.27            0.16                    0.05
# 1508             0.19            3.98                    8.43
# 1509             0.21            2.91                    7.23
# 1510             0.19            0.43                    0.09
# 1511             0.12            1.98                    5.47
#
#       Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 0                    0.77                    0.04                     0.68
# 1                    0.04                    0.02                     0.00
# 2                    0.60                    0.19                     0.11
# 3                    3.24                    1.15                     1.55
# 4                    0.00                    0.00                     0.00
# ...                   ...                     ...                      ...
# 1507                 0.00                    0.00                     0.00
# 1508                 0.37                    0.09                     0.28
# 1509                 0.00                    0.00                     0.00
# 1510                 0.19                    0.06                     0.09
# 1511                 0.00                    0.00                     0.00
#
#       Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 0                        0.00              46.22               0.18
# 1                        0.00              48.96               0.53
# 2                        0.00              26.39               0.12
# 3                        0.04              43.00               0.18
# 4                        0.00              49.15               0.09
# ...                       ...                ...                ...
# 1507                     0.00              38.75               0.05
# 1508                     0.00              37.04               0.28
# 1509                     0.00              34.22               0.04
# 1510                     0.00              57.50               0.19
# 1511                     0.00              31.63               0.06
#
#       Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 0                      1.28           1.480000               0.400000
# 1                      1.21           9.360000               2.940000
# 2                      1.20           8.890000               2.910000
# 3                      1.13           1.480000               0.740000
# 4                      0.42           0.700000               0.260000
# ...                     ...                ...                    ...
# 1507                   0.49           7.652174               1.913043
# 1508                   1.48           3.083333               0.000000
# 1509                   1.38          12.769504               1.964539
# 1510                   0.93          30.037037              10.679012
# 1511                   1.40          14.918605               6.965116
#
#       Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 0               3.60                     13.42           2.33     3.9
# 1               0.29                      0.94           0.24    -1.5
# 2               0.46                      1.42           0.37     2.0
# 3               4.81                      9.97           2.80     8.7
# 4               2.77                      7.77           3.86    -1.9
# ...              ...                       ...            ...     ...
# 1507            0.12                      0.50           0.19    -0.5
# 1508            0.00                      0.00           0.02    -0.1
# 1509            0.00                      0.00           0.06    -0.8
# 1510            0.07                      0.20           0.12    -3.0
# 1511            0.12                      0.25           0.17    -0.7
#
#       Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 0          3.6                       67.0                 0.25
# 1         -2.3                       48.0                 0.25
# 2          2.0                       32.0                 0.20
# 3          8.7                       31.0                 0.08
# 4         -1.9                       75.0                 0.24
# ...        ...                        ...                  ...
# 1507      -0.5                       71.0                 0.33
# 1508      -0.1                       53.0                 0.19
# 1509      -0.8                       63.0                 0.11
# 1510      -3.0                       37.0                 0.09
# 1511      -0.7                       33.0                 0.17
#
#       Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 0                 0.02                       0.01                    1.02
# 1                 0.00                       0.00                    1.12
# 2                 0.00                       0.00                    1.88
# 3                 0.00                       0.00                    0.41
# 4                 0.02                       0.01                    1.59
# ...                ...                        ...                     ...
# 1507              0.05                       0.05                    1.20
# 1508              0.00                       0.00                    0.74
# 1509              0.00                       0.00                    1.63
# 1510              0.00                       0.00                    1.17
# 1511              0.00                       0.00                    0.23
#
#       Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 0                   2.27             0.17                  0.83
# 1                   1.32             0.19                  1.34
# 2                   1.18             0.22                  0.60
# 3                   0.80             0.14                  0.84
# 4                   0.65             0.00                  1.17
# ...                  ...              ...                   ...
# 1507                0.71             0.00                  1.41
# 1508                1.85             0.00                  1.39
# 1509                0.71             0.04                  1.21
# 1510                0.83             0.12                  0.83
# 1511                0.58             0.00                  0.70
#
#       Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 0                   0.94                      0.02
# 1                   1.08                      0.00
# 2                   0.88                      0.00
# 3                   0.80                      0.00
# 4                   0.95                      0.00
# ...                  ...                       ...
# 1507                0.76                      0.00
# 1508                1.39                      0.00
# 1509                1.38                      0.00
# 1510                0.99                      0.00
# 1511                0.81                      0.00
#
#       Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                              0.00                    6.63
# 1                              0.00                    6.73
# 2                              0.01                    5.44
# 3                              0.00                    5.41
# 4                              0.02                    4.97
# ...                             ...                     ...
# 1507                           0.05                    4.78
# 1508                           0.00                    5.46
# 1509                           0.00                    5.07
# 1510                           0.00                    5.90
# 1511                           0.00                    4.59
#
#       Aerials_Won_per_90  Aerials_Lost_per_90  Seasons at top 5  \
# 0                   1.20                 0.58                 3
# 1                   0.98                 1.04                 3
# 2                   0.39                 0.83                 3
# 3                   0.47                 1.04                 3
# 4                   3.03                 1.02                 3
# ...                  ...                  ...               ...
# 1507                1.36                 0.54                 1
# 1508                1.67                 1.48                 1
# 1509                1.35                 0.78                 1
# 1510                0.31                 0.52                 1
# 1511                0.58                 1.16                 1
#
#       Seasons in PL  Seasons in Liga  Seasons in Serie A  Seasons in Ligue 1  \
# 0                 0                0                   3                   0
# 1                 1                0                   0                   0
# 2                 2                0                   2                   0
# 3                 0                0                   0                   0
# 4                 0                0                   3                   0
# ...             ...              ...                 ...                 ...
# 1507              0                0                   0                   1
# 1508              0                0                   0                   1
# 1509              1                0                   0                   1
# 1510              0                0                   0                   1
# 1511              0                0                   1                   0
#
#       Seasons in Bundesliga
# 0                         0
# 1                         3
# 2                         0
# 3                         3
# 4                         0
# ...                     ...
# 1507                      0
# 1508                      1
# 1509                      0
# 1510                      0
# 1511                      0
#
# [1512 rows x 124 columns]

# %%
# Assuming 'final_player' is the DataFrame containing player data

# Filter out forwards (FW) and midfielders (MF) from the 'final_player' DataFrame
defense_players = final_player[final_player['Pos'].isin(['DF'])]
newbie = newbie[newbie['Pos'].isin(['DF'])]
player_2021 = player_2021[player_2021['Pos'].isin(['DF'])]
player_2022 = player_2022[player_2022['Pos'].isin(['DF'])]
player_2023 = player_2023[player_2023['Pos'].isin(['DF'])]
player_2024 = player_2024[player_2024['Pos'].isin(['DF'])]

# Reset the index if needed
defense_players = defense_players.reset_index(drop=True)
newbie = newbie.reset_index(drop=True)
player_2024= player_2024.reset_index(drop=True)
player_2023 = player_2023.reset_index(drop=True)
player_2022 = player_2022.reset_index(drop=True)
player_2021 = player_2021.reset_index(drop=True)

# %%
# Filter player_2023
player_2024 = player_2024.loc[player_2024['Min'] >= 900]

# Filter player_2023
player_2023 = player_2023.loc[player_2023['Min'] >= 900]

# Filter player_2022
player_2022 = player_2022.loc[player_2022['Min'] >= 900]

# Filter player_2021
player_2021 = player_2021.loc[player_2021['Min'] >= 900]

player_2024
# Out:
#      Unnamed: 0            Player   Nation Pos                     Squad  \
# 0             0        Max Aarons  eng ENG  DF               Bournemouth
# 1             4  Yunis Abdelhamid   ma MAR  DF                     Reims
# 2             9             Abner   br BRA  DF                     Betis
# 3            11       Abdel Abqar   ma MAR  DF                    Alavés
# 4            13  Francesco Acerbi   it ITA  DF                     Inter
# ..          ...               ...      ...  ..                       ...
# 564         107   Sergio Reguilón   es ESP  DF  Manchester Utd+Brentford
# 565         115       Alidu Seidu   gh GHA  DF      Rennes+Clermont Foot
# 566         129        Kevin Vogt   de GER  DF   Hoffenheim+Union Berlin
# 567         133  Mateusz Wieteska   pl POL  DF    Cagliari+Clermont Foot
# 568         138      Nadir Zortea   it ITA  DF        Frosinone+Atalanta
#
#                       Comp  Age    Born  MP  Starts   Min   90s  Goals_per90  \
# 0       eng Premier League  0.0  2000.0  20      13  1237  13.7         0.00
# 1               fr Ligue 1  0.0  1987.0  31      31  2781  30.9         0.13
# 2               es La Liga  0.0  2000.0  23      15  1400  15.6         0.00
# 3               es La Liga  0.0  1999.0  27      27  2312  25.7         0.00
# 4               it Serie A  0.0  1988.0  29      26  2388  26.5         0.11
# ..                     ...  ...     ...  ..     ...   ...   ...          ...
# 564     eng Premier League  0.0  1996.0  25      18  1530  17.0         0.00
# 565             fr Ligue 1  0.0  2000.0  25      20  1724  19.2         0.00
# 566          de Bundesliga  0.0  1991.0  32      30  2642  29.4         0.00
# 567  it Serie A+fr Ligue 1  0.0  1997.0  21      12  1139  12.6         0.08
# 568             it Serie A  0.0  1999.0  19      14  1407  15.7         0.13
#
#      G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 0         0.07        0.00          0.07      0.00          0.06        0.00
# 1         0.13        0.10          0.10      0.11          0.12        0.09
# 2         0.06        0.00          0.06      0.01          0.07        0.01
# 3         0.00        0.00          0.00      0.02          0.02        0.02
# 4         0.15        0.11          0.15      0.06          0.13        0.06
# ..         ...         ...           ...       ...           ...         ...
# 564       0.24        0.00          0.24      0.06          0.27        0.06
# 565       0.05        0.00          0.05      0.02          0.09        0.02
# 566       0.00        0.00          0.00      0.02          0.05        0.02
# 567       0.16        0.08          0.16      0.03          0.03        0.03
# 568       0.45        0.13          0.45      0.03          0.19        0.03
#
#      npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 0              0.06                34.0           14.0            41.2
# 1              0.09                15.0            8.0            53.3
# 2              0.07                13.0            7.0            53.8
# 3              0.02                 5.0            3.0            60.0
# 4              0.13                 3.0            2.0            66.7
# ..              ...                 ...            ...             ...
# 564            0.27                37.0           16.0            43.0
# 565            0.09                36.0           17.0            47.0
# 566            0.05                 7.0            6.0            86.0
# 567            0.03                 6.0            3.0            50.0
# 568            0.19                52.0           22.0            42.0
#
#      Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 0                12.0               35.3           51.90
# 1                 7.0               46.7           70.71
# 2                 5.0               38.5           61.92
# 3                 1.0               20.0           40.16
# 4                 1.0               33.3           74.60
# ..                ...                ...             ...
# 564              15.0               41.0           63.88
# 565              15.0               42.0           70.00
# 566               1.0               14.0           65.44
# 567               3.0               50.0           55.56
# 568              25.0               48.0           53.69
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 0                      3.14                   18.39                   22.12
# 1                      9.48                   31.59                   36.21
# 2                      4.62                   22.05                   25.96
# 3                      7.43                   22.18                   16.42
# 4                      8.26                   35.51                   35.70
# ..                      ...                     ...                     ...
# 564                    3.71                   18.35                   24.00
# 565                    4.74                   25.68                   36.61
# 566                    8.57                   34.18                   29.59
# 567                    7.22                   28.89                   24.92
# 568                    2.04                   11.46                   22.10
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                     12.04                    0.80
# 1                      3.69                    1.13
# 2                     14.49                    1.79
# 3                      1.63                    0.82
# 4                      3.70                    0.94
# ..                      ...                     ...
# 564                   22.53                    1.82
# 565                    8.54                    0.16
# 566                    1.87                    0.27
# 567                    2.22                    0.79
# 568                   20.57                    1.66
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                        51.90                       2.48
# 1                        70.68                       0.49
# 2                        61.92                       0.83
# 3                        40.16                       0.19
# 4                        74.60                       0.11
# ..                         ...                        ...
# 564                      63.88                       2.18
# 565                      70.00                       1.88
# 566                      65.44                       0.24
# 567                      55.56                       0.48
# 568                      53.69                       3.31
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                    1.02                     0.88           26.57
# 1                    0.26                     0.23           48.74
# 2                    0.45                     0.32           28.65
# 3                    0.12                     0.04           19.14
# 4                    0.08                     0.04           45.70
# ..                    ...                      ...             ...
# 564                  0.94                     0.88           29.53
# 565                  0.89                     0.78           48.85
# 566                  0.20                     0.03           36.05
# 567                  0.24                     0.24           30.79
# 568                  1.40                     1.59           26.11
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                   158.69                                81.82
# 1                   280.36                               159.26
# 2                   115.51                                60.83
# 3                    95.72                                55.18
# 4                   218.08                               116.26
# ..                     ...                                  ...
# 564                 166.76                                94.18
# 565                 313.07                               139.22
# 566                 192.41                               111.19
# 567                 177.78                               114.60
# 568                 148.09                                70.64
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 0                          1.61                0.88
# 1                          1.17                0.61
# 2                          0.90                0.64
# 3                          0.27                0.23
# 4                          0.79                0.42
# ..                          ...                 ...
# 564                        2.65                1.71
# 565                        1.56                1.72
# 566                        0.58                0.24
# 567                        1.27                0.16
# 568                        2.42                1.72
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 0                           0.51                0.95                 0.58
# 1                           0.00                0.74                 0.13
# 2                           0.32                1.15                 0.71
# 3                           0.00                0.58                 0.04
# 4                           0.00                0.15                 0.04
# ..                           ...                 ...                  ...
# 564                         0.24                1.76                 0.35
# 565                         0.05                1.25                 0.47
# 566                         0.00                0.44                 0.07
# 567                         0.00                0.40                 0.24
# 568                         0.38                2.04                 1.08
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 0                     27.08                                1.90
# 1                     45.40                                0.29
# 2                     32.18                                3.72
# 3                     19.42                                0.04
# 4                     54.57                                0.91
# ..                      ...                                 ...
# 564                   32.29                                4.59
# 565                   43.07                                1.41
# 566                   42.79                                0.44
# 567                   33.81                                0.16
# 568                   30.51                                5.92
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 0                          1.68                     0.15
# 1                          0.78                     0.03
# 2                          0.90                     0.00
# 3                          0.47                     0.00
# 4                          0.83                     0.04
# ..                          ...                      ...
# 564                        2.94                     0.41
# 565                        1.09                     0.05
# 566                        1.12                     0.17
# 567                        0.79                     0.08
# 568                        3.25                     0.57
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 0                     1.17                   0.29                  0.00
# 1                     0.61                   0.03                  0.00
# 2                     0.83                   0.00                  0.00
# 3                     0.35                   0.00                  0.00
# 4                     0.72                   0.00                  0.00
# ..                     ...                    ...                   ...
# 564                   1.94                   0.71                  0.06
# 565                   0.73                   0.10                  0.05
# 566                   1.12                   0.00                  0.00
# 567                   0.71                   0.00                  0.00
# 568                   2.36                   0.38                  0.19
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 0                0.00                     0.22                   0.00
# 1                0.10                     0.03                   0.00
# 2                0.06                     0.00                   0.00
# 3                0.08                     0.04                   0.00
# 4                0.11                     0.00                   0.00
# ..                ...                      ...                    ...
# 564              0.18                     0.06                   0.00
# 565              0.00                     0.16                   0.05
# 566              0.00                     0.00                   0.00
# 567              0.00                     0.00                   0.08
# 568              0.19                     0.06                   0.06
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 0                     0.15                   0.00                  0.00
# 1                     0.00                   0.00                  0.00
# 2                     0.00                   0.00                  0.00
# 3                     0.00                   0.00                  0.00
# 4                     0.04                   0.00                  0.00
# ..                     ...                    ...                   ...
# 564                   0.18                   0.12                  0.00
# 565                   0.05                   0.00                  0.00
# 566                   0.17                   0.00                  0.00
# 567                   0.08                   0.00                  0.00
# 568                   0.51                   0.00                  0.06
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 0                0.00                      0.0                    0.0
# 1                0.03                      0.0                    0.0
# 2                0.00                      0.0                    0.0
# 3                0.00                      0.0                    0.0
# 4                0.00                      0.0                    0.0
# ..                ...                      ...                    ...
# 564              0.12                      0.0                    0.0
# 565              0.00                      0.0                    0.0
# 566              0.00                      0.0                    0.0
# 567              0.00                      0.0                    0.0
# 568              0.00                      0.0                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 0               450.0             581.0               77.5          7402.0
# 1              1552.0            1836.0               84.5         29618.0
# 2               615.0             797.0               77.2          9211.0
# 3               553.0             762.0               72.6         12370.0
# 4              1615.0            1781.0               90.7         29326.0
# ..                ...               ...                ...             ...
# 564             595.0             836.0               71.0          9726.0
# 565             932.0            1118.0               83.0         16513.0
# 566            1465.0            1674.0               88.0         32160.0
# 567             463.0             576.0               80.0          9154.0
# 568             487.0             664.0               73.0          7876.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 0            2789.0             220.0             248.0               88.7
# 1            9672.0             487.0             548.0               88.9
# 2            4552.0             351.0             394.0               89.1
# 3            4872.0             141.0             164.0               86.0
# 4            9174.0             601.0             650.0               92.5
# ..              ...               ...               ...                ...
# 564          3982.0             298.0             351.0               85.0
# 565          4733.0             397.0             433.0               92.0
# 566         13483.0             360.0             381.0               94.0
# 567          4116.0             144.0             164.0               88.0
# 568          3172.0             262.0             303.0               86.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 0                188.0              235.0                80.0
# 1                893.0              976.0                91.5
# 2                203.0              265.0                76.6
# 3                302.0              339.0                89.1
# 4                856.0              908.0                94.3
# ..                 ...                ...                 ...
# 564              231.0              312.0                74.0
# 565              428.0              502.0                85.0
# 566              805.0              875.0                92.0
# 567              270.0              301.0                90.0
# 568              166.0              219.0                76.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 0               34.0             63.0              54.0            0.07
# 1              141.0            252.0              56.0            0.00
# 2               37.0             79.0              46.8            0.06
# 3               99.0            225.0              44.0            0.00
# 4              132.0            179.0              73.7            0.04
# ..               ...              ...               ...             ...
# 564             50.0            108.0              46.0            0.24
# 565             79.0            142.0              56.0            0.05
# 566            277.0            381.0              73.0            0.00
# 567             46.0             99.0              46.0            0.08
# 568             45.0             88.0              51.0            0.32
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 0          0.06       0.07          0.01               0.51
# 1          0.01       0.02         -0.01               0.26
# 2          0.06       0.06          0.00               0.51
# 3          0.01       0.01         -0.01               0.12
# 4          0.07       0.05         -0.03               0.26
# ..          ...        ...           ...                ...
# 564        0.21       0.16          0.03               1.65
# 565        0.04       0.02          0.01               0.42
# 566        0.00       0.02         -0.00               0.10
# 567        0.05       0.02          0.03               0.40
# 568        0.20       0.15          0.12               1.53
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 0                 1.82                        0.95
# 1                 4.17                        0.10
# 2                 1.28                        0.45
# 3                 2.37                        0.08
# 4                 2.19                        0.19
# ..                 ...                         ...
# 564               2.18                        1.24
# 565               3.12                        0.21
# 566               3.74                        0.44
# 567               3.10                        0.40
# 568               1.85                        1.85
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 0                           0.15                       3.14
# 1                           0.00                       4.43
# 2                           0.13                       2.12
# 3                           0.00                       1.91
# 4                           0.08                       3.28
# ..                           ...                        ...
# 564                         0.88                       3.82
# 565                         0.00                       2.92
# 566                         0.00                       4.25
# 567                         0.08                       3.10
# 568                         1.27                       3.31
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 0                      42.41                    33.07
# 1                      59.42                    53.40
# 2                      51.09                    40.26
# 3                      29.65                    27.39
# 4                      67.21                    64.87
# ..                       ...                      ...
# 564                    49.18                    40.00
# 565                    58.23                    52.34
# 566                    56.94                    53.88
# 567                    45.71                    42.78
# 568                    42.29                    32.48
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 0                       9.27                     0.80                  0.15
# 1                       5.76                     2.43                  0.06
# 2                      10.58                     0.45                  0.00
# 3                       2.14                     1.95                  0.00
# 4                       2.26                     1.62                  0.00
# ..                       ...                      ...                   ...
# 564                     8.88                     2.00                  0.06
# 565                     5.62                     0.83                  0.00
# 566                     2.96                     2.18                  0.03
# 567                     2.94                     1.35                  0.08
# 568                     9.75                     0.45                  0.00
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 0               0.22            0.95                    8.47
# 1               0.42            0.10                    0.94
# 2               0.19            1.67                   10.13
# 3               0.66            0.08                    0.16
# 4               0.42            0.34                    0.30
# ..               ...             ...                     ...
# 564             0.12            5.94                    4.94
# 565             0.16            0.52                    4.79
# 566             0.41            0.10                    0.44
# 567             0.08            0.32                    1.51
# 568             0.00            5.48                    8.15
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 0                   0.00                    0.00                     0.00
# 1                   0.00                    0.00                     0.00
# 2                   0.00                    0.00                     0.00
# 3                   0.00                    0.00                     0.00
# 4                   0.00                    0.00                     0.00
# ..                   ...                     ...                      ...
# 564                 1.94                    0.53                     0.88
# 565                 0.00                    0.00                     0.00
# 566                 0.00                    0.00                     0.00
# 567                 0.00                    0.00                     0.00
# 568                 1.15                    0.00                     0.89
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 0                       0.00              32.85               0.07
# 1                       0.00              50.23               0.26
# 2                       0.00              39.42               0.26
# 3                       0.00              21.52               0.12
# 4                       0.00              60.94               0.08
# ..                       ...                ...                ...
# 564                     0.00              35.00               0.29
# 565                     0.00              48.54               0.26
# 566                     0.00              49.83               0.10
# 567                     0.00              36.75               0.00
# 568                     0.06              31.02               0.06
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 0                     1.68               0.15                   0.00
# 1                     0.65               0.68                   0.23
# 2                     1.47               0.26                   0.00
# 3                     0.39               0.39                   0.12
# 4                     0.19               0.57                   0.23
# ..                     ...                ...                    ...
# 564                   1.53               1.00                   0.06
# 565                   0.52               0.42                   0.05
# 566                   0.24               0.10                   0.03
# 567                   0.79               0.56                   0.16
# 568                   1.91               0.76                   0.32
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 0              0.00                      0.00           0.02     0.0
# 1              0.14                      0.43           0.13     0.6
# 2              0.00                      0.00           0.03    -0.1
# 3              0.00                      0.00           0.05    -0.5
# 4              0.20                      0.50           0.11     1.4
# ..              ...                       ...            ...     ...
# 564            0.00                      0.00           0.06    -1.0
# 565            0.00                      0.00           0.04    -0.3
# 566            0.00                      0.00           0.23    -0.7
# 567            0.14                      0.50           0.06     0.6
# 568            0.17                      0.40           0.04     1.5
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 0         0.0                       31.3                 0.07
# 1         0.4                       62.2                 0.16
# 2        -0.1                       58.3                 0.19
# 3        -0.5                       52.0                 0.39
# 4         1.4                       65.4                 0.04
# ..        ...                        ...                  ...
# 564      -1.0                       40.0                 0.41
# 565      -0.3                       63.0                 0.42
# 566      -0.7                       58.0                 0.24
# 567       0.6                       61.0                 0.40
# 568       1.5                       32.0                 0.25
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 0                0.00                       0.00                    0.88
# 1                0.00                       0.00                    0.84
# 2                0.00                       0.00                    1.03
# 3                0.00                       0.00                    1.28
# 4                0.00                       0.00                    0.72
# ..                ...                        ...                     ...
# 564              0.06                       0.00                    0.82
# 565              0.05                       0.00                    1.46
# 566              0.00                       0.00                    0.95
# 567              0.08                       0.08                    0.95
# 568              0.00                       0.00                    1.21
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 0                  1.90             0.15                  0.58
# 1                  0.39             0.00                  1.26
# 2                  0.13             0.13                  0.96
# 3                  0.89             0.04                  0.89
# 4                  0.91             0.11                  1.21
# ..                  ...              ...                   ...
# 564                1.53             0.24                  1.24
# 565                2.24             0.05                  1.82
# 566                0.58             0.03                  0.54
# 567                0.63             0.08                  1.51
# 568                1.02             0.00                  0.32
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 0                  1.39                       0.0
# 1                  1.13                       0.0
# 2                  1.22                       0.0
# 3                  0.74                       0.0
# 4                  0.49                       0.0
# ..                  ...                       ...
# 564                1.65                       0.0
# 565                1.72                       0.0
# 566                0.65                       0.0
# 567                0.95                       0.0
# 568                1.15                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                             0.07                    5.47
# 1                             0.00                    4.82
# 2                             0.06                    5.06
# 3                             0.08                    4.24
# 4                             0.00                    3.85
# ..                             ...                     ...
# 564                           0.06                    5.65
# 565                           0.05                    7.29
# 566                           0.00                    5.88
# 567                           0.00                    4.68
# 568                           0.00                    3.63
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 0                  0.36                 0.80            2.12
# 1                  1.97                 1.20            2.07
# 2                  0.90                 0.64            1.60
# 3                  1.52                 1.40            1.36
# 4                  2.64                 1.40            0.83
# ..                  ...                  ...             ...
# 564                1.12                 1.71            3.41
# 565                1.15                 0.68            2.76
# 566                0.75                 0.54            0.82
# 567                2.46                 1.59            1.43
# 568                0.70                 1.46            1.66
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 0                      1.46                    0.51                    0.15
# 1                      1.17                    0.74                    0.16
# 2                      0.96                    0.58                    0.06
# 3                      1.09                    0.19                    0.08
# 4                      0.60                    0.23                    0.00
# ..                      ...                     ...                     ...
# 564                    1.88                    1.18                    0.35
# 565                    1.77                    0.94                    0.05
# 566                    0.44                    0.37                    0.00
# 567                    0.95                    0.32                    0.16
# 568                    0.70                    0.89                    0.06
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 0                        1.46                         2.48
# 1                        0.84                         1.46
# 2                        1.09                         2.18
# 3                        0.82                         1.36
# 4                        0.42                         0.53
# ..                        ...                          ...
# 564                      1.88                         3.35
# 565                      1.98                         2.60
# 566                      0.48                         0.85
# 567                      0.48                         1.19
# 568                      0.70                         1.66
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 0                            1.02           0.66                  0.36
# 1                            0.61           1.65                  1.04
# 2                            1.09           1.47                  0.32
# 3                            0.54           1.21                  1.01
# 4                            0.11           0.75                  0.49
# ..                            ...            ...                   ...
# 564                          1.47           1.94                  0.35
# 565                          0.62           1.35                  0.52
# 566                          0.37           1.29                  0.95
# 567                          0.71           1.11                  0.56
# 568                          0.96           0.96                  0.32
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                            2.70               1.97                 0.00
# 1                            3.33               3.53                 0.06
# 2                            2.56               3.97                 0.00
# 3                            2.26               4.47                 0.00
# 4                            2.04               2.91                 0.04
# ..                            ...                ...                  ...
# 564                          4.65               2.82                 0.06
# 565                          4.58               2.60                 0.00
# 566                          1.36               4.29                 0.07
# 567                          2.94               4.44                 0.00
# 568                          1.97               2.04                 0.06
#
#      Dribblers_Tackle_W%
# 0                   58.8
# 1                   57.8
# 2                   50.0
# 3                   60.0
# 4                   78.6
# ..                   ...
# 564                 56.0
# 565                 76.0
# 566                 56.0
# 567                 40.0
# 568                 42.0
#
# [569 rows x 131 columns]

# %%
Hakimi=player_2021[player_2021['Player']=='Achraf Hakimi']
Hakimi
# Out:
#      Unnamed: 0         Player  Nation Pos  Squad        Comp   Age    Born  \
# 230      1089.0  Achraf Hakimi  ma MAR  DF  Inter  it Serie A  21.0  1998.0
#
#        MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 230  37.0    29.0  2665  29.6         0.24       0.51        0.24
#
#      G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 230          0.51      0.16          0.37        0.16            0.37
#
#      Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 230                64.0           33.0            51.6              31.0
#
#      Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 230               48.4            62.4                    1.52
#
#      Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 230                   12.36                   22.77                   27.84
#
#      Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 230                    4.63                       62.4
#
#      Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 230                       2.16                  1.11                     1.05
#
#      Carries_per_90  Total_Distance_per_90  \
# 230           33.61                 203.99
#
#      Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 230                               124.36                        3.82
#
#      1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 230                1.96                         1.55                1.93
#
#      Dispossessed_per_90  Passes_Received_per_90  \
# 230                 0.57                    42.5
#
#      Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 230                               10.44                         3.0
#
#      Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 230                     0.64                   2.33                   0.14
#
#      Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 230                  0.14              0.07                      0.3
#
#      Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 230                   0.03                   0.57                    0.0
#
#      Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 230                   0.0               0.0                     0.07
#
#      Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 230                    0.0            1253.0            1539.0
#
#      Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 230               81.4         18000.0          5633.0             738.0
#
#      Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 230             837.0               88.2              380.0
#
#      Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 230              454.0                83.7             69.0            113.0
#
#      Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 230              61.1             0.0        0.21       0.23          0.06
#
#      Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 230               1.22               2.23                        1.59
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 230                         0.64                       3.31
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 230                    51.99                    44.32
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 230                     7.64                     0.41                  0.03
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 230              0.1            3.89                    7.16
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 230                 0.07                     0.0                     0.03
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 230                      0.0              42.33               0.03
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 230                   1.93               1.32                   0.54
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 230            0.18                      0.44           0.12     2.3
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 230       2.3                       36.4                  0.2
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 230               0.0                        0.0                    1.05
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 230                1.22             0.24                  0.74
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 230                1.08                      0.07
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 230                            0.0                    4.19
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 230                0.54                 0.95            1.79
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 230                    0.78                    0.64                    0.37
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 230                      0.78                         1.62
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 230                          0.84           1.05                  0.03
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 230                          2.53               0.78                 0.03
#
#      Dribblers_Tackle_W%
# 230                 47.9

# %%
import pandas as pd





params=['Goals_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90', 'xG_per90', 'xG+xAG_per90', 'npxG_per90',
        'npxG+xAG_per90', 'Take_Ons_Attempted', 'Take_Ons_Succ', 'Take_Ons_Succ%', 'Tackled_Take_Ons', 
        'Tackled_Take_Ons%', 'Touches_per_90', 'Touches_Def_Pen_per_90', 'Touches_Def_3rd_per_90', 
        'Touches_Mid_3rd_per_90', 'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
        'Take_Ons_Attempted_per_90', 'Take_Ons_Succ_per_90', 'Tackled_Take_Ons_per_90', 'Carries_per_90', 
        'Total_Distance_per_90', 'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90', 
        '1/3_Carries_per_90', 'Carries_Penalty_Area_per_90', 'Miscontrols_per_90', 'Dispossessed_per_90', 
        'Passes_Received_per_90', 'Progressive_Passes_Received_per_90', 'Shot_Creating_Action_per90', 
        'Goal_Creating_Action_90', 'Pass_Live_Shot_per_90', 'Pass_Dead_Shot_per_90', 'Take_Ons_Shot_per_90', 
        'Shot-Shot_per_90', 'Fouls_drawn_Shot_per_90', 'Defensive_Shot_per_90', 'Pass_Live_Goal_per_90',
        'Pass_Dead_Goal_per_90', 'Take_Ons_Goal_per_90', 'Shot_Goal_per_90', 'Fouls_Drawn_Goal_per_90', 
        'Defensive_Goal_per_90', 'Passes_Total_Cmp', 'Passes_Total_Att', 'Passes_Total_Cmp%', 'Passes_TotDist', 
        'Passes_PrgDist', 'Passes_Short_Cmp', 'Passes_Short_Att', 'Passes_Short_Cmp%', 'Passes_Medium_Cmp', 
        'Passes_Medium_Att', 'Passes_Medium_Cmp%', 'Passes_Long_Cmp', 'Passes_Long_Att', 'Passes_Long_Cmp%', 
        'Assists_per_90', 'xAG_per_90', 'xA_per_90', 'A-xAG_per_90', 'Key_Passes_per_90', 'Passes_1/3_per_90', 
        'Passes_Penalty_Area_per_90', 'Crosses_Penalty_Area_per_90', 'Progressive_Passes_per_90', 
        'Passes_Attempted_per_90', 'Live_Ball_Passes_per_90', 'Dead_Ball_Passes_per_90', 'Free_Kick_Passes_per_90',
        'Through_Balls_per_90', 'Switches_per_90', 'Crosses_per_90', 'Throw_Ins_Taken_per_90', 
        'Corner_Kicks_per_90', 'In_Corner_Kicks_per_90', 'Out_Corner_Kicks_per_90', 'Str_Corner_Kicks_per_90',
        'Passes_Cmp_per_90', 'Passes_Off_per_90', 'Passes_Blocked_per_90', 'Shots_total_per90', 
        'Shots_on_target_per90', 'Goals_per_shot', 'Goals_per_shot_on_target', 'Npxg_per_shot', 'Xg_net', 
        'Npxg_net', 'Percentage_of_Aerials_Won', 'Yellow_Cards_per_90', 'Red_Cards_per_90', 
        'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90', 'Fouls_Drawn_per_90', 'Offsides_per_90', 
        'Interceptions_per_90', 'Tackles_Won_per_90', 'Penalty_Kicks_Won_per_90', 'Penalty_Kicks_Conceded_per_90',
        'Ball_Recoveries_per_90', 'Aerials_Won_per_90', 'Aerials_Lost_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2021[params].rank(pct=True) * 100

# Get the row of Hakimi's stats from the percentile ranks DataFrame
hakimi_percentile_ranks = round(players_percentile_ranks.iloc[[230]],0)

# Print the percentile ranks for Hakimi
hakimi_percentile_ranks
# Out:
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 230        100.0       99.0       100.0          99.0      99.0          99.0
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 230        99.0            99.0                98.0           95.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 230            24.0              98.0               75.0            44.0
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 230                     1.0                     2.0                    16.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 230                    99.0                   100.0
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 230                       44.0                       94.0
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 230                  91.0                     95.0            45.0
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 230                   67.0                                 76.0
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 230                        98.0                90.0
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 230                        100.0                98.0                 82.0
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 230                    62.0                               100.0
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 230                        97.0                    100.0
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 230                   97.0                   81.0                  92.0
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 230              69.0                     99.0                   69.0
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 230                  100.0                   45.0                  46.0
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 230              42.0                     98.0                   49.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 230              72.0              72.0               47.0            55.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 230            44.0              92.0              93.0               35.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 230               44.0               43.0                36.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 230             35.0             27.0              63.0            49.0
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 230        98.0       99.0          94.0               94.0
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 230               35.0                        96.0
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 230                         91.0                       49.0
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 230                     43.0                     38.0
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 230                     64.0                      9.0                  81.0
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 230             15.0            90.0                    68.0
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 230                 88.0                    46.0                     89.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 230                     50.0               45.0               11.0
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 230                   97.0               98.0                   99.0
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 230            86.0                      72.0           79.0    98.0
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 230      98.0                        5.0                 55.0
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 230              40.0                       45.0                    52.0
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 230                83.0             98.0                   6.0
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 230                69.0                      98.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 230                           27.0                    14.0
#
#      Aerials_Won_per_90  Aerials_Lost_per_90
# 230                 5.0                 22.0

# %%
# Extract the percentile ranks, transpose, and sort them in descending order
hakimi_percentile_ranks_percentile_ranks_sorted = hakimi_percentile_ranks.T.sort_values(by=230, ascending=False)

# Get the top 20 parameters
top_20_params = hakimi_percentile_ranks_percentile_ranks_sorted.index[:30]
top_20_params_values = hakimi_percentile_ranks_percentile_ranks_sorted[230].head(30)

# Display the top 20 parameters and their values
print("Top 20 Parameters:")
print(top_20_params)
print("Values:")
print(top_20_params_values)
# Out:
# Top 20 Parameters:
# Index(['Goals_per90', 'Carries_Penalty_Area_per_90', 'Goal_Creating_Action_90',
#        'Progressive_Passes_Received_per_90', 'Touches_Att_Pen_per_90',
#        'Pass_Live_Goal_per_90', 'G-PK_per90', 'Shots_on_target_per90',
#        'G+A-PK_per90', 'G+A_per90', 'xG_per90', 'xA_per_90', 'npxG_per90',
#        'Fouls_drawn_Shot_per_90', 'Touches_Att_3rd_per_90', 'xG+xAG_per90',
#        'npxG+xAG_per90', 'Shots_total_per90', 'Tackled_Take_Ons',
#        'Take_Ons_Attempted', 'Fouls_Drawn_Goal_per_90', 'Miscontrols_per_90',
#        'Penalty_Kicks_Won_per_90', 'xAG_per_90', 'Xg_net',
#        'Progressive_Carries_per_90', 'Offsides_per_90', 'Npxg_net',
#        'Passes_Blocked_per_90', 'Shot_Creating_Action_per90'],
#       dtype='object')
# Values:
# Goals_per90                           100.0
# Carries_Penalty_Area_per_90           100.0
# Goal_Creating_Action_90               100.0
# Progressive_Passes_Received_per_90    100.0
# Touches_Att_Pen_per_90                100.0
# Pass_Live_Goal_per_90                 100.0
# G-PK_per90                            100.0
# Shots_on_target_per90                  99.0
# G+A-PK_per90                           99.0
# G+A_per90                              99.0
# xG_per90                               99.0
# xA_per_90                              99.0
# npxG_per90                             99.0
# Fouls_drawn_Shot_per_90                99.0
# Touches_Att_3rd_per_90                 99.0
# xG+xAG_per90                           99.0
# npxG+xAG_per90                         99.0
# Shots_total_per90                      98.0
# Tackled_Take_Ons                       98.0
# Take_Ons_Attempted                     98.0
# Fouls_Drawn_Goal_per_90                98.0
# Miscontrols_per_90                     98.0
# Penalty_Kicks_Won_per_90               98.0
# xAG_per_90                             98.0
# Xg_net                                 98.0
# Progressive_Carries_per_90             98.0
# Offsides_per_90                        98.0
# Npxg_net                               98.0
# Passes_Blocked_per_90                  97.0
# Shot_Creating_Action_per90             97.0
# Name: 230, dtype: float64

# %%
import pandas as pd








params=['Goals_per90', 'Carries_Penalty_Area_per_90',  'Goal_Creating_Action_90',
        'Progressive_Passes_Received_per_90','Shots_on_target_per90', 'G+A_per90',
        'xA_per_90','Take_Ons_Attempted', 'Assists_per_90',
        'Progressive_Carries_per_90', 'xG_per90','Shot_Creating_Action_per90', 
        'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90','Progressive_Carries_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2021[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
hakimi_percentile_ranks = round(players_percentile_ranks.iloc[[230]],0)

# Print the percentile ranks for Declan Rice
hakimi_percentile_ranks
# Out:
#      Goals_per90  Carries_Penalty_Area_per_90  Goal_Creating_Action_90  \
# 230        100.0                        100.0                    100.0
#
#      Progressive_Passes_Received_per_90  Shots_on_target_per90  G+A_per90  \
# 230                               100.0                   99.0       99.0
#
#      xA_per_90  Take_Ons_Attempted  Assists_per_90  \
# 230       99.0                98.0            49.0
#
#      Progressive_Carries_per_90  xG_per90  Shot_Creating_Action_per90  \
# 230                        98.0      99.0                        97.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 230                    99.0                   100.0
#
#      Progressive_Carries_per_90
# 230                        98.0

# %%
hakimi_percentile_ranks_list = hakimi_percentile_ranks.values.flatten().tolist()

hakimi_percentile_ranks_list
# Out:
# [100.0,
#  100.0,
#  100.0,
#  100.0,
#  99.0,
#  99.0,
#  99.0,
#  98.0,
#  49.0,
#  98.0,
#  99.0,
#  97.0,
#  99.0,
#  100.0,
#  98.0]

# %%
len(params)
# Out:
# 15

# %%
image_path = "Hakimi.jpg"
fdj_cropped = Image.open(image_path)

# %%
params=['Goals_per90', 'Carries_Penalty_Area_per_90',  'Goal_Creating_Action_90',
        'Progressive_Passes_Received_per_90','Shots_on_target_per90', 'Goals_+_Assists_per90',
        'Expected_Assists_per_90','Take_Ons_Attempted', 'Assists_per_90',
        'Progressive_Carries_per_90', 'xG_per90','Shot_Creating_Action_per90', 
        'Touches_Attempted_Final_Third_per_90', 'Touches_Attempted_Penalty_Box_per_90','Progressive_Carries_per_90']



split_params = [param.replace('_', '\n') for param in params]

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    hakimi_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Achraf Hakimi - FC Internazionale Milano", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Serie A Stats Percentile Rank vs Top-Five Leagues  Defenders | 2020-21 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Hakimi_2021_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
player_2024 = player_2024[player_2024['Player'] != 'Achraf Hakimi']
player_2024
# Out:
#      Unnamed: 0            Player   Nation Pos                     Squad  \
# 0             0        Max Aarons  eng ENG  DF               Bournemouth
# 1             4  Yunis Abdelhamid   ma MAR  DF                     Reims
# 2             9             Abner   br BRA  DF                     Betis
# 3            11       Abdel Abqar   ma MAR  DF                    Alavés
# 4            13  Francesco Acerbi   it ITA  DF                     Inter
# ..          ...               ...      ...  ..                       ...
# 564         107   Sergio Reguilón   es ESP  DF  Manchester Utd+Brentford
# 565         115       Alidu Seidu   gh GHA  DF      Rennes+Clermont Foot
# 566         129        Kevin Vogt   de GER  DF   Hoffenheim+Union Berlin
# 567         133  Mateusz Wieteska   pl POL  DF    Cagliari+Clermont Foot
# 568         138      Nadir Zortea   it ITA  DF        Frosinone+Atalanta
#
#                       Comp  Age    Born  MP  Starts   Min   90s  Goals_per90  \
# 0       eng Premier League  0.0  2000.0  20      13  1237  13.7         0.00
# 1               fr Ligue 1  0.0  1987.0  31      31  2781  30.9         0.13
# 2               es La Liga  0.0  2000.0  23      15  1400  15.6         0.00
# 3               es La Liga  0.0  1999.0  27      27  2312  25.7         0.00
# 4               it Serie A  0.0  1988.0  29      26  2388  26.5         0.11
# ..                     ...  ...     ...  ..     ...   ...   ...          ...
# 564     eng Premier League  0.0  1996.0  25      18  1530  17.0         0.00
# 565             fr Ligue 1  0.0  2000.0  25      20  1724  19.2         0.00
# 566          de Bundesliga  0.0  1991.0  32      30  2642  29.4         0.00
# 567  it Serie A+fr Ligue 1  0.0  1997.0  21      12  1139  12.6         0.08
# 568             it Serie A  0.0  1999.0  19      14  1407  15.7         0.13
#
#      G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 0         0.07        0.00          0.07      0.00          0.06        0.00
# 1         0.13        0.10          0.10      0.11          0.12        0.09
# 2         0.06        0.00          0.06      0.01          0.07        0.01
# 3         0.00        0.00          0.00      0.02          0.02        0.02
# 4         0.15        0.11          0.15      0.06          0.13        0.06
# ..         ...         ...           ...       ...           ...         ...
# 564       0.24        0.00          0.24      0.06          0.27        0.06
# 565       0.05        0.00          0.05      0.02          0.09        0.02
# 566       0.00        0.00          0.00      0.02          0.05        0.02
# 567       0.16        0.08          0.16      0.03          0.03        0.03
# 568       0.45        0.13          0.45      0.03          0.19        0.03
#
#      npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 0              0.06                34.0           14.0            41.2
# 1              0.09                15.0            8.0            53.3
# 2              0.07                13.0            7.0            53.8
# 3              0.02                 5.0            3.0            60.0
# 4              0.13                 3.0            2.0            66.7
# ..              ...                 ...            ...             ...
# 564            0.27                37.0           16.0            43.0
# 565            0.09                36.0           17.0            47.0
# 566            0.05                 7.0            6.0            86.0
# 567            0.03                 6.0            3.0            50.0
# 568            0.19                52.0           22.0            42.0
#
#      Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 0                12.0               35.3           51.90
# 1                 7.0               46.7           70.71
# 2                 5.0               38.5           61.92
# 3                 1.0               20.0           40.16
# 4                 1.0               33.3           74.60
# ..                ...                ...             ...
# 564              15.0               41.0           63.88
# 565              15.0               42.0           70.00
# 566               1.0               14.0           65.44
# 567               3.0               50.0           55.56
# 568              25.0               48.0           53.69
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 0                      3.14                   18.39                   22.12
# 1                      9.48                   31.59                   36.21
# 2                      4.62                   22.05                   25.96
# 3                      7.43                   22.18                   16.42
# 4                      8.26                   35.51                   35.70
# ..                      ...                     ...                     ...
# 564                    3.71                   18.35                   24.00
# 565                    4.74                   25.68                   36.61
# 566                    8.57                   34.18                   29.59
# 567                    7.22                   28.89                   24.92
# 568                    2.04                   11.46                   22.10
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                     12.04                    0.80
# 1                      3.69                    1.13
# 2                     14.49                    1.79
# 3                      1.63                    0.82
# 4                      3.70                    0.94
# ..                      ...                     ...
# 564                   22.53                    1.82
# 565                    8.54                    0.16
# 566                    1.87                    0.27
# 567                    2.22                    0.79
# 568                   20.57                    1.66
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                        51.90                       2.48
# 1                        70.68                       0.49
# 2                        61.92                       0.83
# 3                        40.16                       0.19
# 4                        74.60                       0.11
# ..                         ...                        ...
# 564                      63.88                       2.18
# 565                      70.00                       1.88
# 566                      65.44                       0.24
# 567                      55.56                       0.48
# 568                      53.69                       3.31
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                    1.02                     0.88           26.57
# 1                    0.26                     0.23           48.74
# 2                    0.45                     0.32           28.65
# 3                    0.12                     0.04           19.14
# 4                    0.08                     0.04           45.70
# ..                    ...                      ...             ...
# 564                  0.94                     0.88           29.53
# 565                  0.89                     0.78           48.85
# 566                  0.20                     0.03           36.05
# 567                  0.24                     0.24           30.79
# 568                  1.40                     1.59           26.11
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                   158.69                                81.82
# 1                   280.36                               159.26
# 2                   115.51                                60.83
# 3                    95.72                                55.18
# 4                   218.08                               116.26
# ..                     ...                                  ...
# 564                 166.76                                94.18
# 565                 313.07                               139.22
# 566                 192.41                               111.19
# 567                 177.78                               114.60
# 568                 148.09                                70.64
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 0                          1.61                0.88
# 1                          1.17                0.61
# 2                          0.90                0.64
# 3                          0.27                0.23
# 4                          0.79                0.42
# ..                          ...                 ...
# 564                        2.65                1.71
# 565                        1.56                1.72
# 566                        0.58                0.24
# 567                        1.27                0.16
# 568                        2.42                1.72
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 0                           0.51                0.95                 0.58
# 1                           0.00                0.74                 0.13
# 2                           0.32                1.15                 0.71
# 3                           0.00                0.58                 0.04
# 4                           0.00                0.15                 0.04
# ..                           ...                 ...                  ...
# 564                         0.24                1.76                 0.35
# 565                         0.05                1.25                 0.47
# 566                         0.00                0.44                 0.07
# 567                         0.00                0.40                 0.24
# 568                         0.38                2.04                 1.08
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 0                     27.08                                1.90
# 1                     45.40                                0.29
# 2                     32.18                                3.72
# 3                     19.42                                0.04
# 4                     54.57                                0.91
# ..                      ...                                 ...
# 564                   32.29                                4.59
# 565                   43.07                                1.41
# 566                   42.79                                0.44
# 567                   33.81                                0.16
# 568                   30.51                                5.92
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 0                          1.68                     0.15
# 1                          0.78                     0.03
# 2                          0.90                     0.00
# 3                          0.47                     0.00
# 4                          0.83                     0.04
# ..                          ...                      ...
# 564                        2.94                     0.41
# 565                        1.09                     0.05
# 566                        1.12                     0.17
# 567                        0.79                     0.08
# 568                        3.25                     0.57
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 0                     1.17                   0.29                  0.00
# 1                     0.61                   0.03                  0.00
# 2                     0.83                   0.00                  0.00
# 3                     0.35                   0.00                  0.00
# 4                     0.72                   0.00                  0.00
# ..                     ...                    ...                   ...
# 564                   1.94                   0.71                  0.06
# 565                   0.73                   0.10                  0.05
# 566                   1.12                   0.00                  0.00
# 567                   0.71                   0.00                  0.00
# 568                   2.36                   0.38                  0.19
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 0                0.00                     0.22                   0.00
# 1                0.10                     0.03                   0.00
# 2                0.06                     0.00                   0.00
# 3                0.08                     0.04                   0.00
# 4                0.11                     0.00                   0.00
# ..                ...                      ...                    ...
# 564              0.18                     0.06                   0.00
# 565              0.00                     0.16                   0.05
# 566              0.00                     0.00                   0.00
# 567              0.00                     0.00                   0.08
# 568              0.19                     0.06                   0.06
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 0                     0.15                   0.00                  0.00
# 1                     0.00                   0.00                  0.00
# 2                     0.00                   0.00                  0.00
# 3                     0.00                   0.00                  0.00
# 4                     0.04                   0.00                  0.00
# ..                     ...                    ...                   ...
# 564                   0.18                   0.12                  0.00
# 565                   0.05                   0.00                  0.00
# 566                   0.17                   0.00                  0.00
# 567                   0.08                   0.00                  0.00
# 568                   0.51                   0.00                  0.06
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 0                0.00                      0.0                    0.0
# 1                0.03                      0.0                    0.0
# 2                0.00                      0.0                    0.0
# 3                0.00                      0.0                    0.0
# 4                0.00                      0.0                    0.0
# ..                ...                      ...                    ...
# 564              0.12                      0.0                    0.0
# 565              0.00                      0.0                    0.0
# 566              0.00                      0.0                    0.0
# 567              0.00                      0.0                    0.0
# 568              0.00                      0.0                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 0               450.0             581.0               77.5          7402.0
# 1              1552.0            1836.0               84.5         29618.0
# 2               615.0             797.0               77.2          9211.0
# 3               553.0             762.0               72.6         12370.0
# 4              1615.0            1781.0               90.7         29326.0
# ..                ...               ...                ...             ...
# 564             595.0             836.0               71.0          9726.0
# 565             932.0            1118.0               83.0         16513.0
# 566            1465.0            1674.0               88.0         32160.0
# 567             463.0             576.0               80.0          9154.0
# 568             487.0             664.0               73.0          7876.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 0            2789.0             220.0             248.0               88.7
# 1            9672.0             487.0             548.0               88.9
# 2            4552.0             351.0             394.0               89.1
# 3            4872.0             141.0             164.0               86.0
# 4            9174.0             601.0             650.0               92.5
# ..              ...               ...               ...                ...
# 564          3982.0             298.0             351.0               85.0
# 565          4733.0             397.0             433.0               92.0
# 566         13483.0             360.0             381.0               94.0
# 567          4116.0             144.0             164.0               88.0
# 568          3172.0             262.0             303.0               86.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 0                188.0              235.0                80.0
# 1                893.0              976.0                91.5
# 2                203.0              265.0                76.6
# 3                302.0              339.0                89.1
# 4                856.0              908.0                94.3
# ..                 ...                ...                 ...
# 564              231.0              312.0                74.0
# 565              428.0              502.0                85.0
# 566              805.0              875.0                92.0
# 567              270.0              301.0                90.0
# 568              166.0              219.0                76.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 0               34.0             63.0              54.0            0.07
# 1              141.0            252.0              56.0            0.00
# 2               37.0             79.0              46.8            0.06
# 3               99.0            225.0              44.0            0.00
# 4              132.0            179.0              73.7            0.04
# ..               ...              ...               ...             ...
# 564             50.0            108.0              46.0            0.24
# 565             79.0            142.0              56.0            0.05
# 566            277.0            381.0              73.0            0.00
# 567             46.0             99.0              46.0            0.08
# 568             45.0             88.0              51.0            0.32
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 0          0.06       0.07          0.01               0.51
# 1          0.01       0.02         -0.01               0.26
# 2          0.06       0.06          0.00               0.51
# 3          0.01       0.01         -0.01               0.12
# 4          0.07       0.05         -0.03               0.26
# ..          ...        ...           ...                ...
# 564        0.21       0.16          0.03               1.65
# 565        0.04       0.02          0.01               0.42
# 566        0.00       0.02         -0.00               0.10
# 567        0.05       0.02          0.03               0.40
# 568        0.20       0.15          0.12               1.53
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 0                 1.82                        0.95
# 1                 4.17                        0.10
# 2                 1.28                        0.45
# 3                 2.37                        0.08
# 4                 2.19                        0.19
# ..                 ...                         ...
# 564               2.18                        1.24
# 565               3.12                        0.21
# 566               3.74                        0.44
# 567               3.10                        0.40
# 568               1.85                        1.85
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 0                           0.15                       3.14
# 1                           0.00                       4.43
# 2                           0.13                       2.12
# 3                           0.00                       1.91
# 4                           0.08                       3.28
# ..                           ...                        ...
# 564                         0.88                       3.82
# 565                         0.00                       2.92
# 566                         0.00                       4.25
# 567                         0.08                       3.10
# 568                         1.27                       3.31
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 0                      42.41                    33.07
# 1                      59.42                    53.40
# 2                      51.09                    40.26
# 3                      29.65                    27.39
# 4                      67.21                    64.87
# ..                       ...                      ...
# 564                    49.18                    40.00
# 565                    58.23                    52.34
# 566                    56.94                    53.88
# 567                    45.71                    42.78
# 568                    42.29                    32.48
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 0                       9.27                     0.80                  0.15
# 1                       5.76                     2.43                  0.06
# 2                      10.58                     0.45                  0.00
# 3                       2.14                     1.95                  0.00
# 4                       2.26                     1.62                  0.00
# ..                       ...                      ...                   ...
# 564                     8.88                     2.00                  0.06
# 565                     5.62                     0.83                  0.00
# 566                     2.96                     2.18                  0.03
# 567                     2.94                     1.35                  0.08
# 568                     9.75                     0.45                  0.00
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 0               0.22            0.95                    8.47
# 1               0.42            0.10                    0.94
# 2               0.19            1.67                   10.13
# 3               0.66            0.08                    0.16
# 4               0.42            0.34                    0.30
# ..               ...             ...                     ...
# 564             0.12            5.94                    4.94
# 565             0.16            0.52                    4.79
# 566             0.41            0.10                    0.44
# 567             0.08            0.32                    1.51
# 568             0.00            5.48                    8.15
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 0                   0.00                    0.00                     0.00
# 1                   0.00                    0.00                     0.00
# 2                   0.00                    0.00                     0.00
# 3                   0.00                    0.00                     0.00
# 4                   0.00                    0.00                     0.00
# ..                   ...                     ...                      ...
# 564                 1.94                    0.53                     0.88
# 565                 0.00                    0.00                     0.00
# 566                 0.00                    0.00                     0.00
# 567                 0.00                    0.00                     0.00
# 568                 1.15                    0.00                     0.89
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 0                       0.00              32.85               0.07
# 1                       0.00              50.23               0.26
# 2                       0.00              39.42               0.26
# 3                       0.00              21.52               0.12
# 4                       0.00              60.94               0.08
# ..                       ...                ...                ...
# 564                     0.00              35.00               0.29
# 565                     0.00              48.54               0.26
# 566                     0.00              49.83               0.10
# 567                     0.00              36.75               0.00
# 568                     0.06              31.02               0.06
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 0                     1.68               0.15                   0.00
# 1                     0.65               0.68                   0.23
# 2                     1.47               0.26                   0.00
# 3                     0.39               0.39                   0.12
# 4                     0.19               0.57                   0.23
# ..                     ...                ...                    ...
# 564                   1.53               1.00                   0.06
# 565                   0.52               0.42                   0.05
# 566                   0.24               0.10                   0.03
# 567                   0.79               0.56                   0.16
# 568                   1.91               0.76                   0.32
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 0              0.00                      0.00           0.02     0.0
# 1              0.14                      0.43           0.13     0.6
# 2              0.00                      0.00           0.03    -0.1
# 3              0.00                      0.00           0.05    -0.5
# 4              0.20                      0.50           0.11     1.4
# ..              ...                       ...            ...     ...
# 564            0.00                      0.00           0.06    -1.0
# 565            0.00                      0.00           0.04    -0.3
# 566            0.00                      0.00           0.23    -0.7
# 567            0.14                      0.50           0.06     0.6
# 568            0.17                      0.40           0.04     1.5
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 0         0.0                       31.3                 0.07
# 1         0.4                       62.2                 0.16
# 2        -0.1                       58.3                 0.19
# 3        -0.5                       52.0                 0.39
# 4         1.4                       65.4                 0.04
# ..        ...                        ...                  ...
# 564      -1.0                       40.0                 0.41
# 565      -0.3                       63.0                 0.42
# 566      -0.7                       58.0                 0.24
# 567       0.6                       61.0                 0.40
# 568       1.5                       32.0                 0.25
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 0                0.00                       0.00                    0.88
# 1                0.00                       0.00                    0.84
# 2                0.00                       0.00                    1.03
# 3                0.00                       0.00                    1.28
# 4                0.00                       0.00                    0.72
# ..                ...                        ...                     ...
# 564              0.06                       0.00                    0.82
# 565              0.05                       0.00                    1.46
# 566              0.00                       0.00                    0.95
# 567              0.08                       0.08                    0.95
# 568              0.00                       0.00                    1.21
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 0                  1.90             0.15                  0.58
# 1                  0.39             0.00                  1.26
# 2                  0.13             0.13                  0.96
# 3                  0.89             0.04                  0.89
# 4                  0.91             0.11                  1.21
# ..                  ...              ...                   ...
# 564                1.53             0.24                  1.24
# 565                2.24             0.05                  1.82
# 566                0.58             0.03                  0.54
# 567                0.63             0.08                  1.51
# 568                1.02             0.00                  0.32
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 0                  1.39                       0.0
# 1                  1.13                       0.0
# 2                  1.22                       0.0
# 3                  0.74                       0.0
# 4                  0.49                       0.0
# ..                  ...                       ...
# 564                1.65                       0.0
# 565                1.72                       0.0
# 566                0.65                       0.0
# 567                0.95                       0.0
# 568                1.15                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                             0.07                    5.47
# 1                             0.00                    4.82
# 2                             0.06                    5.06
# 3                             0.08                    4.24
# 4                             0.00                    3.85
# ..                             ...                     ...
# 564                           0.06                    5.65
# 565                           0.05                    7.29
# 566                           0.00                    5.88
# 567                           0.00                    4.68
# 568                           0.00                    3.63
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 0                  0.36                 0.80            2.12
# 1                  1.97                 1.20            2.07
# 2                  0.90                 0.64            1.60
# 3                  1.52                 1.40            1.36
# 4                  2.64                 1.40            0.83
# ..                  ...                  ...             ...
# 564                1.12                 1.71            3.41
# 565                1.15                 0.68            2.76
# 566                0.75                 0.54            0.82
# 567                2.46                 1.59            1.43
# 568                0.70                 1.46            1.66
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 0                      1.46                    0.51                    0.15
# 1                      1.17                    0.74                    0.16
# 2                      0.96                    0.58                    0.06
# 3                      1.09                    0.19                    0.08
# 4                      0.60                    0.23                    0.00
# ..                      ...                     ...                     ...
# 564                    1.88                    1.18                    0.35
# 565                    1.77                    0.94                    0.05
# 566                    0.44                    0.37                    0.00
# 567                    0.95                    0.32                    0.16
# 568                    0.70                    0.89                    0.06
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 0                        1.46                         2.48
# 1                        0.84                         1.46
# 2                        1.09                         2.18
# 3                        0.82                         1.36
# 4                        0.42                         0.53
# ..                        ...                          ...
# 564                      1.88                         3.35
# 565                      1.98                         2.60
# 566                      0.48                         0.85
# 567                      0.48                         1.19
# 568                      0.70                         1.66
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 0                            1.02           0.66                  0.36
# 1                            0.61           1.65                  1.04
# 2                            1.09           1.47                  0.32
# 3                            0.54           1.21                  1.01
# 4                            0.11           0.75                  0.49
# ..                            ...            ...                   ...
# 564                          1.47           1.94                  0.35
# 565                          0.62           1.35                  0.52
# 566                          0.37           1.29                  0.95
# 567                          0.71           1.11                  0.56
# 568                          0.96           0.96                  0.32
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                            2.70               1.97                 0.00
# 1                            3.33               3.53                 0.06
# 2                            2.56               3.97                 0.00
# 3                            2.26               4.47                 0.00
# 4                            2.04               2.91                 0.04
# ..                            ...                ...                  ...
# 564                          4.65               2.82                 0.06
# 565                          4.58               2.60                 0.00
# 566                          1.36               4.29                 0.07
# 567                          2.94               4.44                 0.00
# 568                          1.97               2.04                 0.06
#
#      Dribblers_Tackle_W%
# 0                   58.8
# 1                   57.8
# 2                   50.0
# 3                   60.0
# 4                   78.6
# ..                   ...
# 564                 56.0
# 565                 76.0
# 566                 56.0
# 567                 40.0
# 568                 42.0
#
# [568 rows x 131 columns]

# %%
player_2024=pd.concat([player_2024,Hakimi])
player_2024=player_2024.reset_index(drop=True)
player_2024
# Out:
#      Unnamed: 0            Player   Nation Pos                    Squad  \
# 0           0.0        Max Aarons  eng ENG  DF              Bournemouth
# 1           4.0  Yunis Abdelhamid   ma MAR  DF                    Reims
# 2           9.0             Abner   br BRA  DF                    Betis
# 3          11.0       Abdel Abqar   ma MAR  DF                   Alavés
# 4          13.0  Francesco Acerbi   it ITA  DF                    Inter
# ..          ...               ...      ...  ..                      ...
# 564       115.0       Alidu Seidu   gh GHA  DF     Rennes+Clermont Foot
# 565       129.0        Kevin Vogt   de GER  DF  Hoffenheim+Union Berlin
# 566       133.0  Mateusz Wieteska   pl POL  DF   Cagliari+Clermont Foot
# 567       138.0      Nadir Zortea   it ITA  DF       Frosinone+Atalanta
# 568      1089.0     Achraf Hakimi   ma MAR  DF                    Inter
#
#                       Comp   Age    Born    MP  Starts   Min   90s  \
# 0       eng Premier League   0.0  2000.0  20.0    13.0  1237  13.7
# 1               fr Ligue 1   0.0  1987.0  31.0    31.0  2781  30.9
# 2               es La Liga   0.0  2000.0  23.0    15.0  1400  15.6
# 3               es La Liga   0.0  1999.0  27.0    27.0  2312  25.7
# 4               it Serie A   0.0  1988.0  29.0    26.0  2388  26.5
# ..                     ...   ...     ...   ...     ...   ...   ...
# 564             fr Ligue 1   0.0  2000.0  25.0    20.0  1724  19.2
# 565          de Bundesliga   0.0  1991.0  32.0    30.0  2642  29.4
# 566  it Serie A+fr Ligue 1   0.0  1997.0  21.0    12.0  1139  12.6
# 567             it Serie A   0.0  1999.0  19.0    14.0  1407  15.7
# 568             it Serie A  21.0  1998.0  37.0    29.0  2665  29.6
#
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 0           0.00       0.07        0.00          0.07      0.00          0.06
# 1           0.13       0.13        0.10          0.10      0.11          0.12
# 2           0.00       0.06        0.00          0.06      0.01          0.07
# 3           0.00       0.00        0.00          0.00      0.02          0.02
# 4           0.11       0.15        0.11          0.15      0.06          0.13
# ..           ...        ...         ...           ...       ...           ...
# 564         0.00       0.05        0.00          0.05      0.02          0.09
# 565         0.00       0.00        0.00          0.00      0.02          0.05
# 566         0.08       0.16        0.08          0.16      0.03          0.03
# 567         0.13       0.45        0.13          0.45      0.03          0.19
# 568         0.24       0.51        0.24          0.51      0.16          0.37
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 0          0.00            0.06                34.0           14.0
# 1          0.09            0.09                15.0            8.0
# 2          0.01            0.07                13.0            7.0
# 3          0.02            0.02                 5.0            3.0
# 4          0.06            0.13                 3.0            2.0
# ..          ...             ...                 ...            ...
# 564        0.02            0.09                36.0           17.0
# 565        0.02            0.05                 7.0            6.0
# 566        0.03            0.03                 6.0            3.0
# 567        0.03            0.19                52.0           22.0
# 568        0.16            0.37                64.0           33.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 0              41.2              12.0               35.3           51.90
# 1              53.3               7.0               46.7           70.71
# 2              53.8               5.0               38.5           61.92
# 3              60.0               1.0               20.0           40.16
# 4              66.7               1.0               33.3           74.60
# ..              ...               ...                ...             ...
# 564            47.0              15.0               42.0           70.00
# 565            86.0               1.0               14.0           65.44
# 566            50.0               3.0               50.0           55.56
# 567            42.0              25.0               48.0           53.69
# 568            51.6              31.0               48.4           62.40
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 0                      3.14                   18.39                   22.12
# 1                      9.48                   31.59                   36.21
# 2                      4.62                   22.05                   25.96
# 3                      7.43                   22.18                   16.42
# 4                      8.26                   35.51                   35.70
# ..                      ...                     ...                     ...
# 564                    4.74                   25.68                   36.61
# 565                    8.57                   34.18                   29.59
# 566                    7.22                   28.89                   24.92
# 567                    2.04                   11.46                   22.10
# 568                    1.52                   12.36                   22.77
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                     12.04                    0.80
# 1                      3.69                    1.13
# 2                     14.49                    1.79
# 3                      1.63                    0.82
# 4                      3.70                    0.94
# ..                      ...                     ...
# 564                    8.54                    0.16
# 565                    1.87                    0.27
# 566                    2.22                    0.79
# 567                   20.57                    1.66
# 568                   27.84                    4.63
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                        51.90                       2.48
# 1                        70.68                       0.49
# 2                        61.92                       0.83
# 3                        40.16                       0.19
# 4                        74.60                       0.11
# ..                         ...                        ...
# 564                      70.00                       1.88
# 565                      65.44                       0.24
# 566                      55.56                       0.48
# 567                      53.69                       3.31
# 568                      62.40                       2.16
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                    1.02                     0.88           26.57
# 1                    0.26                     0.23           48.74
# 2                    0.45                     0.32           28.65
# 3                    0.12                     0.04           19.14
# 4                    0.08                     0.04           45.70
# ..                    ...                      ...             ...
# 564                  0.89                     0.78           48.85
# 565                  0.20                     0.03           36.05
# 566                  0.24                     0.24           30.79
# 567                  1.40                     1.59           26.11
# 568                  1.11                     1.05           33.61
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                   158.69                                81.82
# 1                   280.36                               159.26
# 2                   115.51                                60.83
# 3                    95.72                                55.18
# 4                   218.08                               116.26
# ..                     ...                                  ...
# 564                 313.07                               139.22
# 565                 192.41                               111.19
# 566                 177.78                               114.60
# 567                 148.09                                70.64
# 568                 203.99                               124.36
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 0                          1.61                0.88
# 1                          1.17                0.61
# 2                          0.90                0.64
# 3                          0.27                0.23
# 4                          0.79                0.42
# ..                          ...                 ...
# 564                        1.56                1.72
# 565                        0.58                0.24
# 566                        1.27                0.16
# 567                        2.42                1.72
# 568                        3.82                1.96
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 0                           0.51                0.95                 0.58
# 1                           0.00                0.74                 0.13
# 2                           0.32                1.15                 0.71
# 3                           0.00                0.58                 0.04
# 4                           0.00                0.15                 0.04
# ..                           ...                 ...                  ...
# 564                         0.05                1.25                 0.47
# 565                         0.00                0.44                 0.07
# 566                         0.00                0.40                 0.24
# 567                         0.38                2.04                 1.08
# 568                         1.55                1.93                 0.57
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 0                     27.08                                1.90
# 1                     45.40                                0.29
# 2                     32.18                                3.72
# 3                     19.42                                0.04
# 4                     54.57                                0.91
# ..                      ...                                 ...
# 564                   43.07                                1.41
# 565                   42.79                                0.44
# 566                   33.81                                0.16
# 567                   30.51                                5.92
# 568                   42.50                               10.44
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 0                          1.68                     0.15
# 1                          0.78                     0.03
# 2                          0.90                     0.00
# 3                          0.47                     0.00
# 4                          0.83                     0.04
# ..                          ...                      ...
# 564                        1.09                     0.05
# 565                        1.12                     0.17
# 566                        0.79                     0.08
# 567                        3.25                     0.57
# 568                        3.00                     0.64
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 0                     1.17                   0.29                  0.00
# 1                     0.61                   0.03                  0.00
# 2                     0.83                   0.00                  0.00
# 3                     0.35                   0.00                  0.00
# 4                     0.72                   0.00                  0.00
# ..                     ...                    ...                   ...
# 564                   0.73                   0.10                  0.05
# 565                   1.12                   0.00                  0.00
# 566                   0.71                   0.00                  0.00
# 567                   2.36                   0.38                  0.19
# 568                   2.33                   0.14                  0.14
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 0                0.00                     0.22                   0.00
# 1                0.10                     0.03                   0.00
# 2                0.06                     0.00                   0.00
# 3                0.08                     0.04                   0.00
# 4                0.11                     0.00                   0.00
# ..                ...                      ...                    ...
# 564              0.00                     0.16                   0.05
# 565              0.00                     0.00                   0.00
# 566              0.00                     0.00                   0.08
# 567              0.19                     0.06                   0.06
# 568              0.07                     0.30                   0.03
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 0                     0.15                    0.0                  0.00
# 1                     0.00                    0.0                  0.00
# 2                     0.00                    0.0                  0.00
# 3                     0.00                    0.0                  0.00
# 4                     0.04                    0.0                  0.00
# ..                     ...                    ...                   ...
# 564                   0.05                    0.0                  0.00
# 565                   0.17                    0.0                  0.00
# 566                   0.08                    0.0                  0.00
# 567                   0.51                    0.0                  0.06
# 568                   0.57                    0.0                  0.00
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 0                0.00                     0.00                    0.0
# 1                0.03                     0.00                    0.0
# 2                0.00                     0.00                    0.0
# 3                0.00                     0.00                    0.0
# 4                0.00                     0.00                    0.0
# ..                ...                      ...                    ...
# 564              0.00                     0.00                    0.0
# 565              0.00                     0.00                    0.0
# 566              0.00                     0.00                    0.0
# 567              0.00                     0.00                    0.0
# 568              0.00                     0.07                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 0               450.0             581.0               77.5          7402.0
# 1              1552.0            1836.0               84.5         29618.0
# 2               615.0             797.0               77.2          9211.0
# 3               553.0             762.0               72.6         12370.0
# 4              1615.0            1781.0               90.7         29326.0
# ..                ...               ...                ...             ...
# 564             932.0            1118.0               83.0         16513.0
# 565            1465.0            1674.0               88.0         32160.0
# 566             463.0             576.0               80.0          9154.0
# 567             487.0             664.0               73.0          7876.0
# 568            1253.0            1539.0               81.4         18000.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 0            2789.0             220.0             248.0               88.7
# 1            9672.0             487.0             548.0               88.9
# 2            4552.0             351.0             394.0               89.1
# 3            4872.0             141.0             164.0               86.0
# 4            9174.0             601.0             650.0               92.5
# ..              ...               ...               ...                ...
# 564          4733.0             397.0             433.0               92.0
# 565         13483.0             360.0             381.0               94.0
# 566          4116.0             144.0             164.0               88.0
# 567          3172.0             262.0             303.0               86.0
# 568          5633.0             738.0             837.0               88.2
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 0                188.0              235.0                80.0
# 1                893.0              976.0                91.5
# 2                203.0              265.0                76.6
# 3                302.0              339.0                89.1
# 4                856.0              908.0                94.3
# ..                 ...                ...                 ...
# 564              428.0              502.0                85.0
# 565              805.0              875.0                92.0
# 566              270.0              301.0                90.0
# 567              166.0              219.0                76.0
# 568              380.0              454.0                83.7
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 0               34.0             63.0              54.0            0.07
# 1              141.0            252.0              56.0            0.00
# 2               37.0             79.0              46.8            0.06
# 3               99.0            225.0              44.0            0.00
# 4              132.0            179.0              73.7            0.04
# ..               ...              ...               ...             ...
# 564             79.0            142.0              56.0            0.05
# 565            277.0            381.0              73.0            0.00
# 566             46.0             99.0              46.0            0.08
# 567             45.0             88.0              51.0            0.32
# 568             69.0            113.0              61.1            0.00
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 0          0.06       0.07          0.01               0.51
# 1          0.01       0.02         -0.01               0.26
# 2          0.06       0.06          0.00               0.51
# 3          0.01       0.01         -0.01               0.12
# 4          0.07       0.05         -0.03               0.26
# ..          ...        ...           ...                ...
# 564        0.04       0.02          0.01               0.42
# 565        0.00       0.02         -0.00               0.10
# 566        0.05       0.02          0.03               0.40
# 567        0.20       0.15          0.12               1.53
# 568        0.21       0.23          0.06               1.22
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 0                 1.82                        0.95
# 1                 4.17                        0.10
# 2                 1.28                        0.45
# 3                 2.37                        0.08
# 4                 2.19                        0.19
# ..                 ...                         ...
# 564               3.12                        0.21
# 565               3.74                        0.44
# 566               3.10                        0.40
# 567               1.85                        1.85
# 568               2.23                        1.59
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 0                           0.15                       3.14
# 1                           0.00                       4.43
# 2                           0.13                       2.12
# 3                           0.00                       1.91
# 4                           0.08                       3.28
# ..                           ...                        ...
# 564                         0.00                       2.92
# 565                         0.00                       4.25
# 566                         0.08                       3.10
# 567                         1.27                       3.31
# 568                         0.64                       3.31
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 0                      42.41                    33.07
# 1                      59.42                    53.40
# 2                      51.09                    40.26
# 3                      29.65                    27.39
# 4                      67.21                    64.87
# ..                       ...                      ...
# 564                    58.23                    52.34
# 565                    56.94                    53.88
# 566                    45.71                    42.78
# 567                    42.29                    32.48
# 568                    51.99                    44.32
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 0                       9.27                     0.80                  0.15
# 1                       5.76                     2.43                  0.06
# 2                      10.58                     0.45                  0.00
# 3                       2.14                     1.95                  0.00
# 4                       2.26                     1.62                  0.00
# ..                       ...                      ...                   ...
# 564                     5.62                     0.83                  0.00
# 565                     2.96                     2.18                  0.03
# 566                     2.94                     1.35                  0.08
# 567                     9.75                     0.45                  0.00
# 568                     7.64                     0.41                  0.03
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 0               0.22            0.95                    8.47
# 1               0.42            0.10                    0.94
# 2               0.19            1.67                   10.13
# 3               0.66            0.08                    0.16
# 4               0.42            0.34                    0.30
# ..               ...             ...                     ...
# 564             0.16            0.52                    4.79
# 565             0.41            0.10                    0.44
# 566             0.08            0.32                    1.51
# 567             0.00            5.48                    8.15
# 568             0.10            3.89                    7.16
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 0                   0.00                     0.0                     0.00
# 1                   0.00                     0.0                     0.00
# 2                   0.00                     0.0                     0.00
# 3                   0.00                     0.0                     0.00
# 4                   0.00                     0.0                     0.00
# ..                   ...                     ...                      ...
# 564                 0.00                     0.0                     0.00
# 565                 0.00                     0.0                     0.00
# 566                 0.00                     0.0                     0.00
# 567                 1.15                     0.0                     0.89
# 568                 0.07                     0.0                     0.03
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 0                       0.00              32.85               0.07
# 1                       0.00              50.23               0.26
# 2                       0.00              39.42               0.26
# 3                       0.00              21.52               0.12
# 4                       0.00              60.94               0.08
# ..                       ...                ...                ...
# 564                     0.00              48.54               0.26
# 565                     0.00              49.83               0.10
# 566                     0.00              36.75               0.00
# 567                     0.06              31.02               0.06
# 568                     0.00              42.33               0.03
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 0                     1.68               0.15                   0.00
# 1                     0.65               0.68                   0.23
# 2                     1.47               0.26                   0.00
# 3                     0.39               0.39                   0.12
# 4                     0.19               0.57                   0.23
# ..                     ...                ...                    ...
# 564                   0.52               0.42                   0.05
# 565                   0.24               0.10                   0.03
# 566                   0.79               0.56                   0.16
# 567                   1.91               0.76                   0.32
# 568                   1.93               1.32                   0.54
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 0              0.00                      0.00           0.02     0.0
# 1              0.14                      0.43           0.13     0.6
# 2              0.00                      0.00           0.03    -0.1
# 3              0.00                      0.00           0.05    -0.5
# 4              0.20                      0.50           0.11     1.4
# ..              ...                       ...            ...     ...
# 564            0.00                      0.00           0.04    -0.3
# 565            0.00                      0.00           0.23    -0.7
# 566            0.14                      0.50           0.06     0.6
# 567            0.17                      0.40           0.04     1.5
# 568            0.18                      0.44           0.12     2.3
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 0         0.0                       31.3                 0.07
# 1         0.4                       62.2                 0.16
# 2        -0.1                       58.3                 0.19
# 3        -0.5                       52.0                 0.39
# 4         1.4                       65.4                 0.04
# ..        ...                        ...                  ...
# 564      -0.3                       63.0                 0.42
# 565      -0.7                       58.0                 0.24
# 566       0.6                       61.0                 0.40
# 567       1.5                       32.0                 0.25
# 568       2.3                       36.4                 0.20
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 0                0.00                       0.00                    0.88
# 1                0.00                       0.00                    0.84
# 2                0.00                       0.00                    1.03
# 3                0.00                       0.00                    1.28
# 4                0.00                       0.00                    0.72
# ..                ...                        ...                     ...
# 564              0.05                       0.00                    1.46
# 565              0.00                       0.00                    0.95
# 566              0.08                       0.08                    0.95
# 567              0.00                       0.00                    1.21
# 568              0.00                       0.00                    1.05
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 0                  1.90             0.15                  0.58
# 1                  0.39             0.00                  1.26
# 2                  0.13             0.13                  0.96
# 3                  0.89             0.04                  0.89
# 4                  0.91             0.11                  1.21
# ..                  ...              ...                   ...
# 564                2.24             0.05                  1.82
# 565                0.58             0.03                  0.54
# 566                0.63             0.08                  1.51
# 567                1.02             0.00                  0.32
# 568                1.22             0.24                  0.74
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 0                  1.39                      0.00
# 1                  1.13                      0.00
# 2                  1.22                      0.00
# 3                  0.74                      0.00
# 4                  0.49                      0.00
# ..                  ...                       ...
# 564                1.72                      0.00
# 565                0.65                      0.00
# 566                0.95                      0.00
# 567                1.15                      0.00
# 568                1.08                      0.07
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                             0.07                    5.47
# 1                             0.00                    4.82
# 2                             0.06                    5.06
# 3                             0.08                    4.24
# 4                             0.00                    3.85
# ..                             ...                     ...
# 564                           0.05                    7.29
# 565                           0.00                    5.88
# 566                           0.00                    4.68
# 567                           0.00                    3.63
# 568                           0.00                    4.19
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 0                  0.36                 0.80            2.12
# 1                  1.97                 1.20            2.07
# 2                  0.90                 0.64            1.60
# 3                  1.52                 1.40            1.36
# 4                  2.64                 1.40            0.83
# ..                  ...                  ...             ...
# 564                1.15                 0.68            2.76
# 565                0.75                 0.54            0.82
# 566                2.46                 1.59            1.43
# 567                0.70                 1.46            1.66
# 568                0.54                 0.95            1.79
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 0                      1.46                    0.51                    0.15
# 1                      1.17                    0.74                    0.16
# 2                      0.96                    0.58                    0.06
# 3                      1.09                    0.19                    0.08
# 4                      0.60                    0.23                    0.00
# ..                      ...                     ...                     ...
# 564                    1.77                    0.94                    0.05
# 565                    0.44                    0.37                    0.00
# 566                    0.95                    0.32                    0.16
# 567                    0.70                    0.89                    0.06
# 568                    0.78                    0.64                    0.37
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 0                        1.46                         2.48
# 1                        0.84                         1.46
# 2                        1.09                         2.18
# 3                        0.82                         1.36
# 4                        0.42                         0.53
# ..                        ...                          ...
# 564                      1.98                         2.60
# 565                      0.48                         0.85
# 566                      0.48                         1.19
# 567                      0.70                         1.66
# 568                      0.78                         1.62
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 0                            1.02           0.66                  0.36
# 1                            0.61           1.65                  1.04
# 2                            1.09           1.47                  0.32
# 3                            0.54           1.21                  1.01
# 4                            0.11           0.75                  0.49
# ..                            ...            ...                   ...
# 564                          0.62           1.35                  0.52
# 565                          0.37           1.29                  0.95
# 566                          0.71           1.11                  0.56
# 567                          0.96           0.96                  0.32
# 568                          0.84           1.05                  0.03
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                            2.70               1.97                 0.00
# 1                            3.33               3.53                 0.06
# 2                            2.56               3.97                 0.00
# 3                            2.26               4.47                 0.00
# 4                            2.04               2.91                 0.04
# ..                            ...                ...                  ...
# 564                          4.58               2.60                 0.00
# 565                          1.36               4.29                 0.07
# 566                          2.94               4.44                 0.00
# 567                          1.97               2.04                 0.06
# 568                          2.53               0.78                 0.03
#
#      Dribblers_Tackle_W%
# 0                   58.8
# 1                   57.8
# 2                   50.0
# 3                   60.0
# 4                   78.6
# ..                   ...
# 564                 76.0
# 565                 56.0
# 566                 40.0
# 567                 42.0
# 568                 47.9
#
# [569 rows x 131 columns]

# %%
from sklearn.decomposition import PCA
import numpy as np

# Identify features to minimize
negative_features = ['Yellow_Cards_per_90', 'Red_Cards_per_90', 'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90',
                     'Aerials_Lost_per_90','Miscontrols_per_90','Dispossessed_per_90','Penalty_Kicks_Conceded_per_90']

# Reverse the sign of negative features
for feature in negative_features:
    if feature in player_2024.columns:
        player_2024[feature]=-player_2024[feature]
        player_2021[feature]=-player_2024[feature]

# %%
params=['Goals_per90', 'Carries_Penalty_Area_per_90',  'Goal_Creating_Action_90',
        'Progressive_Passes_Received_per_90','Shots_on_target_per90', 'G+A_per90',
        'xA_per_90','Take_Ons_Attempted', 'Penalty_Kicks_Won_per_90',
        'Progressive_Carries_per_90', 'xG_per90','Shot_Creating_Action_per90', 
        'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90','Progressive_Carries_per_90']

# %%
# Normalize data
numerical_player_2024 = player_2024[params].replace([np.inf, -np.inf], 0)
normalized_player_2024 = (numerical_player_2024 - numerical_player_2024.mean()) / numerical_player_2024.std()

# Apply PCA
pca = PCA()
pca.fit(normalized_player_2024)
explained_variances = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variances >= 0.95) + 1

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
transformed_players = pca.fit_transform(normalized_player_2024)

# Convert transformed data back to DataFrame
transformed_df = pd.DataFrame(transformed_players, index=player_2024.index)

# %%
# Get Hakimi's row and compute cosine similarity
hakimi_2021_index = player_2024.index[player_2024['Player'] == 'Achraf Hakimi'][0]
hakimi_2021_data = transformed_df.loc[hakimi_2021_index].values.reshape(1, -1)

# Remove Hakimi from the dataset for comparison
transformed_df = transformed_df.drop(index=hakimi_2021_index)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(transformed_df, hakimi_2021_data).flatten()
transformed_df['similarity_to_hakimi_2021'] = similarity_scores

# Get top 10 players most similar to de hakimi
top_similar_players_indices = transformed_df.sort_values('similarity_to_hakimi_2021', ascending=False).index
top_similar_players = player_2024.loc[top_similar_players_indices]

# %%
player_2024['similarity_to_hakimi_2021']=transformed_df['similarity_to_hakimi_2021']
player_2024[['Player', 'similarity_to_hakimi_2021']]
# Out:
#                Player  similarity_to_hakimi_2021
# 0          Max Aarons                  -0.086582
# 1    Yunis Abdelhamid                  -0.133425
# 2               Abner                  -0.246486
# 3         Abdel Abqar                  -0.888235
# 4    Francesco Acerbi                  -0.376098
# ..                ...                        ...
# 564       Alidu Seidu                  -0.688107
# 565        Kevin Vogt                  -0.906294
# 566  Mateusz Wieteska                  -0.579243
# 567      Nadir Zortea                   0.786932
# 568     Achraf Hakimi                        NaN
#
# [569 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=12)

# Use a dark background
plt.style.use('dark_background')

# Sort the player_2024 DataFrame by similarity_to_hakimi_2021 in descending order
player_2024_sorted = player_2024.sort_values(by='similarity_to_hakimi_2021', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart, but reverse the order of the data
bars = ax.barh(player_2024_sorted['Player'].head(15)[::-1], (player_2024_sorted['similarity_to_hakimi_2021'].head(15)*100)[::-1],
               color=plt.cm.viridis(np.linspace(0, 1, 10)))

# Add labels and title
ax.set_xlabel('Similarity Percentage', fontproperties=font_prop)
ax.set_ylabel('Player', fontproperties=font_prop)
ax.set_title('Who is most similar to 2020-21 Hakimi from top 5 leagues based on the 2023-24 Season ?', fontproperties=font_prop)

# Set the y-axis tick labels with the custom font
ax.set_yticklabels(player_2024_sorted['Player'].head(15)[::-1], fontproperties=font_prop)

# Remove gridlines
ax.grid(False)

# Make the top and right spines invisible
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make the left and bottom spines white
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

# Change the color of ticks to white
ax.tick_params(colors='white')

# Change the color of labels to white
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')

# Add percentage labels to the bars
for bar in bars:
    width = bar.get_width()
    y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, y_pos, f'{width:.1f}%', ha='left', va='center',
            color='white', fontproperties=font_prop)


# Save the figure
plt.savefig('Similar_2021.png' ,dpi=500,bbox_inches = 'tight',transparent=False)

plt.show()

# %%
final_player = pd.read_csv('../final_players.csv')
player_2024=pd.read_csv('../Full_Players_2024.csv')
player_2023=pd.read_csv('../Full_Players_2023.csv')
player_2022=pd.read_csv('../Full_Players_2022.csv')
player_2021=pd.read_csv('../Full_Players_2021.csv')
newbie=pd.read_csv('../newbie_players_2024.csv')
# Fill missing values with 0 in place
final_player.fillna(0, inplace=True)
newbie.fillna(0,inplace=True)
player_2024.fillna(0,inplace=True)
player_2023.fillna(0, inplace=True)
player_2022.fillna(0, inplace=True)
player_2021.fillna(0, inplace=True)
final_player

# Filter player_2023
player_2024 = player_2024.loc[player_2024['Min'] >= 900]

# Filter player_2023
player_2023 = player_2023.loc[player_2023['Min'] >= 900]

# Filter player_2022
player_2022 = player_2022.loc[player_2022['Min'] >= 900]

# Filter player_2021
player_2021 = player_2021.loc[player_2021['Min'] >= 900]

player_2024
# Assuming 'final_player' is the DataFrame containing player data

# Filter out forwards (FW) and midfielders (MF) from the 'final_player' DataFrame
forward_players = final_player[final_player['Pos'].isin(['DF'])]
newbie = newbie[newbie['Pos'].isin(['DF'])]
player_2021 = player_2021[player_2021['Pos'].isin(['DF'])]
player_2022 = player_2022[player_2022['Pos'].isin(['DF'])]
player_2023 = player_2023[player_2023['Pos'].isin(['DF'])]
player_2024 = player_2024[player_2024['Pos'].isin(['DF'])]

# Reset the index if needed
forward_players = forward_players.reset_index(drop=True)
newbie = newbie.reset_index(drop=True)
player_2024= player_2024.reset_index(drop=True)
player_2023 = player_2023.reset_index(drop=True)
player_2022 = player_2022.reset_index(drop=True)
player_2021 = player_2021.reset_index(drop=True)

# %%
Assignon=player_2024[player_2024['Player']=='Lorenz Assignon']
Assignon
# Out:
#      Unnamed: 0           Player  Nation Pos           Squad  \
# 544           8  Lorenz Assignon  tg TOG  DF  Burnley+Rennes
#
#                               Comp  Age    Born  MP  Starts   Min   90s  \
# 544  eng Premier League+fr Ligue 1  0.0  2000.0  29      27  2245  24.9
#
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 544         0.08        0.2        0.08           0.2      0.03          0.19
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 544        0.03            0.19                55.0           23.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 544            42.0              30.0               55.0            55.5
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 544                    2.89                   14.78                   23.82
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 544                   17.83                    2.05
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 544                       55.5                       2.21
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 544                  0.92                      1.2            31.0
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 544                 185.38                                98.11
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 544                        2.65                1.41
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 544                         0.76                1.61                 0.72
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 544                   29.48                                4.98
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 544                        2.45                     0.32
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 544                   1.81                   0.24                   0.2
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 544               0.0                     0.12                   0.08
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 544                    0.2                    0.0                  0.08
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 544               0.0                     0.04                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 544             868.0            1085.0               80.0         14111.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 544          4398.0             402.0             461.0               87.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 544              399.0              478.0                83.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 544             44.0             78.0              56.0            0.12
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 544        0.18       0.12         -0.06               1.33
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 544               1.93                        0.88
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 544                          0.4                       3.41
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 544                    43.57                     34.9
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 544                     8.55                     0.64                   0.0
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 544             0.04            2.05                    7.91
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 544                  0.0                     0.0                      0.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 544                      0.0              34.86               0.12
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 544                   1.24                0.8                   0.32
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 544             0.1                      0.25           0.04     1.2
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 544       1.2                       41.0                 0.36
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 544              0.04                       0.04                    2.21
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 544                1.24             0.08                  1.12
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 544                1.16                      0.04
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 544                           0.08                    5.38
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 544                0.96                 1.37            2.37
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 544                     1.2                    0.84                    0.32
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 544                      0.92                         2.05
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 544                          1.12           1.24                  0.44
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 544                          3.49               2.81                 0.08
#
#      Dribblers_Tackle_W%
# 544                 45.0

# %%
import pandas as pd








params=['Goals_per90', 'Carries_Penalty_Area_per_90',  'Goal_Creating_Action_90',
        'Progressive_Passes_Received_per_90','Shots_on_target_per90', 'G+A_per90',
        'xA_per_90','Take_Ons_Attempted', 'Assists_per_90',
        'Progressive_Carries_per_90', 'xG_per90','Shot_Creating_Action_per90', 
        'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90','Progressive_Carries_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2021[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
assignon_percentile_ranks = round(players_percentile_ranks.iloc[[544]],0)

# Print the percentile ranks for Declan Rice
assignon_percentile_ranks
# Out:
#      Goals_per90  Carries_Penalty_Area_per_90  Goal_Creating_Action_90  \
# 544         22.0                         91.0                     94.0
#
#      Progressive_Passes_Received_per_90  Shots_on_target_per90  G+A_per90  \
# 544                                70.0                    7.0       49.0
#
#      xA_per_90  Take_Ons_Attempted  Assists_per_90  \
# 544       94.0                72.0            98.0
#
#      Progressive_Carries_per_90  xG_per90  Shot_Creating_Action_per90  \
# 544                        74.0      24.0                        88.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 544                    77.0                    69.0
#
#      Progressive_Carries_per_90
# 544                        74.0

# %%
assignon_percentile_ranks_list = assignon_percentile_ranks.values.flatten().tolist()

assignon_percentile_ranks_list
# Out:
# [22.0,
#  91.0,
#  94.0,
#  70.0,
#  7.0,
#  49.0,
#  94.0,
#  72.0,
#  98.0,
#  74.0,
#  24.0,
#  88.0,
#  77.0,
#  69.0,
#  74.0]

# %%
image_path = "Assignon.jfif"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    assignon_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Lorenz Assignon - Stade Rennais/ FC Burnley", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Ligue 1 & Premier League Aggregated Stats Percentile Rank vs Top-Five Leagues Defenders | 2023-24 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Assignon_2024_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
Hakimi= player_2024[player_2024['Player']=='Achraf Hakimi']
Hakimi
# Out:
#      Unnamed: 0         Player  Nation Pos      Squad        Comp  Age  \
# 202        1091  Achraf Hakimi  ma MAR  DF  Paris S-G  fr Ligue 1  0.0
#
#        Born  MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 202  1998.0  25      20  1932  21.5         0.19       0.42        0.19
#
#      G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 202          0.42       0.2          0.44         0.2            0.44
#
#      Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 202                57.0           27.0            47.4              30.0
#
#      Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 202               52.6          103.12                    3.16
#
#      Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 202                   19.77                    45.4                   38.84
#
#      Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 202                    3.12                     103.12
#
#      Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 202                       2.65                  1.26                      1.4
#
#      Carries_per_90  Total_Distance_per_90  \
# 202           81.95                  428.6
#
#      Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 202                               229.86                        3.91
#
#      1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 202                3.63                         1.02                1.53
#
#      Dispossessed_per_90  Passes_Received_per_90  \
# 202                 1.53                   78.09
#
#      Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 202                                10.7                        4.33
#
#      Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 202                     0.65                   3.67                   0.05
#
#      Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 202                  0.09              0.23                     0.23
#
#      Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 202                   0.05                    0.6                    0.0
#
#      Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 202                   0.0              0.05                      0.0
#
#      Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 202                    0.0            1712.0            1979.0
#
#      Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 202               86.5         25356.0          8074.0             948.0
#
#      Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 202            1030.0               92.0              613.0
#
#      Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 202              696.0                88.1             77.0            125.0
#
#      Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 202              61.6            0.23        0.24        0.2         -0.01
#
#      Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 202                2.0               7.12                        2.09
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 202                          0.6                      10.14
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 202                    92.05                    82.47
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 202                     9.44                     1.35                  0.19
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 202             0.28            3.67                    7.44
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 202                 0.65                    0.05                     0.33
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 202                      0.0              79.63               0.14
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 202                   1.95               1.96                   0.56
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 202             0.1                      0.33            0.1    -0.2
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 202      -0.2                       42.9                 0.14
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 202               0.0                        0.0                    1.02
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 202                1.21             0.14                  0.56
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 202                0.88                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 202                           0.05                     6.6
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 202                0.42                 0.56            1.35
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 202                    0.65                    0.42                    0.28
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 202                      0.79                         1.58
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 202                          0.79            1.3                  0.19
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 202                          1.91                1.3                 0.09
#
#      Dribblers_Tackle_W%
# 202                 50.0

# %%
import pandas as pd





params=['Goals_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90', 'xG_per90', 'xG+xAG_per90', 'npxG_per90',
        'npxG+xAG_per90', 'Take_Ons_Attempted', 'Take_Ons_Succ', 'Take_Ons_Succ%', 'Tackled_Take_Ons', 
        'Tackled_Take_Ons%', 'Touches_per_90', 'Touches_Def_Pen_per_90', 'Touches_Def_3rd_per_90', 
        'Touches_Mid_3rd_per_90', 'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
        'Take_Ons_Attempted_per_90', 'Take_Ons_Succ_per_90', 'Tackled_Take_Ons_per_90', 'Carries_per_90', 
        'Total_Distance_per_90', 'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90', 
        '1/3_Carries_per_90', 'Carries_Penalty_Area_per_90', 'Miscontrols_per_90', 'Dispossessed_per_90', 
        'Passes_Received_per_90', 'Progressive_Passes_Received_per_90', 'Shot_Creating_Action_per90', 
        'Goal_Creating_Action_90', 'Pass_Live_Shot_per_90', 'Pass_Dead_Shot_per_90', 'Take_Ons_Shot_per_90', 
        'Shot-Shot_per_90', 'Fouls_drawn_Shot_per_90', 'Defensive_Shot_per_90', 'Pass_Live_Goal_per_90',
        'Pass_Dead_Goal_per_90', 'Take_Ons_Goal_per_90', 'Shot_Goal_per_90', 'Fouls_Drawn_Goal_per_90', 
        'Defensive_Goal_per_90', 'Passes_Total_Cmp', 'Passes_Total_Att', 'Passes_Total_Cmp%', 'Passes_TotDist', 
        'Passes_PrgDist', 'Passes_Short_Cmp', 'Passes_Short_Att', 'Passes_Short_Cmp%', 'Passes_Medium_Cmp', 
        'Passes_Medium_Att', 'Passes_Medium_Cmp%', 'Passes_Long_Cmp', 'Passes_Long_Att', 'Passes_Long_Cmp%', 
        'Assists_per_90', 'xAG_per_90', 'xA_per_90', 'A-xAG_per_90', 'Key_Passes_per_90', 'Passes_1/3_per_90', 
        'Passes_Penalty_Area_per_90', 'Crosses_Penalty_Area_per_90', 'Progressive_Passes_per_90', 
        'Passes_Attempted_per_90', 'Live_Ball_Passes_per_90', 'Dead_Ball_Passes_per_90', 'Free_Kick_Passes_per_90',
        'Through_Balls_per_90', 'Switches_per_90', 'Crosses_per_90', 'Throw_Ins_Taken_per_90', 
        'Corner_Kicks_per_90', 'In_Corner_Kicks_per_90', 'Out_Corner_Kicks_per_90', 'Str_Corner_Kicks_per_90',
        'Passes_Cmp_per_90', 'Passes_Off_per_90', 'Passes_Blocked_per_90', 'Shots_total_per90', 
        'Shots_on_target_per90', 'Goals_per_shot', 'Goals_per_shot_on_target', 'Npxg_per_shot', 'Xg_net', 
        'Npxg_net', 'Percentage_of_Aerials_Won', 'Yellow_Cards_per_90', 'Red_Cards_per_90', 
        'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90', 'Fouls_Drawn_per_90', 'Offsides_per_90', 
        'Interceptions_per_90', 'Tackles_Won_per_90', 'Penalty_Kicks_Won_per_90', 'Penalty_Kicks_Conceded_per_90',
        'Ball_Recoveries_per_90', 'Aerials_Won_per_90', 'Aerials_Lost_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of Hakimi's stats from the percentile ranks DataFrame
hakimi_percentile_ranks = round(players_percentile_ranks.iloc[[202]],0)

# Print the percentile ranks for Hakimi
hakimi_percentile_ranks
# Out:
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 202         98.0       99.0        98.0          99.0     100.0          99.0
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 202       100.0            99.0                95.0           96.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 202            39.0              97.0               84.0            99.0
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 202                    21.0                    28.0                    92.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 202                   100.0                    99.0
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 202                       99.0                       96.0
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 202                  95.0                     97.0            99.0
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 202                  100.0                                 99.0
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 202                        99.0               100.0
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 202                         99.0                91.0                100.0
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 202                    99.0                               100.0
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 202                        99.0                     99.0
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 202                  100.0                   57.0                  82.0
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 202              96.0                     98.0                   74.0
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 202                  100.0                   44.0                  47.0
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 202              91.0                     44.0                   48.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 202              92.0              92.0               74.0            81.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 202            72.0              97.0              97.0               72.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 202               74.0               75.0                50.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 202             50.0             42.0              72.0            97.0
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 202        98.0       97.0          42.0               98.0
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 202               97.0                        98.0
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 202                         87.0                      100.0
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 202                     99.0                     98.0
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 202                     83.0                     53.0                  95.0
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 202             58.0            88.0                    76.0
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 202                 92.0                    90.0                     93.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 202                     49.0               98.0               54.0
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 202                   97.0               99.0                   99.0
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 202            65.0                      64.0           72.0    51.0
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 202      50.0                       15.0                 27.0
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 202              39.0                       45.0                    51.0
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 202                86.0             87.0                  10.0
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 202                36.0                      45.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 202                           80.0                    94.0
#
#      Aerials_Won_per_90  Aerials_Lost_per_90
# 202                 4.0                  6.0

# %%
# Extract the percentile ranks, transpose, and sort them in descending order
hakimi_percentile_ranks_percentile_ranks_sorted = hakimi_percentile_ranks.T.sort_values(by=202, ascending=False)

# Get the top 20 parameters
top_20_params = hakimi_percentile_ranks_percentile_ranks_sorted.index[:30]
top_20_params_values = hakimi_percentile_ranks_percentile_ranks_sorted[202].head(30)

# Display the top 20 parameters and their values
print("Top 20 Parameters:")
print(top_20_params)
print("Values:")
print(top_20_params_values)
# Out:
# Top 20 Parameters:
# Index(['Progressive_Passes_Received_per_90', 'Pass_Live_Goal_per_90',
#        '1/3_Carries_per_90', 'Progressive_Passes_per_90', 'xG_per90',
#        'npxG_per90', 'Total_Distance_per_90', 'Touches_Att_3rd_per_90',
#        'Dispossessed_per_90', 'Pass_Live_Shot_per_90',
#        'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
#        'Passes_Attempted_per_90', 'Passes_Received_per_90',
#        'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90',
#        'Carries_per_90', 'Carries_Penalty_Area_per_90', 'Touches_per_90',
#        'Shot_Creating_Action_per90', 'Goal_Creating_Action_90',
#        'Shots_total_per90', 'Shots_on_target_per90', 'npxG+xAG_per90',
#        'xG+xAG_per90', 'G+A-PK_per90', 'G+A_per90', 'xAG_per_90',
#        'Goals_per90', 'Fouls_drawn_Shot_per_90'],
#       dtype='object')
# Values:
# Progressive_Passes_Received_per_90     100.0
# Pass_Live_Goal_per_90                  100.0
# 1/3_Carries_per_90                     100.0
# Progressive_Passes_per_90              100.0
# xG_per90                               100.0
# npxG_per90                             100.0
# Total_Distance_per_90                  100.0
# Touches_Att_3rd_per_90                 100.0
# Dispossessed_per_90                    100.0
# Pass_Live_Shot_per_90                  100.0
# Touches_Att_Pen_per_90                  99.0
# Tocuhes_Live_Balls_per_90               99.0
# Passes_Attempted_per_90                 99.0
# Passes_Received_per_90                  99.0
# Progressive_Distance_Carried_per_90     99.0
# Progressive_Carries_per_90              99.0
# Carries_per_90                          99.0
# Carries_Penalty_Area_per_90             99.0
# Touches_per_90                          99.0
# Shot_Creating_Action_per90              99.0
# Goal_Creating_Action_90                 99.0
# Shots_total_per90                       99.0
# Shots_on_target_per90                   99.0
# npxG+xAG_per90                          99.0
# xG+xAG_per90                            99.0
# G+A-PK_per90                            99.0
# G+A_per90                               99.0
# xAG_per_90                              98.0
# Goals_per90                             98.0
# Fouls_drawn_Shot_per_90                 98.0
# Name: 202, dtype: float64

# %%
import pandas as pd







params=['Goals_per90', 'Carries_Penalty_Area_per_90',  'Goal_Creating_Action_90',
        'Progressive_Passes_Received_per_90','Shots_on_target_per90', 'G+A_per90',
        'xA_per_90','Take_Ons_Attempted', 'Assists_per_90',
        'Progressive_Carries_per_90', 'xG_per90','Shot_Creating_Action_per90', 
        'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90','Progressive_Carries_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
hakimi_percentile_ranks = round(players_percentile_ranks.iloc[[202]],0)

# Print the percentile ranks for Declan Rice
hakimi_percentile_ranks
# Out:
#      Goals_per90  Carries_Penalty_Area_per_90  Goal_Creating_Action_90  \
# 202         98.0                         99.0                     99.0
#
#      Progressive_Passes_Received_per_90  Shots_on_target_per90  G+A_per90  \
# 202                               100.0                   99.0       99.0
#
#      xA_per_90  Take_Ons_Attempted  Assists_per_90  \
# 202       97.0                95.0            97.0
#
#      Progressive_Carries_per_90  xG_per90  Shot_Creating_Action_per90  \
# 202                        99.0     100.0                        99.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 202                   100.0                    99.0
#
#      Progressive_Carries_per_90
# 202                        99.0

# %%
hakimi_percentile_ranks_list = hakimi_percentile_ranks.values.flatten().tolist()

hakimi_percentile_ranks_list
# Out:
# [98.0,
#  99.0,
#  99.0,
#  100.0,
#  99.0,
#  99.0,
#  97.0,
#  95.0,
#  97.0,
#  99.0,
#  100.0,
#  99.0,
#  100.0,
#  99.0,
#  99.0]

# %%
image_path = "Hakimi.jfif"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    hakimi_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Achraf Hakimi - Paris Saint-Germain", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Ligue 1 Stats Percentile Rank vs Top-Five Leagues  Defenders | 2023-24 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Hakimi_2024_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
from sklearn.decomposition import PCA
import numpy as np

# Identify features to minimize
negative_features = ['Yellow_Cards_per_90', 'Red_Cards_per_90', 'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90',
                     'Aerials_Lost_per_90','Miscontrols_per_90','Dispossessed_per_90','Penalty_Kicks_Conceded_per_90']

# Reverse the sign of negative features
for feature in negative_features:
    if feature in player_2024.columns:
        player_2024[feature]=-player_2024[feature]
        player_2021[feature]=-player_2024[feature]

# %%
# Normalize data
numerical_player_2024 = player_2024[params].replace([np.inf, -np.inf], 0)
normalized_player_2024 = (numerical_player_2024 - numerical_player_2024.mean()) / numerical_player_2024.std()

# Apply PCA
pca = PCA()
pca.fit(normalized_player_2024)
explained_variances = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variances >= 0.95) + 1

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
transformed_players = pca.fit_transform(normalized_player_2024)

# Convert transformed data back to DataFrame
transformed_df = pd.DataFrame(transformed_players, index=player_2024.index)

# %%
# Get Hakimi's row and compute cosine similarity
hakimi_2024_index = player_2024.index[player_2024['Player'] == 'Achraf Hakimi'][0]
hakimi_2024_data = transformed_df.loc[hakimi_2024_index].values.reshape(1, -1)

# Remove Hakimi from the dataset for comparison
transformed_df = transformed_df.drop(index=hakimi_2024_index)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(transformed_df, hakimi_2024_data).flatten()
transformed_df['similarity_to_hakimi_2024'] = similarity_scores

# Get top 10 players most similar to de hakimi
top_similar_players_indices = transformed_df.sort_values('similarity_to_hakimi_2024', ascending=False).index
top_similar_players = player_2024.loc[top_similar_players_indices]

# %%
player_2024['similarity_to_hakimi_2024']=transformed_df['similarity_to_hakimi_2024']
player_2024[['Player', 'similarity_to_hakimi_2024']]
# Out:
#                Player  similarity_to_hakimi_2024
# 0          Max Aarons                  -0.101074
# 1    Yunis Abdelhamid                  -0.170223
# 2               Abner                  -0.337554
# 3         Abdel Abqar                  -0.962091
# 4    Francesco Acerbi                  -0.417048
# ..                ...                        ...
# 564   Sergio Reguilón                   0.774205
# 565       Alidu Seidu                  -0.654394
# 566        Kevin Vogt                  -0.940517
# 567  Mateusz Wieteska                  -0.601849
# 568      Nadir Zortea                   0.825015
#
# [569 rows x 2 columns]

# %%
player_2024['similarity_to_hakimi_2024']=transformed_df['similarity_to_hakimi_2024']
player_2024[['Player', 'similarity_to_hakimi_2024']]
# Out:
#                Player  similarity_to_hakimi_2024
# 0          Max Aarons                  -0.101074
# 1    Yunis Abdelhamid                  -0.170223
# 2               Abner                  -0.337554
# 3         Abdel Abqar                  -0.962091
# 4    Francesco Acerbi                  -0.417048
# ..                ...                        ...
# 564   Sergio Reguilón                   0.774205
# 565       Alidu Seidu                  -0.654394
# 566        Kevin Vogt                  -0.940517
# 567  Mateusz Wieteska                  -0.601849
# 568      Nadir Zortea                   0.825015
#
# [569 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=12)

# Use a dark background
plt.style.use('dark_background')

# Sort the player_2024 DataFrame by similarity_to_hakimi_2024 in descending order
player_2024_sorted = player_2024.sort_values(by='similarity_to_hakimi_2024', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart, but reverse the order of the data
bars = ax.barh(player_2024_sorted['Player'].head(15)[::-1], (player_2024_sorted['similarity_to_hakimi_2024'].head(15)*100)[::-1],
               color=plt.cm.viridis(np.linspace(0, 1, 10)))

# Add labels and title
ax.set_xlabel('Similarity Percentage', fontproperties=font_prop)
ax.set_ylabel('Player', fontproperties=font_prop)
ax.set_title('Who is most similar to 2020-21 Hakimi from top 5 leagues based on the 2023-24 Season ?', fontproperties=font_prop)

# Set the y-axis tick labels with the custom font
ax.set_yticklabels(player_2024_sorted['Player'].head(15)[::-1], fontproperties=font_prop)

# Remove gridlines
ax.grid(False)

# Make the top and right spines invisible
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make the left and bottom spines white
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

# Change the color of ticks to white
ax.tick_params(colors='white')

# Change the color of labels to white
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')

# Add percentage labels to the bars
for bar in bars:
    width = bar.get_width()
    y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, y_pos, f'{width:.1f}%', ha='left', va='center',
            color='white', fontproperties=font_prop)


# Save the figure
plt.savefig('Similar_2024.png' ,dpi=500,bbox_inches = 'tight',transparent=False)

plt.show()

# %%
Widmer=player_2024[player_2024['Player']=='Silvan Widmer']
Widmer
# Out:
#      Unnamed: 0         Player  Nation Pos     Squad           Comp  Age  \
# 523        2763  Silvan Widmer  ch SUI  DF  Mainz 05  de Bundesliga  0.0
#
#        Born  MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 523  1993.0  20      13  1242  13.8         0.07       0.29        0.07
#
#      G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 523          0.29       0.1          0.35         0.1            0.35
#
#      Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 523                18.0            2.0            11.1              14.0
#
#      Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 523               77.8           59.93                    3.48
#
#      Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 523                   15.94                   28.99                   15.51
#
#      Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 523                    2.75                      59.93
#
#      Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 523                        1.3                  0.14                     1.01
#
#      Carries_per_90  Total_Distance_per_90  \
# 523           22.25                 103.26
#
#      Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 523                                56.96                        2.25
#
#      1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 523                1.16                         0.43               -1.01
#
#      Dispossessed_per_90  Passes_Received_per_90  \
# 523                -0.58                   30.29
#
#      Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 523                                4.57                        2.17
#
#      Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 523                     0.22                   1.74                   0.22
#
#      Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 523                   0.0              0.22                      0.0
#
#      Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 523                    0.0                   0.22                    0.0
#
#      Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 523                   0.0               0.0                      0.0
#
#      Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 523                    0.0             490.0             677.0
#
#      Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 523               72.4          8090.0          3637.0             249.0
#
#      Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 523             296.0               84.1              185.0
#
#      Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 523              261.0                70.9             44.0             82.0
#
#      Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 523              53.7            0.22        0.25       0.18         -0.04
#
#      Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 523               1.16               4.13                        0.72
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 523                         0.36                       3.91
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 523                    49.06                    37.68
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 523                     11.3                     0.58                   0.0
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 523              0.0            2.54                   10.72
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 523                  0.0                     0.0                      0.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 523                      0.0              35.51               0.07
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 523                   1.45               1.01                   0.22
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 523            0.07                      0.33            0.1    -0.4
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 523      -0.4                       37.3                -0.29
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 523              -0.0                       -0.0                   -0.72
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 523                0.22             0.22                  1.16
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 523                0.72                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 523                           -0.0                    4.42
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 523                1.38                -2.32            1.67
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 523                    0.87                    0.58                    0.22
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 523                      1.23                         2.03
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 523                           0.8            1.3                  0.36
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 523                          2.83               2.68                  0.0
#
#      Dribblers_Tackle_W%  similarity_to_hakimi_2024
# 523                 60.7                   0.914087

# %%
import pandas as pd







params=['Goals_per90', 'Carries_Penalty_Area_per_90',  'Goal_Creating_Action_90',
        'Progressive_Passes_Received_per_90','Shots_on_target_per90', 'G+A_per90',
        'xA_per_90','Take_Ons_Attempted', 'Assists_per_90',
        'Progressive_Carries_per_90', 'xG_per90','Shot_Creating_Action_per90', 
        'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90','Progressive_Carries_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
widmer_percentile_ranks = round(players_percentile_ranks.iloc[[523]],0)

# Print the percentile ranks for Declan Rice
widmer_percentile_ranks
# Out:
#      Goals_per90  Carries_Penalty_Area_per_90  Goal_Creating_Action_90  \
# 523         72.0                         90.0                     77.0
#
#      Progressive_Passes_Received_per_90  Shots_on_target_per90  G+A_per90  \
# 523                                82.0                   73.0       95.0
#
#      xA_per_90  Take_Ons_Attempted  Assists_per_90  \
# 523       96.0                63.0            96.0
#
#      Progressive_Carries_per_90  xG_per90  Shot_Creating_Action_per90  \
# 523                        85.0      91.0                        82.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 523                    77.0                    98.0
#
#      Progressive_Carries_per_90
# 523                        85.0

# %%
widmer_percentile_ranks_list = widmer_percentile_ranks.values.flatten().tolist()

widmer_percentile_ranks_list
# Out:
# [72.0,
#  90.0,
#  77.0,
#  82.0,
#  73.0,
#  95.0,
#  96.0,
#  63.0,
#  96.0,
#  85.0,
#  91.0,
#  82.0,
#  77.0,
#  98.0,
#  85.0]

# %%
image_path = "Widmer.jpg"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    widmer_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Silvan Widmer - Mainz 05", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Bundesliga Stats Percentile Rank vs Top-Five Leagues  Defenders | 2023-24 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Widmer_2024_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png
