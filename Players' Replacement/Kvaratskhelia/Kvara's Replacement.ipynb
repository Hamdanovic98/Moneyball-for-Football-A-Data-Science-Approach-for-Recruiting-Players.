# %%
import pandas as pd
import numpy as np
from PIL import Image
from mplsoccer import PyPizza, add_image, FontManager
import urllib.request

# %%
# Display the current settings
print("Current maximum number of rows: ", pd.get_option('display.max_rows'))
print("Current maximum number of columns: ", pd.get_option('display.max_columns'))

# Set new maximum number of rows and columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# Display the updated settings
print("Updated maximum number of rows: ", pd.get_option('display.max_rows'))
print("Updated maximum number of columns: ", pd.get_option('display.max_columns'))
# Out:
# Current maximum number of rows:  60
# Current maximum number of columns:  20
# Updated maximum number of rows:  500
# Updated maximum number of columns:  500

# %%
final_player = pd.read_csv('../final_players_2024.csv')
player_2024=pd.read_csv('../Full_Players_2024.csv')
player_2023=pd.read_csv('../Full_Players_2023.csv')
player_2022=pd.read_csv('../Full_Players_2022.csv')
player_2021=pd.read_csv('../Full_Players_2021.csv')
newbie=pd.read_csv('../newbie_players_2024.csv')
# Fill missing values with 0 in place
final_player.fillna(0, inplace=True)
newbie.fillna(0,inplace=True)
player_2024.fillna(0,inplace=True)
player_2023.fillna(0, inplace=True)
player_2022.fillna(0, inplace=True)
player_2021.fillna(0, inplace=True)
final_player
# Out:
#       Unnamed: 0               Player  Nation    Pos  \
# 0              0       Milan Škriniar  sk SVK     DF
# 1              1      Maxence Lacroix  fr FRA     DF
# 2              2          Wataru Endo  jp JPN     MF
# 3              3           Unai López  es ESP     MF
# 4              4        Mario Hermoso  es ESP     DF
# ...          ...                  ...     ...    ...
# 1491        2490  Filippo Terracciano  it ITA  DF,FW
# 1492        2495       Jonathan Viera  es ESP     MF
# 1493        2496       Alan Virginius  fr FRA     FW
# 1494        2505       Bryan Zaragoza  es ESP  FW,MF
# 1495        2507         Nadir Zortea  it ITA     DF
#
#                              Squad                              Comp  Age  \
# 0                  Paris S-G+Inter             fr Ligue 1+it Serie A  0.0
# 1                        Wolfsburg                     de Bundesliga  0.0
# 2              Liverpool+Stuttgart  eng Premier League+de Bundesliga  0.0
# 3     Rayo Vallecano+Athletic Club                        es La Liga  0.0
# 4                  Atlético Madrid                        es La Liga  0.0
# ...                            ...                               ...  ...
# 1491           Hellas Verona+Milan                        it Serie A  0.0
# 1492            Las Palmas+Almería                        es La Liga  0.0
# 1493           Lille+Clermont Foot                        fr Ligue 1  0.0
# 1494         Granada+Bayern Munich          es La Liga+de Bundesliga  0.0
# 1495            Frosinone+Atalanta                        it Serie A  0.0
#
#         Born     MP  Starts    Min    90s  Goals_per90  G+A_per90  G-PK_per90  \
# 0     1995.0  112.0   103.0   9325  103.7         0.06       0.06        0.06
# 1     2000.0  111.0   103.0   9070  100.8         0.06       0.08        0.06
# 2     1993.0  128.0   119.0  10498  116.6         0.11       0.19        0.11
# 3     1995.0  122.0    68.0   5946   66.0         0.07       0.14        0.07
# 4     1995.0  114.0   104.0   9110  101.1         0.06       0.11        0.06
# ...      ...    ...     ...    ...    ...          ...        ...         ...
# 1491  2003.0   21.0    15.0   1372   15.2         0.00       0.07        0.00
# 1492  1989.0   21.0    19.0   1529   17.0         0.12       0.35        0.00
# 1493  2003.0   16.0    13.0   1005   11.2         0.00       0.18        0.00
# 1494  2001.0   28.0    19.0   1821   20.2         0.30       0.40        0.25
# 1495  1999.0   19.0    14.0   1407   15.7         0.13       0.45        0.13
#
#       G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
#
progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 0                                  121.18                        0.97
# 1                                  110.79                        0.57
# 2                                   75.58                        0.95
# 3                                   82.38                        1.36
# 4                                  108.19                        1.29
# ...                                   ...                         ...
# 1491                                92.76                        1.71
# 1492                               125.76                        3.59
# 1493                                76.79                        2.05
# 1494                               141.68                        5.64
# 1495                                70.64                        2.42
#
#       1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 0                   0.71                         0.01                0.52
# 1                   0.47                         0.05                0.73
# 2                   1.02                         0.14                1.57
# 3                   1.36                         0.21                1.36
# 4                   1.00                         0.04                0.74
# ...                  ...                          ...                 ...
# 1491                1.51                         0.07                1.25
# 1492                2.94                         0.65                1.88
# 1493                0.98                         0.98                2.23
# 1494                3.56                         2.13                2.77
# 1495                1.72                         0.38                2.04
#
#       Dispossessed_per_90  Passes_Received_per_90  \
# 0                    0.23                   61.06
# 1                    0.26                   43.50
# 2                    1.45                   43.64
# 3                    1.15                   51.43
# 4                    0.33                   50.39
# ...                   ...                     ...
# 1491                 1.32                   32.63
# 1492                 1.06                   58.06
# 1493                 0.98                   20.45
# 1494                 0.74                   29.55
# 1495                 1.08                   30.51
#
#       Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 0                                   0.81                        0.78
# 1                                   0.27                        0.87
# 2                                   1.63                        2.36
# 3                                   2.30                        3.16
# 4                                   1.21                        1.39
# ...                                  ...                         ...
# 1491                                1.91                        2.37
# 1492                                3.88                        4.53
# 1493                                6.07                        2.05
# 1494                                7.67                        3.76
# 1495                                5.92                        3.25
#
#       Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 0                        0.04                   0.65                   0.00
# 1                        0.06                   0.72                   0.02
# 2                        0.18                   1.92                   0.01
# 3                        0.14                   2.09                   0.70
# 4                        0.16                   1.17                   0.07
# ...                       ...                    ...                    ...
# 1491                     0.26                   1.32                   0.59
# 1492                     0.41                   3.94                   0.18
# 1493                     0.27                   1.43                   0.18
# 1494                     0.25                   1.88                   0.40
# 1495                     0.57                   2.36                   0.38
#
#       Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 0                     0.01              0.09                     0.04
# 1                     0.03              0.07                     0.02
# 2                     0.06              0.12                     0.14
# 3                     0.06              0.14                     0.08
# 4                     0.01              0.11                     0.02
# ...                    ...               ...                      ...
# 1491                  0.20              0.20                     0.07
# 1492                  0.18              0.00                     0.12
# 1493                  0.18              0.18                     0.09
# 1494                  0.89              0.20                     0.35
# 1495                  0.19              0.19                     0.06
#
#       Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 0                      0.65                   0.04                   0.00
# 1                      0.72                   0.05                   0.00
# 2                      1.92                   0.14                   0.00
# 3                      2.09                   0.11                   0.02
# 4                      1.17                   0.10                   0.01
# ...                     ...                    ...                    ...
# 1491                   0.00                   0.13                   0.07
# 1492                   0.12                   0.41                   0.00
# 1493                   0.00                   0.18                   0.00
# 1494                   0.05                   0.10                   0.05
# 1495                   0.06                   0.51                   0.00
#
#       Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 0                     0.00              0.00                     0.00
# 1                     0.00              0.01                     0.00
# 2                     0.00              0.01                     0.03
# 3                     0.00              0.00                     0.00
# 4                     0.00              0.04                     0.01
# ...                    ...               ...                      ...
# 1491                  0.00              0.07                     0.00
# 1492                  0.00              0.00                     0.00
# 1493                  0.00              0.00                     0.09
# 1494                  0.05              0.00                     0.05
# 1495                  0.06              0.00                     0.00
#
#       Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 0                      0.00            7001.0            7533.0
# 1                      0.00            4893.0            5859.0
# 2                      0.01            5117.0            6201.0
# 3                      0.01            3469.0            4256.0
# 4                      0.00            5722.0            6697.0
# ...                     ...               ...               ...
# 1491                   0.00             545.0             753.0
# 1492                   0.00             924.0            1058.0
# 1493                   0.00             150.0             226.0
# 1494                   0.00             308.0             526.0
# 1495                   0.00             487.0             664.0
#
#       Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 0                 92.94        127807.0         38169.0            2585.0
# 1                 83.51        102529.0         36399.0            1344.0
# 2                 82.52         84732.0         23689.0            2377.0
# 3                 81.51         64432.0         16527.0            1495.0
# 4                 85.44        100565.0         33666.0            2441.0
# ...                 ...             ...             ...               ...
# 1491              72.00          9867.0          4331.0             246.0
# 1492              87.00         12386.0          2980.0             567.0
# 1493              66.00          2144.0           599.0              78.0
# 1494              59.00          4904.0          1696.0             173.0
# 1495              73.00          7876.0          3172.0             262.0
#
#       Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 0               2753.0              94.52             3689.0
# 1               1562.0              86.11             2923.0
# 2               2764.0              87.09             2133.0
# 3               1615.0              91.72             1306.0
# 4               2618.0              93.08             2269.0
# ...                ...                ...                ...
# 1491             287.0              86.00              237.0
# 1492             611.0              93.00              278.0
# 1493             100.0              78.00               51.0
# 1494             217.0              80.00               94.0
# 1495             303.0              86.00              166.0
#
#       Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 0                3846.0               95.92            586.0            742.0
# 1                3193.0               91.54            645.0           1011.0
# 2                2437.0               87.53            385.0            573.0
# 3                1505.0               86.78            501.0            823.0
# 4                2546.0               89.12            586.0            941.0
# ...                 ...                 ...              ...              ...
# 1491              314.0               75.00             55.0            118.0
# 1492              316.0               88.00             28.0             53.0
# 1493               81.0               63.00              6.0             14.0
# 1494              167.0               56.00             28.0             85.0
# 1495              219.0               76.00             45.0             88.0
#
#       Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 0                78.98            0.00        0.01       0.02         -0.01
# 1                63.80            0.01        0.02       0.03         -0.00
# 2                67.19            0.00        0.08       0.09         -0.00
# 3                60.87            0.03        0.11       0.12         -0.05
# 4                62.27            0.01        0.04       0.05          0.01
# ...                ...             ...         ...        ...           ...
# 1491             47.00            0.07        0.07       0.09          0.00
# 1492             53.00            0.24        0.22       0.15          0.02
# 1493             43.00            0.18        0.13       0.24          0.04
# 1494             33.00            0.10        0.17       0.23         -0.07
# 1495             51.00            0.32        0.20       0.15          0.12
#
#       Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 0                  0.24               3.91                        0.24
# 1                  0.22               3.36                        0.19
# 2                  0.94               4.67                        0.68
# 3                  1.42               5.52                        1.06
# 4                  0.49               4.65                        0.59
# ...                 ...                ...                         ...
# 1491               1.18               3.22                        0.92
# 1492               2.59               4.24                        1.76
# 1493               1.07               0.98                        0.45
# 1494               1.29               0.74                        1.73
# 1495               1.53               1.85                        1.85
#
#       Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 0                            0.03                       3.71
# 1                            0.02                       4.02
# 2                            0.05                       5.35
# 3                            0.24                       5.74
# 4                            0.15                       5.80
# ...                           ...                        ...
# 1491                         0.66                       3.42
# 1492                         0.12                       7.82
# 1493                         0.18                       2.05
# 1494                         0.89                       2.23
# 1495                         1.27                       3.31
#
#       Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 0                
#
#       Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 0                 0.01                       0.01                    1.22
# 1                 0.06                       0.02                    1.06
# 2                 0.00                       0.00                    1.41
# 3                 0.00                       0.00                    1.95
# 4                 0.03                       0.02                    1.14
# ...                ...                        ...                     ...
# 1491              0.00                       0.00                    1.18
# 1492              0.06                       0.06                    0.76
# 1493              0.00                       0.00                    0.36
# 1494              0.00                       0.00                    0.69
# 1495              0.00                       0.00                    1.21
#
#       Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 0                   0.71             0.03                  0.77
# 1                   0.82             0.01                  1.74
# 2                   1.65             0.03                  1.09
# 3                   1.15             0.17                  0.89
# 4                   0.76             0.07                  1.13
# ...                  ...              ...                   ...
# 1491                2.17             0.00                  1.32
# 1492                1.88             0.29                  0.24
# 1493                0.54             0.36                  0.27
# 1494                1.68             0.74                  0.25
# 1495                1.02             0.00                  0.32
#
#       Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 0                   0.92                      0.00
# 1                   1.03                      0.00
# 2                   1.29                      0.02
# 3                   1.06                      0.00
# 4                   0.85                      0.01
# ...                  ...                       ...
# 1491                1.38                      0.00
# 1492                0.71                      0.00
# 1493                0.54                      0.09
# 1494                0.64                      0.05
# 1495                1.15                      0.00
#
#       Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                              0.01                    5.27
# 1                              0.04                    5.95
# 2                              0.00                    6.98
# 3                              0.00                    6.53
# 4                              0.01                    5.76
# ...                             ...                     ...
# 1491                           0.07                    5.26
# 1492                           0.00                    3.76
# 1493                           0.00                    1.52
# 1494                           0.00                    2.97
# 1495                           0.00                    3.63
#
#       Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 0                   1.21                 1.34            1.43
# 1                   2.48                 1.86            1.77
# 2                   2.12                 1.42            2.19
# 3                   0.57                 1.14            1.91
# 4                   1.61                 1.18            1.51
# ...                  ...                  ...             ...
# 1491                1.25                 1.18            2.11
# 1492                0.24                 0.59            1.47
# 1493                0.36                 1.43            0.89
# 1494                0.25                 0.45            1.09
# 1495                0.70                 1.46            1.66
#
#       Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 0                       0.83                    0.49                    0.10
# 1                       1.20                    0.53                    0.04
# 2                       0.86                    1.12                    0.22
# 3                       0.71                    0.95                    0.24
# 4                       1.05                    0.34                    0.13
# ...                      ...                     ...                     ...
# 1491                    1.58                    0.46                    0.07
# 1492                    0.41                    0.65                    0.41
# 1493                    0.45                    0.36                    0.09
# 1494                    0.50                    0.35                    0.25
# 1495                    0.70                    0.89                    0.06
#
#       Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 0                         0.76                         1.25
# 1                         0.89                         1.40
# 2                         1.01                         2.48
# 3                         0.82                         2.30
# 4                         0.93                         1.78
# ...                        ...                          ...
# 1491                      1.18                         2.24
# 1492                      0.65                         1.65
# 1493                      0.36                         1.07
# 1494                      0.54                         1.29
# 1495                      0.70                         1.66
#
#       Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 0                             0.49           0.99                  0.64
# 1                             0.52           1.42                  0.60
# 2                             1.47           1.41                  0.29
# 3                             1.49           0.96                  0.14
# 4                             0.85           0.86                  0.31
# ...                            ...            ...                   ...
# 1491                          1.05           1.78                  0.39
# 1492                          1.00           0.24                  0.00
# 1493                          0.71           0.62                  0.00
# 1494                          0.74           0.45                  0.00
# 1495                          0.96           0.96                  0.32
#
#       Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                             2.20               2.66                 0.07
# 1                             3.50               4.86                 0.01
# 2                             3.28               1.86                 0.03
# 3                             2.81               0.58                 0.08
# 4                             2.64               2.97                 0.03
# ...                            ...                ...                  ...
# 1491                          3.42               1.18                 0.00
# 1492                          1.71               0.12                 0.00
# 1493                          1.16               0.62                 0.00
# 1494                          1.34               0.15                 0.00
# 1495                          1.97               2.04                 0.06
#
#       Dribblers_Tackle_W%  Seasons at top 5  Seasons in PL  Seasons in Liga  \
# 0                   61.21                 4              0                0
# 1                   62.51                 4              0                0
# 2                   41.21                 4              1                0
# 3                   35.61                 4              0                4
# 4                   50.31                 4              0                4
# ...                   ...               ...            ...              ...
# 1491                53.00                 1              0                0
# 1492                39.00                 1              0                1
# 1493                33.00                 1              0                0
# 1494                42.00                 1              0                1
# 1495                42.00                 1              0                0
#
#       Seasons in Serie A  Seasons in Ligue 1  Seasons in Bundesliga
# 0                      3                   1                      0
# 1                      0                   0                      4
# 2                      0                   0                      3
# 3                      0                   0                      0
# 4                      0                   0                      0
# ...                  ...                 ...                    ...
# 1491                   1                   0                      0
# 1492                   0                   0                      0
# 1493                   0                   1                      0
# 1494                   0                   0                      1
# 1495                   1                   0                      0
#
# [1496 rows x 137 columns]

# %%
# Assuming 'final_player' is the DataFrame containing player data

# Filter out only the Forwards (FW) from the 'final_player' DataFrame
forward_players = final_player[final_player['Pos'] == 'FW']
newbie=newbie[newbie['Pos']=='FW']
player_2021=player_2021[player_2021['Pos']=='FW']
player_2022=player_2022[player_2022['Pos']=='FW']
player_2023=player_2023[player_2023['Pos']=='FW']
# Reset the index if needed
forward_players = forward_players.reset_index(drop=True)
newbie = newbie.reset_index(drop=True)
player_2023 = player_2023.reset_index(drop=True)
player_2022 = player_2022.reset_index(drop=True)
player_2021 = player_2021.reset_index(drop=True)

# %%
# filter player_2024
player_2024= player_2024.loc[player_2024['Min']>= 900]

# Filter player_2023
player_2023 = player_2023.loc[player_2023['Min'] >= 900]

# Filter player_2022
player_2022 = player_2022.loc[player_2022['Min'] >= 900]

# Filter player_2021
player_2021 = player_2021.loc[player_2021['Min'] >= 900]

player_2024
# Out:
#       Unnamed: 0             Player   Nation    Pos                  Squad  \
# 0              0         Max Aarons  eng ENG     DF            Bournemouth
# 1              1   Brenden Aaronson   us USA  MF,FW           Union Berlin
# 2              4   Yunis Abdelhamid   ma MAR     DF                  Reims
# 3              5  Salis Abdul Samed   gh GHA     MF                   Lens
# 4              7    Laurent Abergel   fr FRA     MF                Lorient
# ...          ...                ...      ...    ...                    ...
# 1492         134  Alessandro Zanoli   it ITA  DF,FW     Salernitana+Napoli
# 1493         135       Duván Zapata   co COL     FW        Torino+Atalanta
# 1494         136     Bryan Zaragoza   es ESP  FW,MF  Granada+Bayern Munich
# 1495         138       Nadir Zortea   it ITA     DF     Frosinone+Atalanta
# 1496         139        Milan Đurić   ba BIH     FW    Hellas Verona+Monza
#
#                           Comp  Age    Born  MP  Starts   Min   90s  \
# 0           eng Premier League  0.0  2000.0  20      13  1237  13.7
# 1                de Bundesliga  0.0  2000.0  30      14  1267  14.1
# 2                   fr Ligue 1  0.0  1987.0  31      31  2781  30.9
# 3                   fr Ligue 1  0.0  2000.0  27      17  1519  16.9
# 4                   fr Ligue 1  0.0  1993.0  33      32  2860  31.8
# ...                        ...  ...     ...  ..     ...   ...   ...
# 1492                it Serie A  0.0  2000.0  21      10   973  10.8
# 1493                it Serie A  0.0  1991.0  37      36  2992  33.2
# 1494  es La Liga+de Bundesliga  0.0  2001.0  28      19  1821  20.2
# 1495                it Serie A  0.0  1999.0  19      14  1407  15.7
# 1496                it Serie A  0.0  1990.0  37      26  2461  27.4
#
#       Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  \
# 0            0.00       0.07        0.00          0.07      0.00
# 1            0.14       0.28        0.14          0.28      0.14
# 2            0.13       0.13        0.10          0.10      0.11
# 3            0.00       0.00        0.00          0.00      0.05
# 4            0.06       0.09        0.06          0.09      0.04
# ...           ...        ...         ...           ...       ...
# 1492         0.00       0.19        0.00          0.19      0.02
# 1493         0.39       0.51        0.39          0.51      0.34
# 1494         0.30       0.40        0.25          0.35      0.21
# 1495         0.13       0.45        0.13          0.45      0.03
# 1496         0.33       0.40        0.29          0.36      0.27
#
#       xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 0             0.06        0.00            0.06                34.0
# 1             0.27        0.14            0.27                77.0
# 2             0.12        0.09            0.09                15.0
# 3             0.08        0.05            0.08                19.0
# 4             0.10        0.04            0.10                65.0
# ...            ...         ...             ...                 ...
# 1492          0.02        0.02            0.02                26.0
# 1493          0.44        0.34            0.44               114.0
# 1494          0.32        0.17            0.27               145.0
# 1495          0.19        0.03            0.19                52.0
# 1496          0.39        0.19            0.21                 7.0
#
#       Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 0              14.0            41.2              12.0               35.3
# 1              34.0            44.2              41.0               53.2
# 2               8.0            53.3               7.0               46.7
# 3               7.0            36.8              11.0               57.9
# 4              44.0            67.7              18.0               27.7
# ...             ...             ...               ...                ...
# 1492            6.0            23.0              19.0               73.0
# 1493           38.0            33.0              63.0               55.0
# 1494           61.0            42.0              73.0               50.0
# 1495           22.0            42.0              25.0               48.0
# 1496            4.0            57.0               3.0               43.0
#
#       Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 0              51.90                    3.14                   18.39
# 1              47.87                    0.78                    7.66
# 2              70.71                    9.48                   31.59
# 3              60.47                    1.24                    9.94
# 4              68.05                    3.30                   17.39
# ...              ...                     ...                     ...
# 1492           53.24                    2.13                   12.50
# 1493           38.64                    1.11                    2.65
# 1494           39.46                    0.05                    3.71
# 1495           53.69                    2.04                   11.46
# 1496           29.27                    1.68                    3.36
#
#       Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                      22.12                   12.04                    0.80
# 1                      21.35                   20.78                    3.33
# 2                      36.21                    3.69                    1.13
# 3                      38.28                   12.90                    0.41
# 4                      40.50                   10.97                    0.31
# ...                      ...                     ...                     ...
# 1492                   23.80                   17.50                    1.76
# 1493                   16.14                   20.39                    6.20
# 1494                   14.26                   22.33                    4.41
# 1495                   22.10                   20.57                    1.66
# 1496                   16.57                    9.38                    3.03
#
#       Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                         51.90                       2.48
# 1                         47.87                       5.46
# 2                         70.68                       0.49
# 3                         60.47                       1.12
# 4                         68.05                       2.04
# ...                         ...                        ...
# 1492                      53.24                       2.41
# 1493                      38.64                       3.43
# 1494                      39.41                       7.18
# 1495                      53.69                       3.31
# 1496                      29.16                       0.26
#
#       Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0
#
#       Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                             2.70               1.97                 0.00
# 1                             2.41               0.28                 0.00
# 2                             3.33               3.53                 0.06
# 3                             1.95               1.07                 0.00
# 4                             4.59               1.92                 0.09
# ...                            ...                ...                  ...
# 1492                          1.76               1.67                 0.00
# 1493                          0.75               0.81                 0.00
# 1494                          1.34               0.15                 0.00
# 1495                          1.97               2.04                 0.06
# 1496                          0.26               1.46                 0.00
#
#       Dribblers_Tackle_W%
# 0                    58.8
# 1                    50.0
# 2                    57.8
# 3                    44.4
# 4                    39.6
# ...                   ...
# 1492                 58.0
# 1493                 23.0
# 1494                 42.0
# 1495                 42.0
# 1496                 29.0
#
# [1497 rows x 131 columns]

# %%
# Reset the index if needed
forward_players = forward_players.reset_index(drop=True)
newbie = newbie.reset_index(drop=True)
player_2023 = player_2023.reset_index(drop=True)
player_2022 = player_2022.reset_index(drop=True)
player_2021 = player_2021.reset_index(drop=True)
player_2024 = player_2024.reset_index(drop=True)

# %%
Kvara=forward_players[forward_players['Player']=='Khvicha Kvaratskhelia']
Kvara
# Out:
#      Unnamed: 0                 Player  Nation Pos   Squad        Comp   Age  \
# 124         914  Khvicha Kvaratskhelia  ge GEO  FW  Napoli  it Serie A  21.0
#
#        Born    MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 124  2001.0  68.0    62.0  5255  58.4         0.39       0.67        0.36
#
#      G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 124          0.63      0.33          0.58         0.3            0.55
#
#      Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 124               419.0          176.0            42.0             205.0
#
#      Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 124               49.0           54.62                    0.31
#
#      Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 124                    3.73                    19.3                   32.57
#
#      Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 124                    6.35                      54.59
#
#      Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 124                       7.18                  3.01                     3.51
#
#      Carries_per_90  Total_Distance_per_90  \
# 124           37.21                 277.31
#
#      Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 124                               145.12                        5.53
#
#      1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 124                2.91                         2.82                2.07
#
#      Dispossessed_per_90  Passes_Received_per_90  \
# 124                 1.64                    43.1
#
#      Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 124                                9.54                        4.98
#
#      Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 124                     0.69                   2.91                   0.31
#
#      Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 124                  0.79               0.5                     0.38
#
#      Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 124                   2.91                   0.28                   0.02
#
#      Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 124                   0.1              0.15                     0.12
#
#      Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 124                   0.02            1865.0            2336.0
#
#      Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 124               80.0         28279.0          5410.0            1111.0
#
#      Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 124            1221.0               91.0              525.0
#
#      Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 124              673.0                78.0            159.0            280.0
#
#      Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 124              57.0             0.1        0.25       0.21          0.02
#
#      Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 124                2.0               1.49                        1.37
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 124                         0.18                       3.08
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 124                     40.0                    37.55
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 124                     2.31                     0.44                  0.34
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 124             0.77             3.0                    0.68
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 124                 1.15                     0.6                     0.26
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 124                      0.0              31.93               0.13
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 124                   0.75               3.62                   1.28
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 124             3.2                      9.01           2.42     3.7
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 124       3.3                       37.0                 0.15
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 124               0.0                        0.0                    0.77
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 124                2.14             0.17                  0.31
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 124                0.75                       0.1
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 124                            0.0                    3.72
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 124                0.33                 0.56            1.46
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 124                    0.39                    0.46                     0.6
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 124                      0.55                         1.58
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 124                          1.03            0.6                  0.02
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 124                          1.76               0.26                 0.02
#
#      Dribblers_Tackle_W%  Seasons at top 5  Seasons in PL  Seasons in Liga  \
# 124                34.87                 2              0                0
#
#      Seasons in Serie A  Seasons in Ligue 1  Seasons in Bundesliga
# 124                   2                   0                      0

# %%
Kvara_2023=player_2023[player_2023['Player']=='Khvicha Kvaratskhelia']
Kvara_2023
# Out:
#     Unnamed: 0                 Player  Nation Pos   Squad        Comp  Age  \
# 87        1444  Khvicha Kvaratskhelia  ge GEO  FW  Napoli  it Serie A   21
#
#     Born  MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 87  2001  34      30  2518  28.0         0.43       0.79        0.36
#
#     G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 87          0.71      0.29          0.56        0.23            0.51
#
#     Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 87               199.0           75.0            37.7             107.0
#
#     Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 87               53.8           55.29                    0.29
#
#     Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 87                    3.93                   17.36                   34.86
#
#     Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 87                    6.25                      55.21
#
#     Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 87                       7.11                  2.68                     3.82
#
#     Carries_per_90  Total_Distance_per_90  \
# 87           37.64                 247.68
#
#     Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 87                               132.11                        4.96
#
#     1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 87                2.21                          3.0                2.25
#
#     Dispossessed_per_90  Passes_Received_per_90  \
# 87                 1.71                   43.61
#
#     Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 87                               10.39                        4.86
#
#     Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 87                     0.86                   3.21                   0.11
#
#     Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 87                  0.71              0.46                     0.29
#
#     Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 87                   0.07                   0.36                   0.04
#
#     Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 87                  0.11              0.21                     0.14
#
#     Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 87                    0.0             900.0            1136.0
#
#     Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 87               79.2         12766.0          2560.0             570.0
#
#     Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  Passes_Medium_Att  \
# 87             623.0               91.5              225.0              301.0
#
#     Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  \
# 87                74.8             63.0            118.0              53.4
#
#     Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 87             0.0        0.28       0.24          0.08               1.93
#
#     Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 87               1.46                        1.64
#
#     Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 87                         0.29                       3.25
#
#     Passes_Attempted_per_90  Live_Ball_Passes_per_90  Dead_Ball_Passes_per_90  \
# 87                    40.57                    38.68                     1.75
#
#     Free_Kick_Passes_per_90  Through_Balls_per_90  Switches_per_90  \
# 87                     0.32                   0.5             0.54
#
#     Crosses_per_90  Throw_Ins_Taken_per_90  Corner_Kicks_per_90  \
# 87            2.71                    0.64                 0.79
#
#     In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  Str_Corner_Kicks_per_90  \
# 87                    0.29                     0.11                      0.0
#
#     Passes_Cmp_per_90  Passes_Off_per_90  Passes_Blocked_per_90  \
# 87              32.14               0.14                   0.79
#
#     Shots_total_per90  Shots_on_target_per90  Goals_per_shot  \
# 87               2.97                   1.07            0.12
#
#     Goals_per_shot_on_target  Npxg_per_shot  Xg_net  Npxg_net  \
# 87                      0.33           0.08     3.8       3.4
#
#     Percentage_of_Aerials_Won  Yellow_Cards_per_90  Red_Cards_per_90  \
# 87                       38.1                 0.04               0.0
#
#     Second_Yellow_Card_per_90  Fouls_Committed_per_90  Fouls_Drawn_per_90  \
# 87                        0.0                    0.71                1.61
#
#     Offsides_per_90  Interceptions_per_90  Tackles_Won_per_90  \
# 87             0.21                  0.18                0.82
#
#     Penalty_Kicks_Won_per_90  Penalty_Kicks_Conceded_per_90  \
# 87                      0.14                            0.0
#
#     Ball_Recoveries_per_90  Aerials_Won_per_90  Aerials_Lost_per_90  \
# 87                    4.21                0.29                 0.46
#
#     Tackles_per_90  Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  \
# 87            1.54                    0.43                    0.29
#
#     Tackles_Att_3rd_per_90  Dribblers_Tackled_per_90  \
# 87                    0.82                      0.61
#
#     Dribblers_Challenged_per_90  Dribblers_Tackle_Lost_per_90  Blocks_per_90  \
# 87                         1.54                          0.93           0.71
#
#     Shots_Blocked_per_90  Tackles+Interceptions_per_90  Clearances_per_90  \
# 87                   0.0                          1.71               0.21
#
#     Errors_Shots_per_90  Dribblers_Tackle_W%
# 87                 0.04                 39.5

# %%
import pandas as pd





params=['Goals_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90', 'xG_per90', 'xG+xAG_per90', 'npxG_per90',
        'npxG+xAG_per90', 'Take_Ons_Attempted', 'Take_Ons_Succ', 'Take_Ons_Succ%', 'Tackled_Take_Ons', 
        'Tackled_Take_Ons%', 'Touches_per_90', 'Touches_Def_Pen_per_90', 'Touches_Def_3rd_per_90', 
        'Touches_Mid_3rd_per_90', 'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
        'Take_Ons_Attempted_per_90', 'Take_Ons_Succ_per_90', 'Tackled_Take_Ons_per_90', 'Carries_per_90', 
        'Total_Distance_per_90', 'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90', 
        '1/3_Carries_per_90', 'Carries_Penalty_Area_per_90', 'Miscontrols_per_90', 'Dispossessed_per_90', 
        'Passes_Received_per_90', 'Progressive_Passes_Received_per_90', 'Shot_Creating_Action_per90', 
        'Goal_Creating_Action_90', 'Pass_Live_Shot_per_90', 'Pass_Dead_Shot_per_90', 'Take_Ons_Shot_per_90', 
        'Shot-Shot_per_90', 'Fouls_drawn_Shot_per_90', 'Defensive_Shot_per_90', 'Pass_Live_Goal_per_90',
        'Pass_Dead_Goal_per_90', 'Take_Ons_Goal_per_90', 'Shot_Goal_per_90', 'Fouls_Drawn_Goal_per_90', 
        'Defensive_Goal_per_90', 'Passes_Total_Cmp', 'Passes_Total_Att', 'Passes_Total_Cmp%', 'Passes_TotDist', 
        'Passes_PrgDist', 'Passes_Short_Cmp', 'Passes_Short_Att', 'Passes_Short_Cmp%', 'Passes_Medium_Cmp', 
        'Passes_Medium_Att', 'Passes_Medium_Cmp%', 'Passes_Long_Cmp', 'Passes_Long_Att', 'Passes_Long_Cmp%', 
        'Assists_per_90', 'xAG_per_90', 'xA_per_90', 'A-xAG_per_90', 'Key_Passes_per_90', 'Passes_1/3_per_90', 
        'Passes_Penalty_Area_per_90', 'Crosses_Penalty_Area_per_90', 'Progressive_Passes_per_90', 
        'Passes_Attempted_per_90', 'Live_Ball_Passes_per_90', 'Dead_Ball_Passes_per_90', 'Free_Kick_Passes_per_90',
        'Through_Balls_per_90', 'Switches_per_90', 'Crosses_per_90', 'Throw_Ins_Taken_per_90', 
        'Corner_Kicks_per_90', 'In_Corner_Kicks_per_90', 'Out_Corner_Kicks_per_90', 'Str_Corner_Kicks_per_90',
        'Passes_Cmp_per_90', 'Passes_Off_per_90', 'Passes_Blocked_per_90', 'Shots_total_per90', 
        'Shots_on_target_per90', 'Goals_per_shot', 'Goals_per_shot_on_target', 'Npxg_per_shot', 'Xg_net', 
        'Npxg_net', 'Percentage_of_Aerials_Won', 'Yellow_Cards_per_90', 'Red_Cards_per_90', 
        'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90', 'Fouls_Drawn_per_90', 'Offsides_per_90', 
        'Interceptions_per_90', 'Tackles_Won_per_90', 'Penalty_Kicks_Won_per_90', 'Penalty_Kicks_Conceded_per_90',
        'Ball_Recoveries_per_90', 'Aerials_Won_per_90', 'Aerials_Lost_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_2024_percentile_ranks = forward_players[params].rank(pct=True) * 100

# Get the row of Harry Kane's stats from the percentile ranks DataFrame
kvara_percentile_ranks = round(players_2024_percentile_ranks.iloc[[124]],0)

# Print the percentile ranks for Declan Rice
kvara_percentile_ranks
# Out:
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 124         61.0       77.0        62.0          78.0      40.0          70.0
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 124        44.0            73.0                94.0           93.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 124            41.0              95.0               51.0            93.0
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 124                     8.0                    65.0                    89.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 124                    96.0                    86.0
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 124                       93.0                       98.0
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 124                  96.0                     99.0            94.0
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 124                   94.0                                 93.0
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 124                        95.0                91.0
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 124                         96.0                16.0                 63.0
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 124                    95.0                                88.0
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 124                        87.0                     87.0
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 124                   91.0                   87.0                  97.0
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 124              97.0                     91.0                   93.0
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 124                   72.0                   86.0                  89.0
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 124              98.0                     96.0                   91.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 124              83.0              80.0               93.0            85.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 124            79.0              86.0              82.0               98.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 124               84.0               82.0                77.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 124             90.0             90.0              46.0            74.0
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 124        93.0       91.0          64.0               94.0
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 124               75.0                        86.0
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 124                         78.0                       81.0
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 124                     92.0                     91.0
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 124                     84.0                     87.0                  94.0
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 124             98.0            83.0                    93.0
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 124                 87.0                    88.0                     86.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 124                     46.0               92.0               47.0
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 124                   36.0               93.0                   76.0
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 124            92.0                      75.0           87.0    82.0
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 124      80.0                       40.0                 52.0
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 124              36.0                       43.0                    14.0
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 124                88.0              9.0                  64.0
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 124                80.0                      95.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 124                           41.0                    76.0
#
#      Aerials_Won_per_90  Aerials_Lost_per_90
# 124                 9.0                  7.0

# %%
import pandas as pd





params=['Goals_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90', 'xG_per90', 'xG+xAG_per90', 'npxG_per90',
        'npxG+xAG_per90', 'Take_Ons_Attempted', 'Take_Ons_Succ', 'Take_Ons_Succ%', 'Tackled_Take_Ons', 
        'Tackled_Take_Ons%', 'Touches_per_90', 'Touches_Def_Pen_per_90', 'Touches_Def_3rd_per_90', 
        'Touches_Mid_3rd_per_90', 'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
        'Take_Ons_Attempted_per_90', 'Take_Ons_Succ_per_90', 'Tackled_Take_Ons_per_90', 'Carries_per_90', 
        'Total_Distance_per_90', 'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90', 
        '1/3_Carries_per_90', 'Carries_Penalty_Area_per_90', 'Miscontrols_per_90', 'Dispossessed_per_90', 
        'Passes_Received_per_90', 'Progressive_Passes_Received_per_90', 'Shot_Creating_Action_per90', 
        'Goal_Creating_Action_90', 'Pass_Live_Shot_per_90', 'Pass_Dead_Shot_per_90', 'Take_Ons_Shot_per_90', 
        'Shot-Shot_per_90', 'Fouls_drawn_Shot_per_90', 'Defensive_Shot_per_90', 'Pass_Live_Goal_per_90',
        'Pass_Dead_Goal_per_90', 'Take_Ons_Goal_per_90', 'Shot_Goal_per_90', 'Fouls_Drawn_Goal_per_90', 
        'Defensive_Goal_per_90', 'Passes_Total_Cmp', 'Passes_Total_Att', 'Passes_Total_Cmp%', 'Passes_TotDist', 
        'Passes_PrgDist', 'Passes_Short_Cmp', 'Passes_Short_Att', 'Passes_Short_Cmp%', 'Passes_Medium_Cmp', 
        'Passes_Medium_Att', 'Passes_Medium_Cmp%', 'Passes_Long_Cmp', 'Passes_Long_Att', 'Passes_Long_Cmp%', 
        'Assists_per_90', 'xAG_per_90', 'xA_per_90', 'A-xAG_per_90', 'Key_Passes_per_90', 'Passes_1/3_per_90', 
        'Passes_Penalty_Area_per_90', 'Crosses_Penalty_Area_per_90', 'Progressive_Passes_per_90', 
        'Passes_Attempted_per_90', 'Live_Ball_Passes_per_90', 'Dead_Ball_Passes_per_90', 'Free_Kick_Passes_per_90',
        'Through_Balls_per_90', 'Switches_per_90', 'Crosses_per_90', 'Throw_Ins_Taken_per_90', 
        'Corner_Kicks_per_90', 'In_Corner_Kicks_per_90', 'Out_Corner_Kicks_per_90', 'Str_Corner_Kicks_per_90',
        'Passes_Cmp_per_90', 'Passes_Off_per_90', 'Passes_Blocked_per_90', 'Shots_total_per90', 
        'Shots_on_target_per90', 'Goals_per_shot', 'Goals_per_shot_on_target', 'Npxg_per_shot', 'Xg_net', 
        'Npxg_net', 'Percentage_of_Aerials_Won', 'Yellow_Cards_per_90', 'Red_Cards_per_90', 
        'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90', 'Fouls_Drawn_per_90', 'Offsides_per_90', 
        'Interceptions_per_90', 'Tackles_Won_per_90', 'Penalty_Kicks_Won_per_90', 'Penalty_Kicks_Conceded_per_90',
        'Ball_Recoveries_per_90', 'Aerials_Won_per_90', 'Aerials_Lost_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_2023_percentile_ranks = player_2023[params].rank(pct=True) * 100

# Get the row of Harry Kane's stats from the percentile ranks DataFrame
kvara_2023_percentile_ranks = round(players_2023_percentile_ranks.iloc[[87]],0)

# Print the percentile ranks for Declan Rice
kvara_2023_percentile_ranks
# Out:
#     Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 87         64.0       88.0        60.0          88.0      32.0          67.0
#
#     npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 87        24.0            69.0                98.0           98.0
#
#     Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 87            30.0              99.0               76.0            94.0
#
#     Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 87                     8.0                    77.0                    74.0
#
#     Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 87                    97.0                    87.0                       94.0
#
#     Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 87                       98.0                  95.0                    100.0
#
#     Carries_per_90  Total_Distance_per_90  \
# 87            95.0                   95.0
#
#     Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 87                                 96.0                        95.0
#
#     1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 87                89.0                         98.0                29.0
#
#     Dispossessed_per_90  Passes_Received_per_90  \
# 87                 68.0                    94.0
#
#     Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 87                                90.0                        85.0
#
#     Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 87                     90.0                   94.0                   87.0
#
#     Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 87                  98.0              92.0                     80.0
#
#     Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 87                   84.0                   86.0                   94.0
#
#     Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 87                  87.0             100.0                     99.0
#
#     Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 87                   47.0              95.0              96.0
#
#     Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 87               88.0            96.0            90.0              97.0
#
#     Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  Passes_Medium_Att  \
# 87              96.0               99.0               94.0               94.0
#
#     Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  \
# 87                62.0             96.0             94.0              41.0
#
#     Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 87            46.0        95.0       94.0          86.0               92.0
#
#     Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 87               77.0                        89.0
#
#     Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 87                         88.0                       85.0
#
#     Passes_Attempted_per_90  Live_Ball_Passes_per_90  Dead_Ball_Passes_per_90  \
# 87                     93.0                     94.0                     68.0
#
#     Free_Kick_Passes_per_90  Through_Balls_per_90  Switches_per_90  \
# 87                     89.0                  97.0             96.0
#
#     Crosses_per_90  Throw_Ins_Taken_per_90  Corner_Kicks_per_90  \
# 87            89.0                    93.0                 89.0
#
#     In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  Str_Corner_Kicks_per_90  \
# 87                    89.0                     90.0                     48.0
#
#     Passes_Cmp_per_90  Passes_Off_per_90  Passes_Blocked_per_90  \
# 87               93.0               59.0                   38.0
#
#     Shots_total_per90  Shots_on_target_per90  Goals_per_shot  \
# 87               67.0                   58.0            44.0
#
#     Goals_per_shot_on_target  Npxg_per_shot  Xg_net  Npxg_net  \
# 87                      48.0            6.0    96.0      94.0
#
#     Percentage_of_Aerials_Won  Yellow_Cards_per_90  Red_Cards_per_90  \
# 87                       43.0                 10.0              43.0
#
#     Second_Yellow_Card_per_90  Fouls_Committed_per_90  Fouls_Drawn_per_90  \
# 87                       47.0                    12.0                62.0
#
#     Offsides_per_90  Interceptions_per_90  Tackles_Won_per_90  \
# 87             13.0                  43.0                88.0
#
#     Penalty_Kicks_Won_per_90  Penalty_Kicks_Conceded_per_90  \
# 87                      99.0                           46.0
#
#     Ball_Recoveries_per_90  Aerials_Won_per_90  Aerials_Lost_per_90
# 87                    84.0                 6.0                  5.0

# %%
# Extract the percentile ranks, transpose, and sort them in descending order
kvara_percentile_ranks_sorted = kvara_percentile_ranks.T.sort_values(by=124, ascending=False)

# Get the top 20 parameters
top_20_params = kvara_percentile_ranks_sorted.index[:30]
top_20_params_values = kvara_percentile_ranks_sorted[124].head(30)

# Display the top 20 parameters and their values
print("Top 20 Parameters:")
print(top_20_params)
print("Values:")
print(top_20_params_values)
# Out:
# Top 20 Parameters:
# Index(['Tackled_Take_Ons_per_90', 'Take_Ons_Attempted_per_90',
#        'Shot_Goal_per_90', 'Switches_per_90', 'Passes_Short_Cmp%',
#        'Shot-Shot_per_90', 'Take_Ons_Shot_per_90', 'Touches_Att_3rd_per_90',
#        'Carries_Penalty_Area_per_90', 'Take_Ons_Succ_per_90',
#        'Fouls_Drawn_Goal_per_90', 'Passes_Received_per_90',
#        'Progressive_Carries_per_90', 'Penalty_Kicks_Won_per_90',
#        'Tackled_Take_Ons', 'Take_Ons_Attempted', 'Key_Passes_per_90',
#        'Through_Balls_per_90', 'Total_Distance_per_90', 'Carries_per_90',
#        'Passes_Total_Cmp%', 'Progressive_Distance_Carried_per_90',
#        'Shots_total_per90', 'Defensive_Shot_per_90',
#        'Tocuhes_Live_Balls_per_90', 'xAG_per_90', 'Throw_Ins_Taken_per_90',
#        'Take_Ons_Succ', 'Touches_per_90', 'Goals_per_shot'],
#       dtype='object')
# Values:
# Tackled_Take_Ons_per_90                99.0
# Take_Ons_Attempted_per_90              98.0
# Shot_Goal_per_90                       98.0
# Switches_per_90                        98.0
# Passes_Short_Cmp%                      98.0
# Shot-Shot_per_90                       97.0
# Take_Ons_Shot_per_90                   97.0
# Touches_Att_3rd_per_90                 96.0
# Carries_Penalty_Area_per_90            96.0
# Take_Ons_Succ_per_90                   96.0
# Fouls_Drawn_Goal_per_90                96.0
# Passes_Received_per_90                 95.0
# Progressive_Carries_per_90             95.0
# Penalty_Kicks_Won_per_90               95.0
# Tackled_Take_Ons                       95.0
# Take_Ons_Attempted                     94.0
# Key_Passes_per_90                      94.0
# Through_Balls_per_90                   94.0
# Total_Distance_per_90                  94.0
# Carries_per_90                         94.0
# Passes_Total_Cmp%                      93.0
# Progressive_Distance_Carried_per_90    93.0
# Shots_total_per90                      93.0
# Defensive_Shot_per_90                  93.0
# Tocuhes_Live_Balls_per_90              93.0
# xAG_per_90                             93.0
# Throw_Ins_Taken_per_90                 93.0
# Take_Ons_Succ                          93.0
# Touches_per_90                         93.0
# Goals_per_shot                         92.0
# Name: 124, dtype: float64

# %%
params = [
    "G+A_per90",           # 99%
    "Take_Ons_Attempted_per_90",         # 98%
    "Take_Ons_Succ_per_90",              # 96%
    "Carries_Penalty_Area_per_90",       # 96%
    "Progressive_Carries_per_90",        # 95%
    "Shot_Goal_per_90",                  # 98%
    "Shot_Creating_Action_per90",              # 97%
    "Goal_Creating_Action_90",           # 96%
    "Key_Passes_per_90",                 # 94%
    "xAG_per_90",                        # 93%
    "Passes_Penalty_Area_per_90",                 # 98%
    "Passes_Received_per_90",            # 95%
    "Through_Balls_per_90",                   # 98%
    "Touches_Att_3rd_per_90",            # 96%
    "Progressive_Passes_per_90"              # 94%
]


# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = forward_players[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
kvara_percentile_ranks = round(players_percentile_ranks.iloc[[124]],0)

# Print the percentile ranks for Harry Kane
kvara_percentile_ranks
# Out:
#      G+A_per90  Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  \
# 124       77.0                       98.0                  96.0
#
#      Carries_Penalty_Area_per_90  Progressive_Carries_per_90  \
# 124                         96.0                        95.0
#
#      Shot_Goal_per_90  Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 124              98.0                        87.0                     87.0
#
#      Key_Passes_per_90  xAG_per_90  Passes_Penalty_Area_per_90  \
# 124               94.0        93.0                        86.0
#
#      Passes_Received_per_90  Through_Balls_per_90  Touches_Att_3rd_per_90  \
# 124                    95.0                  94.0                    96.0
#
#      Progressive_Passes_per_90
# 124                       81.0

# %%
kvara_percentile_ranks_list = kvara_percentile_ranks.values.flatten().tolist()

kvara_percentile_ranks_list
# Out:
# [77.0,
#  98.0,
#  96.0,
#  96.0,
#  95.0,
#  98.0,
#  87.0,
#  87.0,
#  94.0,
#  93.0,
#  86.0,
#  95.0,
#  94.0,
#  96.0,
#  81.0]

# %%
params = [
    "G+A_per90",           # 99%
    "Take_Ons_Attempted_per_90",         # 98%
    "Take_Ons_Succ_per_90",              # 96%
    "Carries_Penalty_Area_per_90",       # 96%
    "Progressive_Carries_per_90",        # 95%
    "Shot_Goal_per_90",                  # 98%
    "Shot_Creating_Action_per90",              # 97%
    "Goal_Creating_Action_90",           # 96%
    "Key_Passes_per_90",                 # 94%
    "xAG_per_90",                        # 93%
    "Passes_Penalty_Area_per_90",                 # 98%
    "Passes_Received_per_90",            # 95%
    "Through_Balls_per_90",                   # 98%
    "Touches_Att_3rd_per_90",            # 96%
    "Progressive_Passes_per_90"              # 94%
]



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2023[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
kvara_2023_percentile_ranks = round(players_percentile_ranks.iloc[[87]],0)

# Print the percentile ranks for Harry Kane
kvara_2023_percentile_ranks
# Out:
#     G+A_per90  Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  \
# 87       88.0                       98.0                  95.0
#
#     Carries_Penalty_Area_per_90  Progressive_Carries_per_90  Shot_Goal_per_90  \
# 87                         98.0                        95.0             100.0
#
#     Shot_Creating_Action_per90  Goal_Creating_Action_90  Key_Passes_per_90  \
# 87                        85.0                     90.0               92.0
#
#     xAG_per_90  Passes_Penalty_Area_per_90  Passes_Received_per_90  \
# 87        95.0                        89.0                    94.0
#
#     Through_Balls_per_90  Touches_Att_3rd_per_90  Progressive_Passes_per_90
# 87                  97.0                    97.0                       85.0

# %%
kvara_2023_percentile_ranks_list = kvara_2023_percentile_ranks.values.flatten().tolist()

kvara_2023_percentile_ranks_list
# Out:
# [88.0,
#  98.0,
#  95.0,
#  98.0,
#  95.0,
#  100.0,
#  85.0,
#  90.0,
#  92.0,
#  95.0,
#  89.0,
#  94.0,
#  97.0,
#  97.0,
#  85.0]

# %%
image_path = "Kvara.jpg"
fdj_cropped = Image.open(image_path)

# %%
params = [
    "Goals_+_Assists_per90",           # 99%
    "Take_Ons_Attempted_per90",         # 98%
    "Take_Ons_Succesful_per90",              # 96%
    "Carries_Penalty_Area_per90",       # 96%
    "Progressive_Carries_per90",        # 95%
    "Shot_That_Leads_To_Goal_per90",                  # 98%
    "Shot_Creating_Action_per90",              # 97%
    "Goal_Creating_Action_per90",           # 96%
    "Key_Passes_per90",                 # 94%
    "Expected_Asssited_Goals_per90",                        # 93%
    "Passes_Penalty_Area_per90",                 # 98%
    "Passes_Received_per90",            # 95%
    "Through_Balls_per90",                   # 98%
    "Touches_Attacking_Third_per90",            # 96%
    "Progressive_Passes_per90"              # 94%
]


split_params = [param.replace('_', '\n') for param in params]

# %%
params = [
    "G+A_per90",           # 99%
    "Take_Ons_Attempted_per_90",         # 98%
    "Take_Ons_Succ_per_90",              # 96%
    "Carries_Penalty_Area_per_90",       # 96%
    "Progressive_Carries_per_90",        # 95%
    "Shot_Goal_per_90",                  # 98%
    "Shot_Creating_Action_per90",              # 97%
    "Goal_Creating_Action_90",           # 96%
    "Key_Passes_per_90",                 # 94%
    "xAG_per_90",                        # 93%
    "Passes_Penalty_Area_per_90",                 # 98%
    "Passes_Received_per_90",            # 95%
    "Through_Balls_per_90",                   # 98%
    "Touches_Att_3rd_per_90",            # 96%
    "Progressive_Passes_per_90"              # 94%
]

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    kvara_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Khvicha Kvaratskhelia - SSC Napoli", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Serie A Stats Percentile Rank vs Top-Five Leagues Forwards | Last Seasons",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Kvara_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    kvara_2023_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Khvicha Kvaratskhelia - SSC Napoli", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Serie A Stats Percentile Rank vs Top-Five Leagues Forwards | 2022-23 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Kvara_2023_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
# Extract the percentile ranks, transpose, and sort them in descending order
kvara_percentile_ranks_2023_sorted = kvara_2023_percentile_ranks.T.sort_values(by=87, ascending=False)

# Get the top 20 parameters
top_20_params = kvara_percentile_ranks_2023_sorted.index[:30]
top_20_params_values = kvara_percentile_ranks_2023_sorted[87].head(30)

# Display the top 20 parameters and their values
print("Top 20 Parameters:")
print(top_20_params)
print("Values:")
print(top_20_params_values)
# Out:
# Top 20 Parameters:
# Index(['Shot_Goal_per_90', 'Take_Ons_Attempted_per_90',
#        'Carries_Penalty_Area_per_90', 'Through_Balls_per_90',
#        'Touches_Att_3rd_per_90', 'Take_Ons_Succ_per_90',
#        'Progressive_Carries_per_90', 'xAG_per_90', 'Passes_Received_per_90',
#        'Key_Passes_per_90', 'Goal_Creating_Action_90',
#        'Passes_Penalty_Area_per_90', 'G+A_per90', 'Shot_Creating_Action_per90',
#        'Progressive_Passes_per_90'],
#       dtype='object')
# Values:
# Shot_Goal_per_90               100.0
# Take_Ons_Attempted_per_90       98.0
# Carries_Penalty_Area_per_90     98.0
# Through_Balls_per_90            97.0
# Touches_Att_3rd_per_90          97.0
# Take_Ons_Succ_per_90            95.0
# Progressive_Carries_per_90      95.0
# xAG_per_90                      95.0
# Passes_Received_per_90          94.0
# Key_Passes_per_90               92.0
# Goal_Creating_Action_90         90.0
# Passes_Penalty_Area_per_90      89.0
# G+A_per90                       88.0
# Shot_Creating_Action_per90      85.0
# Progressive_Passes_per_90       85.0
# Name: 87, dtype: float64

# %%
from sklearn.decomposition import PCA
import numpy as np

# Identify features to minimize
negative_features = ['Yellow_Cards_per_90', 'Red_Cards_per_90', 'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90',
                     'Aerials_Lost_per_90','Miscontrols_per_90','Dispossessed_per_90','Penalty_Kicks_Conceded_per_90']

# Reverse the sign of negative features
for feature in negative_features:
    if feature in forward_players.columns:
        forward_players[feature]=-forward_players[feature]

# %%
# Normalize data
numerical_forward_players = forward_players[params].replace([np.inf, -np.inf], 0)
normalized_forward_players = (numerical_forward_players - numerical_forward_players.mean()) / numerical_forward_players.std()

# Apply PCA
pca = PCA()
pca.fit(normalized_forward_players)
explained_variances = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variances >= 0.95) + 1

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
transformed_players = pca.fit_transform(normalized_forward_players)

# Convert transformed data back to DataFrame
transformed_df = pd.DataFrame(transformed_players, index=forward_players.index)

# %%
# Get Kvara's row and compute cosine similarity
kvara_index = forward_players.index[forward_players['Player'] == 'Khvicha Kvaratskhelia'][0]
kvara_data = transformed_df.loc[kvara_index].values.reshape(1, -1)

# Remove Kvara from the dataset for comparison
transformed_df = transformed_df.drop(index=kvara_index)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(transformed_df, kvara_data).flatten()
transformed_df['similarity_to_kvara'] = similarity_scores

# Get top 10 players most similar to kvara
top_similar_players_indices = transformed_df.sort_values('similarity_to_kvara', ascending=False).index
top_similar_players = forward_players.loc[top_similar_players_indices]

# %%
# Visualize the resultsa
forward_players['similarity_to_kvara'] = transformed_df['similarity_to_kvara']
forward_players_sorted = forward_players.sort_values(by='similarity_to_kvara', ascending=False)
forward_players_sorted
# Out:
#      Unnamed: 0                     Player   Nation Pos  \
# 77          609         Gabriel Martinelli   br BRA  FW
# 19          139            Vinicius Júnior   br BRA  FW
# 58          451              Gabriel Jesus   br BRA  FW
# 163        1518            Mykhailo Mudryk   ua UKR  FW
# 102         776               Kaoru Mitoma   jp JPN  FW
# 108                                       Monaco+Reims
# 85                               Osasuna+Betis+Osasuna
# 143                                             Girona
# 16                                       Granada+Elche
# 141                                              Betis
# 81                                               Milan
# 130                                            Burnley
# 83                                           Brentford
# 44   Empoli+Sampdoria+Empoli+Sampdoria+Sassuolo+Sas...
# 32                                        Lyon+Arsenal
# 15                   Almería+Almería+Marseille+Granada
# 55                   Stuttgart+Rennes+Stuttgart+Rennes
# 185                                         Hoffenheim
# 120               Werder Bremen+Dortmund+Werder Bremen
# 1                                        Newcastle Utd
# 168                                           Cagliari
# 175                                      Real Sociedad
# 121                              Nantes+Auxerre+Rennes
# 72                        Montpellier+Lens+Montpellier
# 68                           Nice+Nice+Lorient+Lorient
# 154                                              Lecce
# 86                                               Brest
# 140                                              Reims
# 57                                              Napoli
# 133                                            Lorient
# 137                                             Bochum
# 155                                           Le Havre
# 23               Juventus+Juventus+Marseille+Marseille
# 63                                               Lille
# 160                                     Crystal Palace
# 99                                             Arsenal
# 177                                         RB Leipzig
# 11                                   Brentford+Lorient
# 28                         Fiorentina+Roma+Roma+Torino
# 181                                           Augsburg
# 46                                   Fiorentina+Spezia
# 89                        Werder Bremen+Eint Frankfurt
# 94                                        Lazio+Girona
# 76                                   Freiburg+Augsburg
# 116                                  Las Palmas+Getafe
# 171                                          Paris S-G
# 33                                             Everton
# 22             Mainz 05+Strasbourg+Mainz 05+Strasbourg
# 147                                              Cádiz
# 173                                             Fulham
# 13                                               Brest
# 145                                         Strasbourg
# 197                                Lille+Clermont Foot
# 87                             Everton+Udinese+Udinese
# 195                                     Alavés+Granada
# 148                                        Salernitana
# 156                                           Cagliari
# 112                Wolfsburg+Union Berlin+Union Berlin
# 73                            Valencia+Getafe+Valencia
# 70                             Mallorca+Lazio+Mallorca
# 103                                        Bournemouth
# 95                                       Clermont Foot
# 14                    Atalanta+West Ham+Sassuolo+Genoa
# 101                                Mallorca+Valladolid
# 123                                      Athletic Club
# 127                                        Montpellier
# 142                                         Celta Vigo
# 182                                     Rayo Vallecano
# 164                                             Fulham
# 53                                          Leverkusen
# 111                                     Rayo Vallecano
# 92                                            Toulouse
# 84                            Brest+Empoli+Inter+Brest
# 105                                            Almería
# 18                        Nott'ham Forest+Union Berlin
# 138                                          Frosinone
# 60                 Getafe+Roma+Getafe+Roma+Real Madrid
# 64                                             Osasuna
# 51                  Brentford+Everton+Everton+Brighton
# 52                         Real Madrid+Espanyol+Alavés
# 24                                             Sevilla
# 196                                       Empoli+Lecce
# 100                            Manchester Utd+Atalanta
# 78                     Köln+Hertha BSC+Köln+Hertha BSC
# 115                 Gladbach+Union Berlin+Union Berlin
# 107                                             Bochum
# 157                                             Getafe
# 132                                           Le Havre
# 110                                        Monza+Lecce
# 189                                           Valencia
# 80                                     Sassuolo+Empoli
# 169                                         RB Leipzig
# 152                                         Heidenheim
# 97                                              Nantes
# 106                                         Celta Vigo
# 183                                            Granada
# 40                           Cádiz+Elche+Cádiz+Levante
# 158                                            Udinese
# 88       Hellas Verona+Monza+Hellas Verona+Salernitana
# 144                                              Genoa
# 133            -0.512329
# 137            -0.518573
# 155            -0.521419
# 23             -0.535744
# 63             -0.540233
# 160            -0.550327
# 99             -0.552705
# 177            -0.564399
# 11             -0.565094
# 28             -0.566053
# 181            -0.569005
# 46             -0.570383
# 89             -0.572098
# 94             -0.574868
# 76             -0.581891
# 116            -0.600812
# 171            -0.602427
# 33             -0.603236
# 22             -0.609925
# 147            -0.615009
# 173            -0.619323
# 13             -0.621858
# 145            -0.637988
# 197            -0.638121
# 87             -0.639225
# 195            -0.650816
# 148            -0.659499
# 156            -0.665665
# 112            -0.666338
# 73             -0.666841
# 70             -0.686311
# 103            -0.687163
# 95             -0.731196
# 14             -0.737266
# 101            -0.744673
# 123            -0.745196
# 127            -0.750074
# 142            -0.750886
# 182            -0.752769
# 164            -0.754544
# 53             -0.761789
# 111            -0.765120
# 92             -0.765426
# 84             -0.771090
# 105            -0.780448
# 18             -0.786362
# 138            -0.786679
# 60             -0.803420
# 64             -0.812118
# 51             -0.812320
# 52             -0.813843
# 24             -0.825041
# 196            -0.831826
# 100            -0.835301
# 78             -0.835605
# 115            -0.839608
# 107            -0.842931
# 157            -0.844808
# 132            -0.845041
# 110            -0.849293
# 189            -0.849662
# 80             -0.860089
# 169            -0.860106
# 152            -0.865508
# 97             -0.865997
# 106            -0.869101
# 183            -0.873650
# 40             -0.884051
# 158            -0.885003
# 88             -0.885208
# 144            -0.894189
# 187            -0.895613
# 151            -0.896907
# 174            -0.901330
# 161            -0.907926
# 114            -0.932401
# 172            -0.935544
# 165            -0.973782
# 124                  NaN

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=12)

# Use a dark background
plt.style.use('dark_background')

# Sort the forward_players DataFrame by similarity_to_rice in descending order
forward_players_sorted = forward_players.sort_values(by='similarity_to_kvara', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart, but reverse the order of the data
bars = ax.barh(forward_players_sorted['Player'].head(20)[::-1], (forward_players_sorted['similarity_to_kvara'].head(20)*100)[::-1],
               color=plt.cm.viridis(np.linspace(0, 1, 10)))

# Add labels and title
ax.set_xlabel('Similarity Percentage', fontproperties=font_prop)
ax.set_ylabel('Player', fontproperties=font_prop)
ax.set_title('Who is most similar to Kvaratskhelia from top 5 leagues based on the last 4 seasons ?', fontproperties=font_prop)

# Set the y-axis tick labels with the custom font
ax.set_yticklabels(forward_players_sorted['Player'].head(20)[::-1], fontproperties=font_prop)

# Remove gridlines
ax.grid(False)

# Make the top and right spines invisible
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make the left and bottom spines white
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

# Change the color of ticks to white
ax.tick_params(colors='white')

# Change the color of labels to white
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')

# Add percentage labels to the bars
for bar in bars:
    width = bar.get_width()
    y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, y_pos, f'{width:.1f}%', ha='left', va='center',
            color='white', fontproperties=font_prop)


# Save the figure
plt.savefig('Similar.png' ,dpi=500,bbox_inches = 'tight',transparent=False)

plt.show()

# %%
Martinelli=forward_players[forward_players['Player']=='Gabriel Martinelli']
Martinelli
# Out:
#     Unnamed: 0              Player  Nation Pos    Squad                Comp  \
# 77         609  Gabriel Martinelli  br BRA  FW  Arsenal  eng Premier League
#
#     Age    Born     MP  Starts   Min   90s  Goals_per90  G+A_per90  \
# 77  0.0  2001.0  100.0    79.0  6668  74.1         0.36       0.57
#
#     G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 77        0.35          0.56      0.32          0.58        0.31
#
#     npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 77            0.57               325.0          144.0            44.0
#
#     Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 77             150.0               46.0           48.97
#
#     Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 77                    0.76                    4.41                   13.36
#
#     Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 77                   31.92                    7.23                      48.96
#
#     Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 77                       4.39                  1.94                     2.02
#
#     Carries_per_90  Total_Distance_per_90  \
# 77           32.78                 232.75
#
#     Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 77                               112.49                        4.45
#
#     1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 77                1.97                         2.63               -2.63
#
#     Dispossessed_per_90  Passes_Received_per_90  \
# 77                -1.77                   35.95
#
#     Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 77                               12.17                        3.93
#
#     Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 77                     0.55                    2.7                   0.24
#
#     Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 77                  0.44              0.38                     0.09
#
#     Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 77                    2.7                   0.31                   0.04
#
#     Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 77                  0.07              0.13                      0.0
#
#     Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 77                    0.0            1996.0            2647.0
#
#     Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 77               75.0         30728.0          5853.0            1123.0
#
#     Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  Passes_Medium_Att  \
# 77            1320.0               85.0              682.0              798.0
#
#     Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  \
# 77                80.0            137.0            270.0              51.0
#
#     Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 77            0.05        0.26       0.21         -0.06               1.87
#
#     Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 77               0.89                        1.24
#
#     Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 77                         0.29                       2.64
#
#     Passes_Attempted_per_90  Live_Ball_Passes_per_90  Dead_Ball_Passes_per_90  \
# 77                    35.72                    33.17                      2.4
#
#     Free_Kick_Passes_per_90  Through_Balls_per_90  Switches_per_90  \
# 77                     0.24                  0.22             0.08
#
#     Crosses_per_90  Throw_Ins_Taken_per_90  Corner_Kicks_per_90  \
# 77             4.0                     0.4                 1.73
#
#     In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  Str_Corner_Kicks_per_90  \
# 77                    1.34                      0.0                      0.0
#
#     Passes_Cmp_per_90  Passes_Off_per_90  Passes_Blocked_per_90  \
# 77              26.94               0.15                   1.31
#
#     Shots_total_per90  Shots_on_target_per90  Goals_per_shot  \
# 77               2.54                   0.88            3.54
#
#     Goals_per_shot_on_target  Npxg_per_shot  Xg_net  Npxg_net  \
# 77                      10.4            3.0     3.6       3.3
#
#     Percentage_of_Aerials_Won  Yellow_Cards_per_90  Red_Cards_per_90  \
# 77                       26.0                -0.09             -0.01
#
#     Second_Yellow_Card_per_90  Fouls_Committed_per_90  Fouls_Drawn_per_90  \
# 77                      -0.01                   -1.16                1.09
#
#     Offsides_per_90  Interceptions_per_90  Tackles_Won_per_90  \
# 77             0.36                  0.46                0.82
#
#     Penalty_Kicks_Won_per_90  Penalty_Kicks_Conceded_per_90  \
# 77                       0.0                           -0.0
#
#     Ball_Recoveries_per_90  Aerials_Won_per_90  Aerials_Lost_per_90  \
# 77                    3.83                0.63                -1.79
#
#     Tackles_per_90  Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  \
# 77            1.19                    0.39                    0.52
#
#     Tackles_Att_3rd_per_90  Dribblers_Tackled_per_90  \
# 77                    0.28                      0.43
#
#     Dribblers_Challenged_per_90  Dribblers_Tackle_Lost_per_90  Blocks_per_90  \
# 77                         1.12                          0.69           0.99
#
#     Shots_Blocked_per_90  Tackles+Interceptions_per_90  Clearances_per_90  \
# 77                  0.04                          1.65               0.51
#
#     Errors_Shots_per_90  Dribblers_Tackle_W%  Seasons at top 5  Seasons in PL  \
# 77                 0.01                39.02                 3              3
#
#     Seasons in Liga  Seasons in Serie A  Seasons in Ligue 1  \
# 77                0                   0                   0
#
#     Seasons in Bundesliga  similarity_to_kvara
# 77                      0             0.950467

# %%
# Calculate percentile ranks for players in the larger DataFrame
players_percentile_ranks = forward_players[params].rank(pct=True) * 100

# Get the row of Ndayishimiye's stats from the percentile ranks DataFrame
Martinelli_percentile_ranks = round(players_percentile_ranks.iloc[[77]], 0)

# Print the percentile ranks for schlotterbeck
Martinelli_percentile_ranks
# Out:
#     G+A_per90  Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  \
# 77       64.0                       82.0                  82.0
#
#     Carries_Penalty_Area_per_90  Progressive_Carries_per_90  Shot_Goal_per_90  \
# 77                         95.0                        88.0              97.0
#
#     Shot_Creating_Action_per90  Goal_Creating_Action_90  Key_Passes_per_90  \
# 77                        77.0                     78.0               90.0
#
#     xAG_per_90  Passes_Penalty_Area_per_90  Passes_Received_per_90  \
# 77        95.0                        78.0                    85.0
#
#     Through_Balls_per_90  Touches_Att_3rd_per_90  Progressive_Passes_per_90
# 77                  79.0                    95.0                       71.0

# %%
Martinelli_percentile_ranks_list = Martinelli_percentile_ranks.values.flatten().tolist()
Martinelli_percentile_ranks_list
# Out:
# [64.0,
#  82.0,
#  82.0,
#  95.0,
#  88.0,
#  97.0,
#  77.0,
#  78.0,
#  90.0,
#  95.0,
#  78.0,
#  85.0,
#  79.0,
#  95.0,
#  71.0]

# %%
image_path = "Martinelli.jpg"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    Martinelli_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Gabriel Martinelli - Arsenal", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Premier League Stats Percentile Rank vs Top-Five Leagues Forwards | Last 4 Seasons",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Martinelli_Percentile.png',dpi=500, bbox_inches='tight', facecolor=fig.get_facecolor(), edgecolor='none')  # save as png

# %%
player_2024 = player_2024[player_2024['Player'] != 'Khvicha Kvaratskhelia']
player_2024
# Out:
#       Unnamed: 0             Player   Nation    Pos                  Squad  \
# 0              0         Max Aarons  eng ENG     DF            Bournemouth
# 1              1   Brenden Aaronson   us USA  MF,FW           Union Berlin
# 2              4   Yunis Abdelhamid   ma MAR     DF                  Reims
# 3              5  Salis Abdul Samed   gh GHA     MF                   Lens
# 4              7    Laurent Abergel   fr FRA     MF                Lorient
# ...          ...                ...      ...    ...                    ...
# 1492         134  Alessandro Zanoli   it ITA  DF,FW     Salernitana+Napoli
# 1493         135       Duván Zapata   co COL     FW        Torino+Atalanta
# 1494         136     Bryan Zaragoza   es ESP  FW,MF  Granada+Bayern Munich
# 1495         138       Nadir Zortea   it ITA     DF     Frosinone+Atalanta
# 1496         139        Milan Đurić   ba BIH     FW    Hellas Verona+Monza
#
#                           Comp  Age    Born  MP  Starts   Min   90s  \
# 0           eng Premier League  0.0  2000.0  20      13  1237  13.7
# 1                de Bundesliga  0.0  2000.0  30      14  1267  14.1
# 2                   fr Ligue 1  0.0  1987.0  31      31  2781  30.9
#
#       Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                             2.70               1.97                 0.00
# 1                             2.41               0.28                 0.00
# 2                             3.33               3.53                 0.06
# 3                             1.95               1.07                 0.00
# 4                             4.59               1.92                 0.09
# ...                            ...                ...                  ...
# 1492                          1.76               1.67                 0.00
# 1493                          0.75               0.81                 0.00
# 1494                          1.34               0.15                 0.00
# 1495                          1.97               2.04                 0.06
# 1496                          0.26               1.46                 0.00
#
#       Dribblers_Tackle_W%
# 0                    58.8
# 1                    50.0
# 2                    57.8
# 3                    44.4
# 4                    39.6
# ...                   ...
# 1492                 58.0
# 1493                 23.0
# 1494                 42.0
# 1495                 42.0
# 1496                 29.0
#
# [1496 rows x 131 columns]

# %%
player_2024=pd.concat([player_2024,Kvara_2023])
player_2024=player_2024.reset_index(drop=True)
player_2024
# Out:
#       Unnamed: 0                 Player   Nation    Pos  \
# 0              0             Max Aarons  eng ENG     DF
# 1              1       Brenden Aaronson   us USA  MF,FW
# 2              4       Yunis Abdelhamid   ma MAR     DF
# 3              5      Salis Abdul Samed   gh GHA     MF
# 4              7        Laurent Abergel   fr FRA     MF
# ...          ...                    ...      ...    ...
# 1492         135           Duván Zapata   co COL     FW
# 1493         136         Bryan Zaragoza   es ESP  FW,MF
# 1494         138           Nadir Zortea   it ITA     DF
# 1495         139            Milan Đurić   ba BIH     FW
# 1496        1444  Khvicha Kvaratskhelia   ge GEO     FW
#
#                       Squad                      Comp   Age    Born  MP  \
# 0               Bournemouth        eng Premier League   0.0  2000.0  20
# 1              Union Berlin             de Bundesliga   0.0  2000.0  30
# 2                     Reims                fr Ligue 1   0.0  1987.0  31
# 3                      Lens                fr Ligue 1   0.0  2000.0  27
# 4                   Lorient                fr Ligue 1   0.0  1993.0  33
# ...                     ...                       ...   ...     ...  ..
# 1492        Torino+Atalanta                it Serie A   0.0  1991.0  37
# 1493  Granada+Bayern Munich  es La Liga+de Bundesliga   0.0  2001.0  28
# 1494     Frosinone+Atalanta                it Serie A   0.0  1999.0  19
# 1495    Hellas Verona+Monza                it Serie A   0.0  1990.0  37
# 1496                 Napoli                it Serie A  21.0  2001.0  34
#
#       Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  \
# 0         13  1237  13.7         0.00       0.07        0.00          0.07
# 1         14  1267  14.1         0.14       0.28        0.14          0.28
# 2         31  2781  30.9         0.13       0.13        0.10          0.10
# 3         17  1519  16.9         0.00       0.00        0.00          0.00
# 4         32  2860  31.8         0.06       0.09        0.06          0.09
# ...      ...   ...   ...          ...        ...         ...           ...
# 1492      36  2992  33.2         0.39       0.51        0.39          0.51
# 1493      19  1821  20.2         0.30       0.40        0.25          0.35
# 1494      14  1407  15.7         0.13       0.45        0.13          0.45
# 1495      26  2461  27.4         0.33       0.40        0.29          0.36
# 1496      30  2518  28.0         0.43       0.79        0.36          0.71
#
#       xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 0         0.00          0.06        0.00            0.06                34.0
# 1         0.14          0.27        0.14            0.27                77.0
# 2         0.11          0.12        0.09            0.09                15.0
# 3         0.05          0.08        0.05            0.08                19.0
# 4         0.04          0.10        0.04            0.10                65.0
# ...        ...           ...         ...             ...                 ...
# 1492      0.34          0.44        0.34            0.44               114.0
# 1493      0.21          0.32        0.17            0.27               145.0
# 1494      0.03          0.19        0.03            0.19                52.0
# 1495      0.27          0.39        0.19            0.21                 7.0
# 1496      0.29          0.56        0.23            0.51               199.0
#
#       Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 0              14.0            41.2              12.0               35.3
# 1              34.0            44.2              41.0               53.2
# 2               8.0            53.3               7.0               46.7
# 3               7.0            36.8              11.0               57.9
# 4              44.0            67.7              18.0               27.7
# ...             ...             ...               ...                ...
# 1492           38.0            33.0              63.0               55.0
# 1493           61.0            42.0              73.0               50.0
# 1494           22.0            42.0              25.0               48.0
# 1495            4.0            57.0               3.0               43.0
# 1496           75.0            37.7             107.0               53.8
#
#       Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 0              51.90                    3.14                   18.39
# 1              47.87                    0.78                    7.66
# 2              70.71                    9.48                   31.59
# 3              60.47                    1.24                    9.94
# 4              68.05                    3.30                   17.39
# ...              ...                     ...                     ...
# 1492           38.64                    1.11                    2.65
# 1493           39.46                    0.05                    3.71
# 1494           53.69                    2.04                   11.46
# 1495           29.27                    1.68                    3.36
# 1496           55.29                    0.29                    3.93
#
#       Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                      22.12                   12.04                    0.80
# 1                      21.35                   20.78                    3.33
# 2                      36.21                    3.69                    1.13
# 3                      38.28                   12.90                    0.41
# 4                      40.50                   10.97                    0.31
# ...                      ...                     ...                     ...
# 1492                   16.14                   20.39                    6.20
# 1493                   14.26                   22.33                    4.41
# 1494                   22.10                   20.57                    1.66
# 1495                   16.57                    9.38                    3.03
# 1496                   17.36                   34.86                    6.25
#
#       Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                         51.90                       2.48
# 1                         47.87                       5.46
# 2                         70.68                       0.49
# 3                         60.47                       1.12
# 4                         68.05                       2.04
# ...                         ...                        ...
# 1492                      38.64                       3.43
# 1493                      39.41                       7.18
# 1494                      53.69                       3.31
# 1495                      29.16                       0.26
# 1496                      55.21                       7.11
#
#       Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                     1.02                     0.88           26.57
# 1                     2.41                     2.91           28.79
# 2                     0.26                     0.23           48.74
# 3                     0.41                     0.65           48.70
# 4                     1.38                     0.57           51.86
# ...                    ...                      ...             ...
# 1492                  1.14                     1.90           24.58
# 1493                  3.02                     3.61           27.72
# 1494                  1.40                     1.59           26.11
# 1495                  0.15                     0.11           12.41
# 1496                  2.68                     3.82           37.64
#
#       Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                    158.69                                81.82
# 1                    192.98                                98.37
# 2                    280.36                               159.26
# 3                    258.05                                99.59
# 4                    273.81                               122.39
# ...                     ...                                  ...
# 1492                 142.23                                57.68
# 1493                 247.23                               141.68
# 1494                 148.09                                70.64
# 1495                  36.02                                 9.45
# 1496                 247.68                               132.11
#
#       Progressive_Carries_per_90  1/3_Carries_per_90  \
# 0                           1.61                0.88
# 1                           2.62                2.06
# 2                           1.17                0.61
# 3                           0.53                1.95
# 4                           1.19                1.54
# ...                          ...                 ...
# 1492                        2.32                1.66
# 1493                        5.64                3.56
# 1494                        2.42                1.72
# 1495                        0.18                0.29
# 1496                        4.96                2.21
#
#       Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 0                            0.51                0.95                 0.58
# 1                            0.64                2.91                 2.70
# 2                            0.00                0.74                 0.13
# 3                            0.00                1.36                 0.65
# 4                            0.09                1.01                 0.94
# ...                           ...                 ...                  ...
# 1492                         0.87                3.73                 1.75
# 1493                         2.13                2.77                 0.74
# 1494                         0.38                2.04                 1.08
# 1495                         0.07                1.68                 0.80
# 1496                         3.00                2.25                 1.71
#
#       Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 0
#
#       Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                              0.07                    5.47
# 1                              0.00                    6.24
# 2                              0.00                    4.82
# 3                              0.18                    5.27
# 4                              0.00                    7.11
# ...                             ...                     ...
# 1492                           0.00                    2.74
# 1493                           0.00                    2.97
# 1494                           0.00                    3.63
# 1495                           0.00                    1.97
# 1496                           0.00                    4.21
#
#       Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 0                   0.36                 0.80            2.12
# 1                   0.92                 1.13            2.27
# 2                   1.97                 1.20            2.07
# 3                   0.12                 0.41            1.24
# 4                   0.47                 0.44            2.67
# ...                  ...                  ...             ...
# 1492                4.04                 3.61            0.54
# 1493                0.25                 0.45            1.09
# 1494                0.70                 1.46            1.66
# 1495                8.07                 3.03            0.22
# 1496                0.29                 0.46            1.54
#
#       Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 0                       1.46                    0.51                    0.15
# 1                       0.92                    0.92                    0.43
# 2                       1.17                    0.74                    0.16
# 3                       0.47                    0.59                    0.18
# 4                       1.35                    1.07                    0.25
# ...                      ...                     ...                     ...
# 1492                    0.27                    0.06                    0.21
# 1493                    0.50                    0.35                    0.25
# 1494                    0.70                    0.89                    0.06
# 1495                    0.00                    0.18                    0.04
# 1496                    0.43                    0.29                    0.82
#
#       Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 0                         1.46                         2.48
# 1                         1.13                         2.27
# 2                         0.84                         1.46
# 3                         0.47                         1.07
# 4                         1.19                         3.02
# ...                        ...                          ...
# 1492                      0.09                         0.39
# 1493                      0.54                         1.29
# 1494                      0.70                         1.66
# 1495                      0.07                         0.26
# 1496                      0.61                         1.54
#
#       Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 0                             1.02           0.66                  0.36
# 1                             1.13           1.84                  0.07
# 2                             0.61           1.65                  1.04
# 3                             0.59           0.71                  0.06
# 4                             1.82           0.91                  0.19
# ...                            ...            ...                   ...
# 1492                          0.30           0.60                  0.18
# 1493                          0.74           0.45                  0.00
# 1494                          0.96           0.96                  0.32
# 1495                          0.18           0.22                  0.07
# 1496                          0.93           0.71                  0.00
#
#       Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                             2.70               1.97                 0.00
# 1                             2.41               0.28                 0.00
# 2                             3.33               3.53                 0.06
# 3                             1.95               1.07                 0.00
# 4                             4.59               1.92                 0.09
# ...                            ...                ...                  ...
# 1492                          0.75               0.81                 0.00
# 1493                          1.34               0.15                 0.00
# 1494                          1.97               2.04                 0.06
# 1495                          0.26               1.46                 0.00
# 1496                          1.71               0.21                 0.04
#
#       Dribblers_Tackle_W%
# 0                    58.8
# 1                    50.0
# 2                    57.8
# 3                    44.4
# 4                    39.6
# ...                   ...
# 1492                 23.0
# 1493                 42.0
# 1494                 42.0
# 1495                 29.0
# 1496                 39.5
#
# [1497 rows x 131 columns]

# %%
from sklearn.decomposition import PCA
import numpy as np

# Identify features to minimize
negative_features = ['Yellow_Cards_per_90', 'Red_Cards_per_90', 'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90',
                     'Aerials_Lost_per_90','Miscontrols_per_90','Dispossessed_per_90','Penalty_Kicks_Conceded_per_90']

# Reverse the sign of negative features
for feature in negative_features:
    if feature in forward_players.columns:
        
        player_2024[feature]=-player_2024[feature]

# %%
# Normalize data
numerical_player_2024 = player_2024[params].replace([np.inf, -np.inf], 0)
normalized_player_2024 = (numerical_player_2024 - numerical_player_2024.mean()) / numerical_player_2024.std()

# Apply PCA
pca = PCA()
pca.fit(normalized_player_2024)
explained_variances = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variances >= 0.95) + 1

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
transformed_players = pca.fit_transform(normalized_player_2024)

# Convert transformed data back to DataFrame
transformed_df = pd.DataFrame(transformed_players, index=player_2024.index)

# %%
# Get kvara's row and compute cosine similarity
kvara_2023_index = player_2024.index[player_2024['Player'] == 'Khvicha Kvaratskhelia'][0]
kvara_2023_data = transformed_df.loc[kvara_2023_index].values.reshape(1, -1)

# Remove kvara from the dataset for comparison
transformed_df = transformed_df.drop(index=kvara_2023_index)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(transformed_df, kvara_2023_data).flatten()
transformed_df['similarity_to_kvara_2023'] = similarity_scores

# Get top 10 players most similar to de kvara
top_similar_players_indices = transformed_df.sort_values('similarity_to_kvara_2023', ascending=False).index
top_similar_players = player_2024.loc[top_similar_players_indices]

# %%
player_2024['similarity_to_kvara_2023']=transformed_df['similarity_to_kvara_2023']
player_2024[['Player', 'similarity_to_kvara_2023']]
# Out:
#                      Player  similarity_to_kvara_2023
# 0                Max Aarons                 -0.416925
# 1          Brenden Aaronson                  0.652027
# 2          Yunis Abdelhamid                 -0.718631
# 3         Salis Abdul Samed                 -0.850771
# 4           Laurent Abergel                 -0.326626
# ...                     ...                       ...
# 1492           Duván Zapata                  0.397934
# 1493         Bryan Zaragoza                  0.693060
# 1494           Nadir Zortea                  0.517078
# 1495            Milan Đurić                 -0.605706
# 1496  Khvicha Kvaratskhelia                       NaN
#
# [1497 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=12)

# Use a dark background
plt.style.use('dark_background')

# Sort the player_2024 DataFrame by similarity_to_kvara_2023 in descending order
player_2024_sorted = player_2024.sort_values(by='similarity_to_kvara_2023', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart, but reverse the order of the data
bars = ax.barh(player_2024_sorted['Player'].head(15)[::-1], (player_2024_sorted['similarity_to_kvara_2023'].head(15)*100)[::-1],
               color=plt.cm.viridis(np.linspace(0, 1, 10)))

# Add labels and title
ax.set_xlabel('Similarity Percentage', fontproperties=font_prop)
ax.set_ylabel('Player', fontproperties=font_prop)
ax.set_title('Who is most similar to 2022-23 Kvaratskhelia from top 5 leagues based on the 2023-24 Season ?', fontproperties=font_prop)

# Set the y-axis tick labels with the custom font
ax.set_yticklabels(player_2024_sorted['Player'].head(15)[::-1], fontproperties=font_prop)

# Remove gridlines
ax.grid(False)

# Make the top and right spines invisible
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make the left and bottom spines white
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

# Change the color of ticks to white
ax.tick_params(colors='white')

# Change the color of labels to white
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')

# Add percentage labels to the bars
for bar in bars:
    width = bar.get_width()
    y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, y_pos, f'{width:.1f}%', ha='left', va='center',
            color='white', fontproperties=font_prop)


# Save the figure
plt.savefig('Similar_2023.png' ,dpi=500,bbox_inches = 'tight',transparent=False)

plt.show()

# %%
Baumgartner=player_2024[player_2024['Player']=='Christoph Baumgartner']
Baumgartner
# Out:
#      Unnamed: 0                 Player  Nation    Pos       Squad  \
# 119         240  Christoph Baumgartner  at AUT  MF,FW  RB Leipzig
#
#               Comp  Age    Born  MP  Starts   Min   90s  Goals_per90  \
# 119  de Bundesliga  0.0  1999.0  32      11  1158  12.9         0.39
#
#      G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 119       0.47        0.39          0.47      0.28          0.41        0.28
#
#      npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 119            0.41                37.0           18.0            48.6
#
#      Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 119              15.0               40.5           51.32
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 119                    1.32                    7.29                   23.64
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 119                   21.32                    5.19
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 119                      51.32                       2.87
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 119                   1.4                     1.16           30.23
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 119                 166.36                                97.05
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 119                        2.79                 2.4
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 119                         1.01               -2.95                -2.17
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 119                   37.13                                6.67
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 119                         3.5                     0.39
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 119                    2.4                    0.0                  0.23
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 119              0.39                     0.39                   0.08
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 119                   0.23                    0.0                   0.0
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 119              0.08                     0.08                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 119             340.0             456.0               74.6          4651.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 119          1244.0             189.0             236.0               80.1
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 119              112.0              137.0                81.8
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 119             14.0             26.0              53.8            0.08
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 119        0.12       0.12         -0.05               1.24
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 119                2.4                        0.93
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 119                         0.08                       3.64
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 119                    35.35                    34.34
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 119                     0.62                     0.39                  0.31
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 119             0.08            0.62                    0.23
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 119                  0.0                     0.0                      0.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 119                      0.0              26.36               0.39
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 119                   1.16               2.41                   0.85
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 119            0.16                      0.45           0.12     1.3
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 119       1.3                       40.8                -0.23
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 119              -0.0                       -0.0                   -2.09
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 119                2.09             0.08                  0.39
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 119                1.01                      0.08
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 119                           -0.0                     3.1
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 119                1.55                -2.25            2.02
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 119                    0.78                    0.93                    0.31
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 119                      1.09                         2.95
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 119                          1.86           1.55                  0.08
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 119                           2.4               1.09                  0.0
#
#      Dribblers_Tackle_W%  similarity_to_kvara_2023
# 119                 36.8                   0.97745

# %%
# Calculate percentile ranks for players in the larger DataFrame
players_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of schlotterbeck's stats from the percentile ranks DataFrame
Baumgartner_percentile_ranks = round(players_percentile_ranks.iloc[[119]], 0)

# Print the percentile ranks for schlotterbeck
Baumgartner_percentile_ranks
# Out:
#      G+A_per90  Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  \
# 119       86.0                       81.0                  84.0
#
#      Carries_Penalty_Area_per_90  Progressive_Carries_per_90  \
# 119                         86.0                        83.0
#
#      Shot_Goal_per_90  Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 119              91.0                        83.0                     81.0
#
#      Key_Passes_per_90  xAG_per_90  Passes_Penalty_Area_per_90  \
# 119               71.0        67.0                        63.0
#
#      Passes_Received_per_90  Through_Balls_per_90  Touches_Att_3rd_per_90  \
# 119                    57.0                  89.0                    81.0
#
#      Progressive_Passes_per_90
# 119                       53.0

# %%
Baumgartner_percentile_ranks_list = Baumgartner_percentile_ranks.values.flatten().tolist()

Baumgartner_percentile_ranks_list
# Out:
# [86.0,
#  81.0,
#  84.0,
#  86.0,
#  83.0,
#  91.0,
#  83.0,
#  81.0,
#  71.0,
#  67.0,
#  63.0,
#  57.0,
#  89.0,
#  81.0,
#  53.0]

# %%
image_path = "Baumgartner.jpg"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    Baumgartner_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Christoph Baumgartner - RB Leipzig", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Bundesliga Stats Percentile Rank vs Top-Five Leagues Forwards | 2023-24 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Baumgartner_Percentile.png',dpi=500, bbox_inches='tight', facecolor=fig.get_facecolor(), edgecolor='none')  # save as png
