# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(10, 14))

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Stegen': (5, 50),  # Goalkeeper
    'Baldé': (20, 90),  # Left Back
    'Iñigo Martinez': (20, 65),  # Left Center Back
    'Koundé': (20, 35),  # Right Center Back
    'Santos': (20, 10),  # Right Back
    'Gundogan': (40, 65),  # Left Pivot
    'Christensen': (40, 35),  # Right Pivot
    'Olmo': (70, 50),  # Attacking Midfielder (Number 10)
    'Fuhrich': (70, 85),  # Left Winger
    'Yamal': (70, 15),  # Right Winger
    'David': (78, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font
ax.set_title('Barcelona 2024/25 - Ideal Team Setup (4-2-3-1)', color='white', fontproperties=font_prop, fontsize=18)

# Save the figure
plt.savefig('Barcelona_2025.png' ,dpi=500,bbox_inches = 'tight',transparent=False)
# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 37
#      34 ax.set_title('Barcelona 2024/25 - Ideal Team Setup (4-2-3-1)', color='white', fontproperties=font_prop, fontsize=18)
#      36 # Save the figure
# ---> 37 plt.savefig('Barcelona_2025.png' ,dpi=500,bbox_inches = 'tight',transparent=False)
#      38 # Show plot
#      39 plt.show()
#
# File ~\anaconda3\envs\Football\lib\site-packages\matplotlib\pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# ...
