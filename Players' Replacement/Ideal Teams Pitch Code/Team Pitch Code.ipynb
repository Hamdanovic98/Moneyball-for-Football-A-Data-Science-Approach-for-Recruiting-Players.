# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Stegen': (5, 50),  # Goalkeeper
    'Baldé': (20, 90),  # Left Back
    'Iñigo Martinez': (20, 65),  # Left Center Back
    'Koundé': (20, 35),  # Right Center Back
    'Santos': (20, 10),  # Right Back
    'De Jong': (40, 65),  # Left Pivot
    'Christensen': (40, 35),  # Right Pivot
    'Olmo': (70, 50),  # Attacking Midfielder (Number 10)
    'Führich': (70, 85),  # Left Winger
    'Yamal': (70, 15),  # Right Winger
    'David': (78, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('Barcelona 2024/25: Rebuilding the Squad the Data Way', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Barcelona_2025.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Meret': (3, 50),  # Goalkeeper
    'Olivera': (55, 90),  # Left Back
    'Buongiorno': (25, 75),  # Left Center Back
    'Rahmani': (25, 50),  # Right Center Back
    'Di Lorenzo': (25, 20),  # Right Back
    'Lobtoka': (40, 50),  # Left Pivot
    'Anguissa': (55, 25),  # Right Pivot
    'Darder': (55, 75),  # Attacking Midfielder (Number 10)
    'Wildmer': (55, 10),  # Left Winger
    'Kvaratskhelia': (68, 65),  # Right Winger
    'Boniface': (78, 35),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('SSC Napoli 2024/25: Rebuilding the Squad the Data Way', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Napoli_3-5-2_2025.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Meret': (3, 50),  # Goalkeeper
    'Olivera': (55, 90),  # Left Back
    'Buongiorno': (25, 75),  # Left Center Back
    'Rahmani': (25, 50),  # Right Center Back
    'Di Lorenzo': (25, 20),  # Right Back
    'Lobtoka': (40, 65),  # Left Pivot
    'Anguissa': (40, 35),  # Right Pivot
    
    'Neres': (68, 35),  # Attacking Midfielder (Number 10)
    'Wildmer': (55, 10),  # Left Winger
    'Kvaratskhelia': (68, 65),  # Right Winger
    'Boniface': (78, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('SSC Napoli 2024/25: Rebuilding the Squad the Data Way', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Napoli_3-4-3_2025.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Courtois': (3, 50),  # Goalkeeper
    'Truffert': (20, 90),  # Left Back
    'Schlotterbeck': (20, 65),  # Left Center Back
    'Militão': (20, 35),  # Right Center Back
    'Dumfries': (20, 10),  # Right Back
    'Rovella': (40, 50),  # Left Pivot
    'Valverde': (40, 25),  # Right Pivot
    'Bellignham': (40, 75),  # Attacking Midfielder (Number 10)
    'Vinicius': (70, 85),  # Left Winger
    'Rodrigo': (70, 15),  # Right Winger
    'Mbappé': (70, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('Real Madrid 2024/25: Rebuilding the Squad the Data Way', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Real_Madrid_2025.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Ederson': (3, 50),  # Goalkeeper
    'Gvardiol': (20, 90),  # Left Back
    'Tah': (20, 65),  # Left Center Back
    'Ruben': (20, 35),  # Right Center Back
    'Posch': (20, 10),  # Right Back
    'Guimarães': (40, 50),  # Left Pivot
    'Bernardo': (60, 35),  # Right Pivot
    'Pellegrini': (60, 65),  # Attacking Midfielder (Number 10)
    'Savinho': (60, 85),  # Left Winger
    'Foden': (60, 15),  # Right Winger
    'Haaland': (70, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('Manchester City 2024/25: Rejuvenating the Squad the Data Way', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Man_City_2025.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Ederson': (3, 50),  # Goalkeeper
    'Gvardiol': (20, 90),  # Left Back
    'Tah': (20, 65),  # Left Center Back
    'Ruben': (20, 35),  # Right Center Back
    'Posch': (20, 10),  # Right Back
    'André': (40, 50),  # Left Pivot
    'Bernardo': (60, 35),  # Right Pivot
    'Pellegrini': (60, 65),  # Attacking Midfielder (Number 10)
    'Savinho': (60, 85),  # Left Winger
    'Foden': (60, 15),  # Right Winger
    'Haaland': (70, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('Manchester City 2024/25: Quick Fix Using Data', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Man_City_2025_2.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Mamardashvili': (5, 50),  # Goalkeeper
    'C. Henrique': (20, 90),  # Left Back
    'Araújo': (20, 65),  # Left Center Back
    'Konaté': (20, 35),  # Right Center Back
    'Molina': (20, 10),  # Right Back
    'Mac Allister': (40, 65),  # Left Pivot
    'Gravenberch': (40, 35),  # Right Pivot
    'Szoboszlai': (70, 50),  # Attacking Midfielder (Number 10)
    'Gakpo': (70, 85),  # Left Winger
    'Sané': (70, 15),  # Right Winger
    'Diaz': (78, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('Liverpool 2025/26: Planning the Squad the Data Way', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Liverpool_2026.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import mplsoccer
from mplsoccer import VerticalPitch

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=15)  # Adjust size as needed

# Initialize pitch with a smaller size
pitch = VerticalPitch(pitch_type='opta', pitch_color='black', line_color='white')
fig, ax = pitch.draw(figsize=(8, 12))  # Reduced figure size

# Define positions (x, y) for each player in a 4-2-3-1 formation
positions = {
    'Kobel': (3, 50),  # Goalkeeper
    'Raum': (55, 90),  # Left Back
    'Martinez': (25, 75),  # Left Center Back
    'Yoro': (25, 50),  # Right Center Back
    'de Ligt': (25, 20),  # Right Back
    'Mainoo': (40, 65),  # Left Pivot
    'Ugarte': (40, 35),  # Right Pivot
    
    'Diallo': (68, 35),  # Attacking Midfielder (Number 10)
    'Molina': (55, 10),  # Left Winger
    'Bruno': (68, 65),  # Right Winger
    'Toney': (78, 50),  # Striker (Number 9)
}

# Annotate player names on the pitch
for player, pos in positions.items():
    pitch.annotate(player, xy=pos, va='center', ha='center', color='white', fontsize=15, ax=ax, fontproperties=font_prop)

# Title with custom font and padding
ax.set_title('Manchester United 2025/26: Fixing the Squad the Data Way', color='white', fontproperties=font_prop, fontsize=18, pad=20)

# Set facecolor to black to ensure the background matches
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Save the figure with tight bounding box to remove extra borders
plt.savefig('Man_Utd_2026.png', dpi=500, bbox_inches='tight', facecolor='black', edgecolor='none')

# Show plot
plt.show()
