# %%
import pandas as pd
import numpy as np
from PIL import Image
from mplsoccer import PyPizza, add_image, FontManager
import urllib.request

# %%
# Display the current settings
print("Current maximum number of rows: ", pd.get_option('display.max_rows'))
print("Current maximum number of columns: ", pd.get_option('display.max_columns'))

# Set new maximum number of rows and columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# Display the updated settings
print("Updated maximum number of rows: ", pd.get_option('display.max_rows'))
print("Updated maximum number of columns: ", pd.get_option('display.max_columns'))
# Out:
# Current maximum number of rows:  60
# Current maximum number of columns:  20
# Updated maximum number of rows:  500
# Updated maximum number of columns:  500

# %%
final_player = pd.read_csv('../final_players_2024.csv')
player_2024=pd.read_csv('../Full_Players_2024.csv')
player_2023=pd.read_csv('../Full_Players_2023.csv')
player_2022=pd.read_csv('../Full_Players_2022.csv')
player_2021=pd.read_csv('../Full_Players_2021.csv')
newbie=pd.read_csv('../newbie_players_2024.csv')
# Fill missing values with 0 in place
final_player.fillna(0, inplace=True)
newbie.fillna(0,inplace=True)
player_2024.fillna(0,inplace=True)
player_2023.fillna(0, inplace=True)
player_2022.fillna(0, inplace=True)
player_2021.fillna(0, inplace=True)
final_player
# Out:
#       Unnamed: 0               Player  Nation    Pos  \
# 0              0       Milan Škriniar  sk SVK     DF
# 1              1      Maxence Lacroix  fr FRA     DF
# 2              2          Wataru Endo  jp JPN     MF
# 3              3           Unai López  es ESP     MF
# 4              4        Mario Hermoso  es ESP     DF
# ...          ...                  ...     ...    ...
# 1491        2490  Filippo Terracciano  it ITA  DF,FW
# 1492        2495       Jonathan Viera  es ESP     MF
# 1493        2496       Alan Virginius  fr FRA     FW
# 1494        2505       Bryan Zaragoza  es ESP  FW,MF
# 1495        2507         Nadir Zortea  it ITA     DF
#
#                              Squad                              Comp  Age  \
# 0                  Paris S-G+Inter             fr Ligue 1+it Serie A  0.0
# 1                        Wolfsburg                     de Bundesliga  0.0
# 2              Liverpool+Stuttgart  eng Premier League+de Bundesliga  0.0
# ...

# %%
final_player = pd.read_csv('../final_players_2024.csv')
player_2024=pd.read_csv('../Full_Players_2024.csv')
player_2023=pd.read_csv('../Full_Players_2023.csv')
player_2022=pd.read_csv('../Full_Players_2022.csv')
player_2021=pd.read_csv('../Full_Players_2021.csv')
newbie=pd.read_csv('../newbie_players_2024.csv')
# Fill missing values with 0 in place
final_player.fillna(0, inplace=True)
newbie.fillna(0,inplace=True)
player_2024.fillna(0,inplace=True)
player_2023.fillna(0, inplace=True)
player_2022.fillna(0, inplace=True)
player_2021.fillna(0, inplace=True)
final_player
# Out:
#       Unnamed: 0               Player  Nation    Pos  \
# 0              0       Milan Škriniar  sk SVK     DF
# 1              1      Maxence Lacroix  fr FRA     DF
# 2              2          Wataru Endo  jp JPN     MF
# 3              3           Unai López  es ESP     MF
# 4              4        Mario Hermoso  es ESP     DF
# ...          ...                  ...     ...    ...
# 1491        2490  Filippo Terracciano  it ITA  DF,FW
# 1492        2495       Jonathan Viera  es ESP     MF
# 1493        2496       Alan Virginius  fr FRA     FW
# 1494        2505       Bryan Zaragoza  es ESP  FW,MF
# 1495        2507         Nadir Zortea  it ITA     DF
#
#                              Squad                              Comp  Age  \
# 0                  Paris S-G+Inter             fr Ligue 1+it Serie A  0.0
# 1                        Wolfsburg                     de Bundesliga  0.0
# 2              Liverpool+Stuttgart  eng Premier League+de Bundesliga  0.0
# ...

# %%
# Assuming 'final_player' is the DataFrame containing player data

# Filter out forwards (FW) and midfielders (MF) from the 'final_player' DataFrame
defense_players = final_player[final_player['Pos'].isin(['DF'])]
newbie = newbie[newbie['Pos'].isin(['DF'])]
player_2021 = player_2021[player_2021['Pos'].isin(['DF'])]
player_2022 = player_2022[player_2022['Pos'].isin(['DF'])]
player_2023 = player_2023[player_2023['Pos'].isin(['DF'])]
player_2024 = player_2024[player_2024['Pos'].isin(['DF'])]

# Reset the index if needed
defense_players = defense_players.reset_index(drop=True)
newbie = newbie.reset_index(drop=True)
player_2024= player_2024.reset_index(drop=True)
player_2023 = player_2023.reset_index(drop=True)
player_2022 = player_2022.reset_index(drop=True)
player_2021 = player_2021.reset_index(drop=True)

# %%
Walker=defense_players[defense_players['Player']=='Kyle Walker']
Walker
# Out:
#      Unnamed: 0       Player   Nation Pos            Squad  \
# 135         367  Kyle Walker  eng ENG  DF  Manchester City
#
#                    Comp  Age    Born     MP  Starts   Min   90s  Goals_per90  \
# 135  eng Premier League  0.0  1990.0  103.0    94.0  8426  93.6         0.01
#
#      G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 135       0.08        0.01          0.08      0.01          0.07        0.01
#
#      npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 135            0.07               109.0           65.0           59.63
#
#      Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 135              39.0              35.78           90.57
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 135                    2.37                   17.96                   52.65
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 135                   20.57                    1.01
# ...

# %%
Walker_2024=player_2024[player_2024['Player']=='Kyle Walker']
Walker_2024
# Out:
#      Unnamed: 0       Player   Nation Pos            Squad  \
# 517        2738  Kyle Walker  eng ENG  DF  Manchester City
#
#                    Comp  Age    Born  MP  Starts   Min   90s  Goals_per90  \
# 517  eng Premier League  0.0  1990.0  32      30  2767  30.7          0.0
#
#      G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 517       0.13         0.0          0.13      0.01           0.1        0.01
#
#      npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 517             0.1                35.0           21.0            60.0
#
#      Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 517              11.0               31.4           85.11
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 517                    2.51                   17.13                   44.23
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 517                    24.4                    1.34
#
# ...

# %%
import pandas as pd





params=['Goals_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90', 'xG_per90', 'xG+xAG_per90', 'npxG_per90',
        'npxG+xAG_per90', 'Take_Ons_Attempted', 'Take_Ons_Succ', 'Take_Ons_Succ%', 'Tackled_Take_Ons', 
        'Tackled_Take_Ons%', 'Touches_per_90', 'Touches_Def_Pen_per_90', 'Touches_Def_3rd_per_90', 
        'Touches_Mid_3rd_per_90', 'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
        'Take_Ons_Attempted_per_90', 'Take_Ons_Succ_per_90', 'Tackled_Take_Ons_per_90', 'Carries_per_90', 
        'Total_Distance_per_90', 'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90', 
        '1/3_Carries_per_90', 'Carries_Penalty_Area_per_90', 'Miscontrols_per_90', 'Dispossessed_per_90', 
        'Passes_Received_per_90', 'Progressive_Passes_Received_per_90', 'Shot_Creating_Action_per90', 
        'Goal_Creating_Action_90', 'Pass_Live_Shot_per_90', 'Pass_Dead_Shot_per_90', 'Take_Ons_Shot_per_90', 
        'Shot-Shot_per_90', 'Fouls_drawn_Shot_per_90', 'Defensive_Shot_per_90', 'Pass_Live_Goal_per_90',
        'Pass_Dead_Goal_per_90', 'Take_Ons_Goal_per_90', 'Shot_Goal_per_90', 'Fouls_Drawn_Goal_per_90', 
        'Defensive_Goal_per_90', 'Passes_Total_Cmp', 'Passes_Total_Att', 'Passes_Total_Cmp%', 'Passes_TotDist', 
        'Passes_PrgDist', 'Passes_Short_Cmp', 'Passes_Short_Att', 'Passes_Short_Cmp%', 'Passes_Medium_Cmp', 
        'Passes_Medium_Att', 'Passes_Medium_Cmp%', 'Passes_Long_Cmp', 'Passes_Long_Att', 'Passes_Long_Cmp%', 
        'Assists_per_90', 'xAG_per_90', 'xA_per_90', 'A-xAG_per_90', 'Key_Passes_per_90', 'Passes_1/3_per_90', 
        'Passes_Penalty_Area_per_90', 'Crosses_Penalty_Area_per_90', 'Progressive_Passes_per_90', 
        'Passes_Attempted_per_90', 'Live_Ball_Passes_per_90', 'Dead_Ball_Passes_per_90', 'Free_Kick_Passes_per_90',
        'Through_Balls_per_90', 'Switches_per_90', 'Crosses_per_90', 'Throw_Ins_Taken_per_90', 
        'Corner_Kicks_per_90', 'In_Corner_Kicks_per_90', 'Out_Corner_Kicks_per_90', 'Str_Corner_Kicks_per_90',
        'Passes_Cmp_per_90', 'Passes_Off_per_90', 'Passes_Blocked_per_90', 'Shots_total_per90', 
        'Shots_on_target_per90', 'Goals_per_shot', 'Goals_per_shot_on_target', 'Npxg_per_shot', 'Xg_net', 
        'Npxg_net', 'Percentage_of_Aerials_Won', 'Yellow_Cards_per_90', 'Red_Cards_per_90', 
        'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90', 'Fouls_Drawn_per_90', 'Offsides_per_90', 
        'Interceptions_per_90', 'Tackles_Won_per_90', 'Penalty_Kicks_Won_per_90', 'Penalty_Kicks_Conceded_per_90',
        'Ball_Recoveries_per_90', 'Aerials_Won_per_90', 'Aerials_Lost_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = defense_players[params].rank(pct=True) * 100

# Get the row of Stones' stats from the percentile ranks DataFrame
walker_percentile_ranks = round(players_percentile_ranks.iloc[[135]],0)

# Print the percentile ranks for Stones
walker_percentile_ranks
# Out:
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 135         25.0       44.0        25.0          44.0       5.0          33.0
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 135         5.0            33.0                88.0           91.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 135            60.0              83.0               48.0            97.0
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 135                     7.0                    18.0                    99.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 135                    91.0                    54.0
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 135                       97.0                       71.0
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# ...

# %%
# Extract the percentile ranks, transpose, and sort them in descending order
walker_percentile_ranks_sorted = walker_percentile_ranks.T.sort_values(by=135, ascending=False)

# Get the top 20 parameters
top_20_params = walker_percentile_ranks_sorted.index[:30]
top_20_params_values = walker_percentile_ranks_sorted[135].head(30)

# Display the top 20 parameters and their values
print("Top 20 Parameters:")
print(top_20_params)
print("Values:")
print(top_20_params_values)
# Out:
# Top 20 Parameters:
# Index(['Passes_1/3_per_90', 'Touches_Mid_3rd_per_90', 'Passes_Received_per_90',
#        'Passes_Cmp_per_90', 'Passes_Attempted_per_90',
#        'Progressive_Passes_per_90', 'Passes_Short_Cmp', 'Touches_per_90',
#        'Passes_Short_Att', 'Live_Ball_Passes_per_90',
#        'Tocuhes_Live_Balls_per_90', 'Passes_Total_Att', 'Passes_Total_Cmp',
#        'Switches_per_90', 'Through_Balls_per_90', '1/3_Carries_per_90',
#        'Passes_TotDist', 'Carries_per_90', 'Passes_Medium_Cmp',
#        'Passes_Short_Cmp%', 'Passes_Medium_Att', 'Take_Ons_Succ',
#        'Touches_Att_3rd_per_90', 'Progressive_Carries_per_90',
#        'Passes_Long_Cmp', 'Passes_Long_Cmp%', 'Total_Distance_per_90',
#        'Take_Ons_Attempted', 'Take_Ons_Goal_per_90', 'Passes_Total_Cmp%'],
#       dtype='object')
# Values:
# Passes_1/3_per_90             100.0
# Touches_Mid_3rd_per_90         99.0
# Passes_Received_per_90         98.0
# Passes_Cmp_per_90              98.0
# ...

# %%
params = [
    "Passes_1/3_per_90",             # 100.0 - Key for delivering passes into dangerous areas (final third).
    "Touches_Mid_3rd_per_90",        # 99.0 - Demonstrates his involvement in the midfield, supporting inverted play.
    "Progressive_Passes_per_90",     # 97.0 - Highlights his ability to play forward passes and break defensive lines.
    "Passes_Attempted_per_90",       # 98.0 - Reflects his high involvement in build-up play.
    "Passes_Cmp_per_90",             # 98.0 - Shows his reliability in completing passes.
    "Passes_Received_per_90",        # 98.0 - Indicates his availability to teammates and ability to receive under pressure.
    "Carries_per_90",                # 94.0 - Demonstrates his ability to carry the ball forward into advanced areas.
    "Progressive_Carries_per_90",    # 89.0 - Reflects his forward ball progression via carries.
    "Switches_per_90",               # 96.0 - Highlights his ability to spread play and switch the ball effectively.
    "Touches_Att_3rd_per_90",        # 90.0 - Indicates his contributions in the attacking third when overlapping.
    "Live_Ball_Passes_per_90",       # 97.0 - Captures his involvement in active play.
    "Passes_Total_Cmp",              # 97.0 - Reflects his total passing ability and success.
    "1/3_Carries_per_90",            # 93.0 - Demonstrates his ability to carry the ball into the attacking third.
    "Through_Balls_per_90",          # 92.0 - Highlights his creativity and ability to find teammates in advanced positions.
    "Take_Ons_Succ",                 # 88.0 - Reflects his ability to successfully beat opponents in 1v1 situations.
]


# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = player_2024[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
walker_2024_percentile_ranks = round(players_percentile_ranks.iloc[[517]],0)

# Print the percentile ranks for Declan Rice
walker_2024_percentile_ranks
# Out:
#      Passes_1/3_per_90  Touches_Mid_3rd_per_90  Progressive_Passes_per_90  \
# 517               96.0                    91.0                       85.0
#
#      Passes_Attempted_per_90  Passes_Cmp_per_90  Passes_Received_per_90  \
# 517                     92.0               92.0                    92.0
#
#      Carries_per_90  Progressive_Carries_per_90  Switches_per_90  \
# 517            83.0                        87.0             89.0
#
#      Touches_Att_3rd_per_90  Live_Ball_Passes_per_90  Passes_Total_Cmp  \
# 517                    97.0                     91.0              97.0
#
#      1/3_Carries_per_90  Through_Balls_per_90  Take_Ons_Succ
# 517                95.0                  96.0           90.0

# %%
# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = defense_players[params].rank(pct=True) * 100

# Get the row of Stones' stats from the percentile ranks DataFrame
walker_percentile_ranks = round(players_percentile_ranks.iloc[[135]],0)

# Print the percentile ranks for Stones
walker_percentile_ranks
# Out:
#      Passes_1/3_per_90  Touches_Mid_3rd_per_90  Progressive_Passes_per_90  \
# 135              100.0                    99.0                       98.0
#
#      Passes_Attempted_per_90  Passes_Cmp_per_90  Passes_Received_per_90  \
# 135                     98.0               98.0                    98.0
#
#      Carries_per_90  Progressive_Carries_per_90  Switches_per_90  \
# 135            94.0                        90.0             96.0
#
#      Touches_Att_3rd_per_90  Live_Ball_Passes_per_90  Passes_Total_Cmp  \
# 135                    91.0                     97.0              96.0
#
#      1/3_Carries_per_90  Through_Balls_per_90  Take_Ons_Succ
# 135                95.0                  95.0           91.0

# %%
walker_percentile_ranks_list = walker_percentile_ranks.values.flatten().tolist()

walker_percentile_ranks_list
# Out:
# [100.0,
#  99.0,
#  98.0,
#  98.0,
#  98.0,
#  98.0,
#  94.0,
#  90.0,
#  96.0,
#  91.0,
#  97.0,
#  96.0,
#  95.0,
#  95.0,
#  91.0]

# %%
walker_2024_percentile_ranks_list = walker_2024_percentile_ranks.values.flatten().tolist()

walker_2024_percentile_ranks_list
# Out:
# [96.0,
#  91.0,
#  85.0,
#  92.0,
#  92.0,
#  92.0,
#  83.0,
#  87.0,
#  89.0,
#  97.0,
#  91.0,
#  97.0,
#  95.0,
#  96.0,
#  90.0]

# %%
params = [
    "Passes_Final_Third_per_90",             # 100.0 - Key for delivering passes into dangerous areas (final third).
    "Touches_in_Middle_Third_per_90",        # 99.0 - Demonstrates his involvement in the midfield, supporting inverted play.
    "Progressive_Passes_per_90",     # 97.0 - Highlights his ability to play forward passes and break defensive lines.
    "Passes_Attempted_per_90",       # 98.0 - Reflects his high involvement in build-up play.
    "Passes_Completed_per_90",             # 98.0 - Shows his reliability in completing passes.
    "Passes_Received_per_90",        # 98.0 - Indicates his availability to teammates and ability to receive under pressure.
    "Carries_per_90",                # 94.0 - Demonstrates his ability to carry the ball forward into advanced areas.
    "Progressive_Carries_per_90",    # 89.0 - Reflects his forward ball progression via carries.
    "Switches_per_90",               # 96.0 - Highlights his ability to spread play and switch the ball effectively.
    "Touches_Attempted_Final_Third_per_90",        # 90.0 - Indicates his contributions in the attacking third when overlapping.
    "Live_Ball_Passes_per_90",       # 97.0 - Captures his involvement in active play.
    "Passes_Total_Cmp",              # 97.0 - Reflects his total passing ability and success.
    "Final_Third_Carries_per_90",            # 93.0 - Demonstrates his ability to carry the ball into the attacking third.
    "Through_Balls_per_90",          # 92.0 - Highlights his creativity and ability to find teammates in advanced positions.
    "Take_Ons_Succesful",                 # 88.0 - Reflects his ability to successfully beat opponents in 1v1 situations.
]

split_params = [param.replace('_', '\n') for param in params]

# %%
params = [
    "Passes_1/3_per_90",             # 100.0 - Key for delivering passes into dangerous areas (final third).
    "Touches_Mid_3rd_per_90",        # 99.0 - Demonstrates his involvement in the midfield, supporting inverted play.
    "Progressive_Passes_per_90",     # 97.0 - Highlights his ability to play forward passes and break defensive lines.
    "Passes_Attempted_per_90",       # 98.0 - Reflects his high involvement in build-up play.
    "Passes_Cmp_per_90",             # 98.0 - Shows his reliability in completing passes.
    "Passes_Received_per_90",        # 98.0 - Indicates his availability to teammates and ability to receive under pressure.
    "Carries_per_90",                # 94.0 - Demonstrates his ability to carry the ball forward into advanced areas.
    "Progressive_Carries_per_90",    # 89.0 - Reflects his forward ball progression via carries.
    "Switches_per_90",               # 96.0 - Highlights his ability to spread play and switch the ball effectively.
    "Touches_Att_3rd_per_90",        # 90.0 - Indicates his contributions in the attacking third when overlapping.
    "Live_Ball_Passes_per_90",       # 97.0 - Captures his involvement in active play.
    "Passes_Total_Cmp",              # 97.0 - Reflects his total passing ability and success.
    "1/3_Carries_per_90",            # 93.0 - Demonstrates his ability to carry the ball into the attacking third.
    "Through_Balls_per_90",          # 92.0 - Highlights his creativity and ability to find teammates in advanced positions.
    "Take_Ons_Succ",                 # 88.0 - Reflects his ability to successfully beat opponents in 1v1 situations.
]

# %%
image_path = "Walker.jpg"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    walker_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Kyle Walker - Manchester City", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Premier League Stats Percentile Rank vs Top-Five Leagues  Defenders | Last Four seasons",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Walker_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    walker_2024_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Kyle Walker - Manchester City", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Premier League Stats Percentile Rank vs Top-Five Leagues  Defenders | 2023-24 Season",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Walker_2024_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
from sklearn.decomposition import PCA
import numpy as np

# Identify features to minimize
negative_features = ['Yellow_Cards_per_90', 'Red_Cards_per_90', 'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90',
                     'Aerials_Lost_per_90','Miscontrols_per_90','Dispossessed_per_90', 'Penalty_Kicks_Conceded_per_90']

# Reverse the sign of negative features
for feature in negative_features:
    if feature in defense_players.columns:
        defense_players[feature] = -defense_players[feature]
        player_2024[feature]=-player_2024[feature]

# %%
# Normalize data
numerical_defense_players = defense_players[params].replace([np.inf, -np.inf], 0)
normalized_defense_players = (numerical_defense_players - numerical_defense_players.mean()) / numerical_defense_players.std()

# Apply PCA
pca = PCA()
pca.fit(normalized_defense_players)
explained_variances = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variances >= 0.95) + 1

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
transformed_players = pca.fit_transform(normalized_defense_players)

# Convert transformed data back to DataFrame
transformed_df = pd.DataFrame(transformed_players, index=defense_players.index)

# %%
# Get Walker's row and compute cosine similarity
walker_index = defense_players.index[defense_players['Player'] == 'Kyle Walker'][0]
walker_data = transformed_df.loc[walker_index].values.reshape(1, -1)

# Remove de Ligt from the dataset for comparison
transformed_df = transformed_df.drop(index=walker_index)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(transformed_df, walker_data).flatten()
transformed_df['similarity_to_walker'] = similarity_scores

# Get top 10 players most similar to de Ligt
top_similar_players_indices = transformed_df.sort_values('similarity_to_walker', ascending=False).index
top_similar_players = defense_players.loc[top_similar_players_indices]

# %%
# Visualize the results
defense_players['similarity_to_walker'] = transformed_df['similarity_to_walker']
defense_players_sorted = defense_players.sort_values(by='similarity_to_walker', ascending=False)
defense_players_sorted
# Out:
#      Unnamed: 0               Player   Nation Pos              Squad  \
# 109         313            Mário Rui   pt POR  DF             Napoli
# 6            23       Facundo Medina   ar ARG  DF               Lens
# 161         417   Alessandro Bastoni   it ITA  DF              Inter
# 9            36         Jules Koundé   fr FRA  DF  Barcelona+Sevilla
# 213         547  Giovanni Di Lorenzo   it ITA  DF             Napoli
# ..          ...                  ...      ...  ..                ...
# 374          36     Anel Ahmedhodžić   ba BIH  DF      Sheffield Utd
# 541        2194        Ismaël Traoré   ci CIV  DF               Metz
# 543        2203        Auston Trusty   us USA  DF      Sheffield Utd
# 495        1668         Gabriel Osho   ng NGA  DF         Luton Town
# 135         367          Kyle Walker  eng ENG  DF    Manchester City
#
#                    Comp  Age    Born     MP  Starts    Min    90s  \
# 109          it Serie A  0.0  1991.0  104.0    86.0   7615   84.5
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=12)

# Use a dark background
plt.style.use('dark_background')

# Sort the defense_players DataFrame by similarity_to_walker in descending order
defense_players_sorted = defense_players.sort_values(by='similarity_to_walker', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart, but reverse the order of the data
bars = ax.barh(defense_players_sorted['Player'].head(15)[::-1], (defense_players_sorted['similarity_to_walker'].head(15)*100)[::-1],
               color=plt.cm.viridis(np.linspace(0, 1, 10)))

# Add labels and title
ax.set_xlabel('Similarity Percentage', fontproperties=font_prop)
ax.set_ylabel('Player', fontproperties=font_prop)
ax.set_title('Who is most similar to Walker from top 5 leagues based on the last 4 seasons ?', fontproperties=font_prop)

# Set the y-axis tick labels with the custom font
ax.set_yticklabels(defense_players_sorted['Player'].head(15)[::-1], fontproperties=font_prop)

# Remove gridlines
ax.grid(False)

# Make the top and right spines invisible
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make the left and bottom spines white
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

# Change the color of ticks to white
ax.tick_params(colors='white')

# Change the color of labels to white
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')

# Add percentage labels to the bars
for bar in bars:
    width = bar.get_width()
    y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, y_pos, f'{width:.1f}%', ha='left', va='center',
            color='white', fontproperties=font_prop)


# Save the figure
plt.savefig('Similar.png' ,dpi=500,bbox_inches = 'tight',transparent=False)

plt.show()

# %%
Posch=defense_players[defense_players['Player']=='Stefan Posch']
Posch
# Out:
#     Unnamed: 0        Player  Nation Pos  \
# 81         232  Stefan Posch  at AUT  DF
#
#                                     Squad  \
# 81  Bologna+Bologna+Hoffenheim+Hoffenheim
#
#                                                  Comp  Age    Born     MP  \
# 81  it Serie A+it Serie A+de Bundesliga+de Bundesliga  0.0  1997.0  116.0
#
#     Starts   Min    90s  Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  \
# 81   111.0  9277  103.0         0.09       0.12        0.09          0.12
#
#     xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 81      0.06          0.09        0.06            0.09                88.0
#
#     Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 81           35.0           39.77              45.0              51.14
#
#     Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 81            76.7                    5.62                   30.72
#
# ...

# %%
# Calculate percentile ranks for players in the larger DataFrame
players_percentile_ranks = defense_players[params].rank(pct=True) * 100

# Get the row of Ndayishimiye's stats from the percentile ranks DataFrame
Posch_percentile_ranks = round(players_percentile_ranks.iloc[[81]], 0)

# Print the percentile ranks for schlotterbeck
Posch_percentile_ranks
# Out:
#     Passes_1/3_per_90  Touches_Mid_3rd_per_90  Progressive_Passes_per_90  \
# 81               86.0                    82.0                       86.0
#
#     Passes_Attempted_per_90  Passes_Cmp_per_90  Passes_Received_per_90  \
# 81                     83.0               75.0                    80.0
#
#     Carries_per_90  Progressive_Carries_per_90  Switches_per_90  \
# 81            78.0                        64.0             80.0
#
#     Touches_Att_3rd_per_90  Live_Ball_Passes_per_90  Passes_Total_Cmp  \
# 81                    57.0                     77.0              89.0
#
#     1/3_Carries_per_90  Through_Balls_per_90  Take_Ons_Succ
# 81                63.0                  64.0           73.0

# %%
Posch_percentile_ranks_list = Posch_percentile_ranks.values.flatten().tolist()

Posch_percentile_ranks_list
# Out:
# [86.0,
#  82.0,
#  86.0,
#  83.0,
#  75.0,
#  80.0,
#  78.0,
#  64.0,
#  80.0,
#  57.0,
#  77.0,
#  89.0,
#  63.0,
#  64.0,
#  73.0]

# %%
image_path = "Posch.png"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    Posch_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Stefan Posch", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Bundesliga & Serie A Stats Percentile Rank vs Top-Five Leagues Defenders | Last 4 Seasons",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Posch_Percentile.png',dpi=500, bbox_inches='tight', facecolor=fig.get_facecolor(), edgecolor='none')  # save as png
