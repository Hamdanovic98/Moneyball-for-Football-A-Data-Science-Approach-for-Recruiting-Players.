# %%
import pandas as pd
import numpy as np
from PIL import Image
from mplsoccer import PyPizza, add_image, FontManager
import urllib.request

# %%
# Display the current settings
print("Current maximum number of rows: ", pd.get_option('display.max_rows'))
print("Current maximum number of columns: ", pd.get_option('display.max_columns'))

# Set new maximum number of rows and columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# Display the updated settings
print("Updated maximum number of rows: ", pd.get_option('display.max_rows'))
print("Updated maximum number of columns: ", pd.get_option('display.max_columns'))
# Out:
# Current maximum number of rows:  60
# Current maximum number of columns:  20
# Updated maximum number of rows:  500
# Updated maximum number of columns:  500

# %%
final_player = pd.read_csv('../final_players.csv')
player_2024=pd.read_csv('../Full_Players_2024.csv')
player_2023=pd.read_csv('../Full_Players_2023.csv')
player_2022=pd.read_csv('../Full_Players_2022.csv')
player_2021=pd.read_csv('../Full_Players_2021.csv')
newbie=pd.read_csv('../newbie_players_2024.csv')
# Fill missing values with 0 in place
final_player.fillna(0, inplace=True)
newbie.fillna(0,inplace=True)
player_2024.fillna(0,inplace=True)
player_2023.fillna(0, inplace=True)
player_2022.fillna(0, inplace=True)
player_2021.fillna(0, inplace=True)
final_player
# Out:
#       Unnamed: 0             Player  Nation    Pos  \
# 0              0     Theo Hernández  fr FRA     DF
# 1              1    Marcel Sabitzer  at AUT     MF
# 2              2   Dejan Kulusevski  se SWE  MF,FW
# 3              3      Julian Brandt  de GER  FW,MF
# 4              4  Nikola Milenković  rs SRB     DF
# ...          ...                ...     ...    ...
# 1507        2504   Souleymane Touré  fr FRA     DF
# 1508        2506        Jere Uronen  fi FIN     DF
# 1509        2507         Yan Valery  tn TUN     DF
# 1510        2513            Vitinha  pt POR     MF
# 1511        2518  Alessandro Zanoli  it ITA     DF
#
#                                                   Squad  \
# 0                                                 Milan
# 1     RB Leipzig+RB Leipzig+Bayern Munich+Manchester...
# 2                           Juventus+Tottenham+Juventus
# 3                                              Dortmund
# 4                                            Fiorentina
# ...                                                 ...
# 1507                                  Marseille+Auxerre
# 1508                                   Brest+Schalke 04
# 1509                                 Southampton+Angers
# 1510                                Marseille+Paris S-G
# 1511                                   Sampdoria+Napoli
#
#                                                 Comp   Age    Born     MP  \
# 0                                         it Serie A  25.0  1997.0   97.0
# 1     de Bundesliga+eng Premier League+de Bundesliga  29.0  1994.0   80.0
# 2           it Serie A+eng Premier League+it Serie A  23.0  2000.0  103.0
# 3                                      de Bundesliga  27.0  1996.0   94.0
# 4                                         it Serie A  25.0  1997.0   95.0
# ...                                              ...   ...     ...    ...
# 1507                                      fr Ligue 1  19.0  2003.0   24.0
# 1508                        fr Ligue 1+de Bundesliga  28.0  1994.0   17.0
# 1509                   eng Premier League+fr Ligue 1  23.0  1999.0   31.0
# 1510                                      fr Ligue 1  22.0  2000.0   50.0
# 1511                                      it Serie A  21.0  2000.0   23.0
#
#       Starts      Min   90s  Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  \
# 0       95.0     8415  93.5         0.17       0.31        0.15          0.29
# 1       46.0    53186  47.1         0.21       0.34        0.13          0.25
# 2       61.0  1265762  67.0         0.18       0.49        0.18          0.49
# 3       68.0     5970  66.3         0.32       0.59        0.32          0.59
# 4       91.0     8097  89.9         0.07       0.09        0.07          0.09
# ...      ...      ...   ...          ...        ...         ...           ...
# 1507    18.0     1656  18.4         0.05       0.05        0.05          0.05
# 1508    12.0      976  10.8         0.00       0.09        0.00          0.09
# 1509    31.0     2542  28.2         0.00       0.00        0.00          0.00
# 1510    34.0     2910  32.4         0.12       0.22        0.12          0.22
# 1511    16.0     1552  17.2         0.12       0.29        0.12          0.29
#
#       xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 0         0.13          0.28        0.11            0.26               272.0
# 1         0.25          0.31        0.17            0.25                38.0
# 2         0.15          0.36        0.15            0.36               260.0
# 3         0.18          0.43        0.18            0.43               185.0
# 4         0.09          0.10        0.09            0.10                13.0
# ...        ...           ...         ...             ...                 ...
# 1507      0.08          0.02        0.08            0.02                19.0
# 1508      0.01          0.13        0.01            0.13                12.0
# 1509      0.03          0.07        0.03            0.07                69.0
# 1510      0.22          0.88        0.22            0.88                64.0
# 1511      0.16          0.15        0.16            0.15                45.0
#
#       Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 0             141.0            52.0             118.0               43.0
# 1              22.0            58.0              15.0               39.0
# 2             138.0            53.0             114.0               44.0
# 3             102.0            55.0              78.0               42.0
# 4              10.0            77.0               3.0               23.0
# ...             ...             ...               ...                ...
# 1507            8.0            42.0               8.0              100.0
# 1508            3.0            25.0               8.0                0.0
# 1509           33.0            48.0              28.0                0.0
# 1510           36.0            56.0              23.0               55.0
# 1511           27.0            60.0              12.0               27.0
#
#       Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 0              68.72                    2.58                   16.66
# 1              71.53                    1.78                   12.23
# 2              46.15                    0.64                    6.18
# 3              65.47                    0.73                    7.14
# 4              65.57                    6.49                   30.81
# ...              ...                     ...                     ...
# 1507           55.00                    7.77                   27.77
# 1508           59.17                    3.15                   16.11
# 1509           57.84                    4.08                   18.01
# 1510           73.67                    1.45                   10.46
# 1511           50.93                    4.30                   19.24
#
#       Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                      33.33                   19.91                    2.24
# 1                      40.19                   19.51                    2.02
# 2                      17.72                   23.27                    5.04
# 3                      29.89                   29.16                    2.85
# 4                      31.63                    3.61                    1.02
# ...                      ...                     ...                     ...
# 1507                   25.11                    2.83                    0.92
# 1508                   29.63                   13.89                    0.19
# 1509                   27.09                   13.55                    0.50
# 1510                   42.62                   21.33                    2.47
# 1511                   20.06                   12.56                    1.34
#
#       Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                         68.68                       2.91
# 1                         71.44                       0.81
# 2                         46.15                       3.88
# 3                         65.47                       2.79
# 4                         65.57                       0.15
# ...                         ...                        ...
# 1507                      55.00                       1.03
# 1508                      59.17                       1.11
# 1509                      57.84                       2.45
# 1510                      73.67                       1.98
# 1511                      50.93                       2.62
#
#       Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                     1.51                     1.26           39.18
# 1                     0.47                     0.32           38.74
# 2                     2.06                     1.70           29.58
# 3                     1.54                     1.18           38.78
# 4                     0.11                     0.03           35.61
# ...                    ...                      ...             ...
# 1507                  0.43                     0.43           38.64
# 1508                  0.28                     0.74           29.44
# 1509                  1.17                     0.99           37.66
# 1510                  1.11                     0.71           61.88
# 1511                  1.57                     0.70           26.86
#
#       Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                    278.91                               174.26
# 1                    162.38                                72.17
# 2                    207.92                               110.02
# 3                    212.82                                87.22
# 4                    160.19                                89.36
# ...                     ...                                  ...
# 1507                 217.55                               106.90
# 1508                 130.46                                56.02
# 1509                 253.30                               125.28
# 1510                 325.49                               146.39
# 1511                 164.88                                99.19
#
#       Progressive_Carries_per_90  1/3_Carries_per_90  \
# 0                           4.00                2.88
# 1                           1.27                1.38
# 2                           3.97                2.09
# 3                           2.60                1.75
# 4                           0.52                0.49
# ...                          ...                 ...
# 1507                        0.65                0.38
# 1508                        1.11                0.83
# 1509                        2.55                2.55
# 1510                        1.64                2.47
# 1511                        2.97                1.40
#
#       Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 0                            0.76                1.74                 0.75
# 1                            0.17                1.32                 0.98
# 2                            1.76                3.33                 2.06
# 3                            0.92                2.26                 1.42
# 4                            0.02                0.35                 0.09
# ...                           ...                 ...                  ...
# 1507                         0.00                0.43                 0.11
# 1508                         0.00                1.30                 0.28
# 1509                         0.21                1.28                 1.21
# 1510                         0.22                1.57                 1.27
# 1511                         0.64                0.87                 0.52
#
#       Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 0                      43.07                                5.08
# 1                      49.37                                3.82
# 2                      32.71                                8.75
# 3                      48.34                                8.01
# 4                      41.12                                0.30
# ...                      ...                                 ...
# 1507                   35.00                                0.38
# 1508                   30.46                                2.87
# 1509                   33.30                                2.62
# 1510                   58.86                                4.17
# 1511                   30.99                                3.60
#
#       Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 0                       3.040000                 0.380000
# 1                      11.670000                 1.170000
# 2                      16.760000                 3.630000
# 3                       4.610000                 0.810000
# 4                       0.710000                 0.080000
# ...                          ...                      ...
# 1507                   16.304348                 0.000000
# 1508                   13.722222                 0.305556
# 1509                   36.343972                 0.982270
# 1510                   63.049383                 8.555556
# 1511                   34.802326                 2.982558
#
#       Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 0                      1.86                   0.49                  0.15
# 1                      2.38                   0.02                  0.00
# 2                      3.00                   0.18                  0.48
# 3                      3.21                   0.92                  0.24
# 4                      0.59                   0.01                  0.01
# ...                     ...                    ...                   ...
# 1507                   0.87                   0.00                  0.05
# 1508                   1.48                   0.28                  0.09
# 1509                   0.89                   0.07                  0.18
# 1510                   2.10                   0.06                  0.09
# 1511                   1.51                   0.12                  0.41
#
#       Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 0                 0.18                     0.31                   1.86
# 1                 0.17                     0.08                   2.38
# 2                 0.28                     0.06                   3.00
# 3                 0.11                     0.12                   3.21
# 4                 0.10                     0.00                   0.59
# ...                ...                      ...                    ...
# 1507              0.05                     0.00                   0.00
# 1508              0.00                     0.19                   0.00
# 1509              0.07                     0.11                   0.00
# 1510              0.19                     0.09                   0.06
# 1511              0.06                     0.00                   0.00
#
#       Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 0                      0.29                   0.02                  0.02
# 1                      0.26                   0.00                  0.00
# 2                      0.42                   0.01                  0.09
# 3                      0.56                   0.12                  0.08
# 4                      0.05                   0.00                  0.00
# ...                     ...                    ...                   ...
# 1507                   0.00                   0.00                  0.00
# 1508                   0.09                   0.00                  0.00
# 1509                   0.04                   0.00                  0.00
# 1510                   0.25                   0.00                  0.03
# 1511                   0.12                   0.00                  0.06
#
#       Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 0                 0.03                     0.01                   0.01
# 1                 0.02                     0.00                   0.00
# 2                 0.01                     0.00                   0.00
# 3                 0.01                     0.05                   0.00
# 4                 0.02                     0.00                   0.00
# ...                ...                      ...                    ...
# 1507              0.00                     0.00                   0.00
# 1508              0.00                     0.00                   0.00
# 1509              0.00                     0.00                   0.00
# 1510              0.03                     0.03                   0.00
# 1511              0.00                     0.00                   0.00
#
#       Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 0               4322.0            5383.0               80.0         69809.0
# 1               2306.0            2878.0               80.0         35602.0
# 2               1768.0            2242.0               79.0         24626.0
# 3               2851.0            3623.0               79.0         43730.0
# 4               4419.0            5076.0               87.0         86576.0
# ...                ...               ...                ...             ...
# 1507             713.0             820.0               87.0         13368.0
# 1508             400.0             530.0               75.0          7012.0
# 1509             965.0            1315.0               73.0         16999.0
# 1510            1863.0            2054.0               91.0         27171.0
# 1511             544.0             711.0               77.0          8897.0
#
#       Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 0            23453.0            2291.0            2557.0               90.0
# 1            10553.0            1258.0            1433.0               88.0
# 2             5878.0            1073.0            1230.0               87.0
# 3            11218.0            1558.0            1794.0               87.0
# 4            28099.0            1478.0            1657.0               89.0
# ...              ...               ...               ...                ...
# 1507          4272.0             233.0             274.0               85.0
# 1508          2847.0             183.0             211.0               87.0
# 1509          6836.0             423.0             513.0               82.0
# 1510          6003.0            1006.0            1079.0               93.0
# 1511          2760.0             269.0             300.0               90.0
#
#       Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 0                1580.0             1904.0                83.0
# 1                 806.0              954.0                84.0
# 2                 532.0              651.0                82.0
# 3                 844.0             1028.0                82.0
# 4                2369.0             2573.0                92.0
# ...                 ...                ...                 ...
# 1507              380.0              404.0                94.0
# 1508              161.0              195.0                83.0
# 1509              411.0              517.0                79.0
# 1510              634.0              683.0                93.0
# 1511              224.0              284.0                79.0
#
#       Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 0               336.0            593.0              57.0            0.00
# 1               147.0            272.0              54.0            0.06
# 2                80.0            140.0              57.0            0.17
# 3               265.0            446.0              59.0            0.00
# 4               527.0            720.0              73.0            0.00
# ...               ...              ...               ...             ...
# 1507             77.0            108.0              71.0            0.00
# 1508             44.0             86.0              51.0            0.09
# 1509             99.0            216.0              46.0            0.00
# 1510             98.0            117.0              84.0            0.09
# 1511             39.0             80.0              49.0            0.17
#
#       xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 0           0.15       0.14         -0.01               1.39
# 1           0.12       0.17          0.00               1.19
# 2           0.23       0.19          0.08               2.00
# 3           0.25       0.25          0.03               2.23
# 4           0.02       0.02          0.01               0.17
# ...          ...        ...           ...                ...
# 1507        0.02       0.02         -0.02               0.43
# 1508        0.10       0.15         -0.01               0.93
# 1509        0.07       0.06         -0.07               0.43
# 1510        0.10       0.11         -0.01               0.93
# 1511        0.07       0.05          0.10               0.81
#
#       Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 0                  3.25                        1.20
# 1                  5.12                        1.51
# 2                  1.26                        1.55
# 3                  2.93                        1.66
# 4                  3.27                        0.11
# ...                 ...                         ...
# 1507               2.39                        0.22
# 1508               2.87                        1.20
# 1509               2.48                        0.60
# 1510               5.46                        0.80
# 1511               1.10                        0.76
#
#       Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 0                            0.39                       4.03
# 1                            0.24                       7.05
# 2                            0.39                       2.92
# 3                            0.29                       5.23
# 4                            0.00                       3.50
# ...                           ...                        ...
# 1507                         0.00                       2.55
# 1508                         1.11                       4.17
# 1509                         0.50                       2.98
# 1510                         0.03                       4.51
# 1511                         0.41                       2.09
#
#       Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 0                       57.57                    47.03
# 1                       61.10                    57.54
# 2                       33.46                    31.49
# 3                       54.65                    50.00
# 4                       56.46                    53.29
# ...                       ...                      ...
# 1507                    44.57                    43.42
# 1508                    49.07                    38.89
# 1509                    46.63                    38.62
# 1510                    63.40                    62.31
# 1511                    41.34                    35.12
#
#       Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 0                       10.36                     1.73                  0.06
# 1                        3.04                     1.51                  0.12
# 2                        1.85                     0.18                  0.24
# 3                        4.46                     0.67                  0.21
# 4                        3.08                     1.94                  0.00
# ...                       ...                      ...                   ...
# 1507                     1.09                     1.03                  0.00
# 1508                     9.91                     1.11                  0.00
# 1509                     7.98                     0.74                  0.00
# 1510                     0.90                     0.31                  0.25
# 1511                     6.16                     0.70                  0.00
#
#       Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 0                0.59            3.15                    7.86
# 1                0.53            1.12                    1.38
# 2                0.09            2.30                    0.25
# 3                0.45            4.86                    0.49
# 4                0.77            0.09                    1.14
# ...               ...             ...                     ...
# 1507             0.27            0.16                    0.05
# 1508             0.19            3.98                    8.43
# 1509             0.21            2.91                    7.23
# 1510             0.19            0.43                    0.09
# 1511             0.12            1.98                    5.47
#
#       Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 0                    0.77                    0.04                     0.68
# 1                    0.04                    0.02                     0.00
# 2                    0.60                    0.19                     0.11
# 3                    3.24                    1.15                     1.55
# 4                    0.00                    0.00                     0.00
# ...                   ...                     ...                      ...
# 1507                 0.00                    0.00                     0.00
# 1508                 0.37                    0.09                     0.28
# 1509                 0.00                    0.00                     0.00
# 1510                 0.19                    0.06                     0.09
# 1511                 0.00                    0.00                     0.00
#
#       Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 0                        0.00              46.22               0.18
# 1                        0.00              48.96               0.53
# 2                        0.00              26.39               0.12
# 3                        0.04              43.00               0.18
# 4                        0.00              49.15               0.09
# ...                       ...                ...                ...
# 1507                     0.00              38.75               0.05
# 1508                     0.00              37.04               0.28
# 1509                     0.00              34.22               0.04
# 1510                     0.00              57.50               0.19
# 1511                     0.00              31.63               0.06
#
#       Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 0                      1.28           1.480000               0.400000
# 1                      1.21           9.360000               2.940000
# 2                      1.20           8.890000               2.910000
# 3                      1.13           1.480000               0.740000
# 4                      0.42           0.700000               0.260000
# ...                     ...                ...                    ...
# 1507                   0.49           7.652174               1.913043
# 1508                   1.48           3.083333               0.000000
# 1509                   1.38          12.769504               1.964539
# 1510                   0.93          30.037037              10.679012
# 1511                   1.40          14.918605               6.965116
#
#       Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 0               3.60                     13.42           2.33     3.9
# 1               0.29                      0.94           0.24    -1.5
# 2               0.46                      1.42           0.37     2.0
# 3               4.81                      9.97           2.80     8.7
# 4               2.77                      7.77           3.86    -1.9
# ...              ...                       ...            ...     ...
# 1507            0.12                      0.50           0.19    -0.5
# 1508            0.00                      0.00           0.02    -0.1
# 1509            0.00                      0.00           0.06    -0.8
# 1510            0.07                      0.20           0.12    -3.0
# 1511            0.12                      0.25           0.17    -0.7
#
#       Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 0          3.6                       67.0                 0.25
# 1         -2.3                       48.0                 0.25
# 2          2.0                       32.0                 0.20
# 3          8.7                       31.0                 0.08
# 4         -1.9                       75.0                 0.24
# ...        ...                        ...                  ...
# 1507      -0.5                       71.0                 0.33
# 1508      -0.1                       53.0                 0.19
# 1509      -0.8                       63.0                 0.11
# 1510      -3.0                       37.0                 0.09
# 1511      -0.7                       33.0                 0.17
#
#       Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 0                 0.02                       0.01                    1.02
# 1                 0.00                       0.00                    1.12
# 2                 0.00                       0.00                    1.88
# 3                 0.00                       0.00                    0.41
# 4                 0.02                       0.01                    1.59
# ...                ...                        ...                     ...
# 1507              0.05                       0.05                    1.20
# 1508              0.00                       0.00                    0.74
# 1509              0.00                       0.00                    1.63
# 1510              0.00                       0.00                    1.17
# 1511              0.00                       0.00                    0.23
#
#       Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 0                   2.27             0.17                  0.83
# 1                   1.32             0.19                  1.34
# 2                   1.18             0.22                  0.60
# 3                   0.80             0.14                  0.84
# 4                   0.65             0.00                  1.17
# ...                  ...              ...                   ...
# 1507                0.71             0.00                  1.41
# 1508                1.85             0.00                  1.39
# 1509                0.71             0.04                  1.21
# 1510                0.83             0.12                  0.83
# 1511                0.58             0.00                  0.70
#
#       Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 0                   0.94                      0.02
# 1                   1.08                      0.00
# 2                   0.88                      0.00
# 3                   0.80                      0.00
# 4                   0.95                      0.00
# ...                  ...                       ...
# 1507                0.76                      0.00
# 1508                1.39                      0.00
# 1509                1.38                      0.00
# 1510                0.99                      0.00
# 1511                0.81                      0.00
#
#       Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                              0.00                    6.63
# 1                              0.00                    6.73
# 2                              0.01                    5.44
# 3                              0.00                    5.41
# 4                              0.02                    4.97
# ...                             ...                     ...
# 1507                           0.05                    4.78
# 1508                           0.00                    5.46
# 1509                           0.00                    5.07
# 1510                           0.00                    5.90
# 1511                           0.00                    4.59
#
#       Aerials_Won_per_90  Aerials_Lost_per_90  Seasons at top 5  \
# 0                   1.20                 0.58                 3
# 1                   0.98                 1.04                 3
# 2                   0.39                 0.83                 3
# 3                   0.47                 1.04                 3
# 4                   3.03                 1.02                 3
# ...                  ...                  ...               ...
# 1507                1.36                 0.54                 1
# 1508                1.67                 1.48                 1
# 1509                1.35                 0.78                 1
# 1510                0.31                 0.52                 1
# 1511                0.58                 1.16                 1
#
#       Seasons in PL  Seasons in Liga  Seasons in Serie A  Seasons in Ligue 1  \
# 0                 0                0                   3                   0
# 1                 1                0                   0                   0
# 2                 2                0                   2                   0
# 3                 0                0                   0                   0
# 4                 0                0                   3                   0
# ...             ...              ...                 ...                 ...
# 1507              0                0                   0                   1
# 1508              0                0                   0                   1
# 1509              1                0                   0                   1
# 1510              0                0                   0                   1
# 1511              0                0                   1                   0
#
#       Seasons in Bundesliga
# 0                         0
# 1                         3
# 2                         0
# 3                         3
# 4                         0
# ...                     ...
# 1507                      0
# 1508                      1
# 1509                      0
# 1510                      0
# 1511                      0
#
# [1512 rows x 124 columns]

# %%
# Assuming 'final_player' is the DataFrame containing player data

# Filter out forwards (FW) and midfielders (MF) from the 'final_player' DataFrame
defense_players = final_player[final_player['Pos'].isin(['DF'])]
newbie = newbie[newbie['Pos'].isin(['DF'])]
player_2021 = player_2021[player_2021['Pos'].isin(['DF'])]
player_2022 = player_2022[player_2022['Pos'].isin(['DF'])]
player_2023 = player_2023[player_2023['Pos'].isin(['DF'])]
player_2024 = player_2024[player_2024['Pos'].isin(['DF'])]

# Reset the index if needed
defense_players = defense_players.reset_index(drop=True)
newbie = newbie.reset_index(drop=True)
player_2024= player_2024.reset_index(drop=True)
player_2023 = player_2023.reset_index(drop=True)
player_2022 = player_2022.reset_index(drop=True)
player_2021 = player_2021.reset_index(drop=True)

# %%
# Filter player_2023
player_2024 = player_2024.loc[player_2024['Min'] >= 900]

# Filter player_2023
player_2023 = player_2023.loc[player_2023['Min'] >= 900]

# Filter player_2022
player_2022 = player_2022.loc[player_2022['Min'] >= 900]

# Filter player_2021
player_2021 = player_2021.loc[player_2021['Min'] >= 900]

player_2024
# Out:
#      Unnamed: 0            Player   Nation Pos                     Squad  \
# 0             0        Max Aarons  eng ENG  DF               Bournemouth
# 1             4  Yunis Abdelhamid   ma MAR  DF                     Reims
# 2             9             Abner   br BRA  DF                     Betis
# 3            11       Abdel Abqar   ma MAR  DF                    Alavés
# 4            13  Francesco Acerbi   it ITA  DF                     Inter
# ..          ...               ...      ...  ..                       ...
# 564         107   Sergio Reguilón   es ESP  DF  Manchester Utd+Brentford
# 565         115       Alidu Seidu   gh GHA  DF      Rennes+Clermont Foot
# 566         129        Kevin Vogt   de GER  DF   Hoffenheim+Union Berlin
# 567         133  Mateusz Wieteska   pl POL  DF    Cagliari+Clermont Foot
# 568         138      Nadir Zortea   it ITA  DF        Frosinone+Atalanta
#
#                       Comp  Age    Born  MP  Starts   Min   90s  Goals_per90  \
# 0       eng Premier League  0.0  2000.0  20      13  1237  13.7         0.00
# 1               fr Ligue 1  0.0  1987.0  31      31  2781  30.9         0.13
# 2               es La Liga  0.0  2000.0  23      15  1400  15.6         0.00
# 3               es La Liga  0.0  1999.0  27      27  2312  25.7         0.00
# 4               it Serie A  0.0  1988.0  29      26  2388  26.5         0.11
# ..                     ...  ...     ...  ..     ...   ...   ...          ...
# 564     eng Premier League  0.0  1996.0  25      18  1530  17.0         0.00
# 565             fr Ligue 1  0.0  2000.0  25      20  1724  19.2         0.00
# 566          de Bundesliga  0.0  1991.0  32      30  2642  29.4         0.00
# 567  it Serie A+fr Ligue 1  0.0  1997.0  21      12  1139  12.6         0.08
# 568             it Serie A  0.0  1999.0  19      14  1407  15.7         0.13
#
#      G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 0         0.07        0.00          0.07      0.00          0.06        0.00
# 1         0.13        0.10          0.10      0.11          0.12        0.09
# 2         0.06        0.00          0.06      0.01          0.07        0.01
# 3         0.00        0.00          0.00      0.02          0.02        0.02
# 4         0.15        0.11          0.15      0.06          0.13        0.06
# ..         ...         ...           ...       ...           ...         ...
# 564       0.24        0.00          0.24      0.06          0.27        0.06
# 565       0.05        0.00          0.05      0.02          0.09        0.02
# 566       0.00        0.00          0.00      0.02          0.05        0.02
# 567       0.16        0.08          0.16      0.03          0.03        0.03
# 568       0.45        0.13          0.45      0.03          0.19        0.03
#
#      npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 0              0.06                34.0           14.0            41.2
# 1              0.09                15.0            8.0            53.3
# 2              0.07                13.0            7.0            53.8
# 3              0.02                 5.0            3.0            60.0
# 4              0.13                 3.0            2.0            66.7
# ..              ...                 ...            ...             ...
# 564            0.27                37.0           16.0            43.0
# 565            0.09                36.0           17.0            47.0
# 566            0.05                 7.0            6.0            86.0
# 567            0.03                 6.0            3.0            50.0
# 568            0.19                52.0           22.0            42.0
#
#      Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 0                12.0               35.3           51.90
# 1                 7.0               46.7           70.71
# 2                 5.0               38.5           61.92
# 3                 1.0               20.0           40.16
# 4                 1.0               33.3           74.60
# ..                ...                ...             ...
# 564              15.0               41.0           63.88
# 565              15.0               42.0           70.00
# 566               1.0               14.0           65.44
# 567               3.0               50.0           55.56
# 568              25.0               48.0           53.69
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 0                      3.14                   18.39                   22.12
# 1                      9.48                   31.59                   36.21
# 2                      4.62                   22.05                   25.96
# 3                      7.43                   22.18                   16.42
# 4                      8.26                   35.51                   35.70
# ..                      ...                     ...                     ...
# 564                    3.71                   18.35                   24.00
# 565                    4.74                   25.68                   36.61
# 566                    8.57                   34.18                   29.59
# 567                    7.22                   28.89                   24.92
# 568                    2.04                   11.46                   22.10
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 0                     12.04                    0.80
# 1                      3.69                    1.13
# 2                     14.49                    1.79
# 3                      1.63                    0.82
# 4                      3.70                    0.94
# ..                      ...                     ...
# 564                   22.53                    1.82
# 565                    8.54                    0.16
# 566                    1.87                    0.27
# 567                    2.22                    0.79
# 568                   20.57                    1.66
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 0                        51.90                       2.48
# 1                        70.68                       0.49
# 2                        61.92                       0.83
# 3                        40.16                       0.19
# 4                        74.60                       0.11
# ..                         ...                        ...
# 564                      63.88                       2.18
# 565                      70.00                       1.88
# 566                      65.44                       0.24
# 567                      55.56                       0.48
# 568                      53.69                       3.31
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 0                    1.02                     0.88           26.57
# 1                    0.26                     0.23           48.74
# 2                    0.45                     0.32           28.65
# 3                    0.12                     0.04           19.14
# 4                    0.08                     0.04           45.70
# ..                    ...                      ...             ...
# 564                  0.94                     0.88           29.53
# 565                  0.89                     0.78           48.85
# 566                  0.20                     0.03           36.05
# 567                  0.24                     0.24           30.79
# 568                  1.40                     1.59           26.11
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 0                   158.69                                81.82
# 1                   280.36                               159.26
# 2                   115.51                                60.83
# 3                    95.72                                55.18
# 4                   218.08                               116.26
# ..                     ...                                  ...
# 564                 166.76                                94.18
# 565                 313.07                               139.22
# 566                 192.41                               111.19
# 567                 177.78                               114.60
# 568                 148.09                                70.64
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 0                          1.61                0.88
# 1                          1.17                0.61
# 2                          0.90                0.64
# 3                          0.27                0.23
# 4                          0.79                0.42
# ..                          ...                 ...
# 564                        2.65                1.71
# 565                        1.56                1.72
# 566                        0.58                0.24
# 567                        1.27                0.16
# 568                        2.42                1.72
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 0                           0.51                0.95                 0.58
# 1                           0.00                0.74                 0.13
# 2                           0.32                1.15                 0.71
# 3                           0.00                0.58                 0.04
# 4                           0.00                0.15                 0.04
# ..                           ...                 ...                  ...
# 564                         0.24                1.76                 0.35
# 565                         0.05                1.25                 0.47
# 566                         0.00                0.44                 0.07
# 567                         0.00                0.40                 0.24
# 568                         0.38                2.04                 1.08
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 0                     27.08                                1.90
# 1                     45.40                                0.29
# 2                     32.18                                3.72
# 3                     19.42                                0.04
# 4                     54.57                                0.91
# ..                      ...                                 ...
# 564                   32.29                                4.59
# 565                   43.07                                1.41
# 566                   42.79                                0.44
# 567                   33.81                                0.16
# 568                   30.51                                5.92
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 0                          1.68                     0.15
# 1                          0.78                     0.03
# 2                          0.90                     0.00
# 3                          0.47                     0.00
# 4                          0.83                     0.04
# ..                          ...                      ...
# 564                        2.94                     0.41
# 565                        1.09                     0.05
# 566                        1.12                     0.17
# 567                        0.79                     0.08
# 568                        3.25                     0.57
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 0                     1.17                   0.29                  0.00
# 1                     0.61                   0.03                  0.00
# 2                     0.83                   0.00                  0.00
# 3                     0.35                   0.00                  0.00
# 4                     0.72                   0.00                  0.00
# ..                     ...                    ...                   ...
# 564                   1.94                   0.71                  0.06
# 565                   0.73                   0.10                  0.05
# 566                   1.12                   0.00                  0.00
# 567                   0.71                   0.00                  0.00
# 568                   2.36                   0.38                  0.19
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 0                0.00                     0.22                   0.00
# 1                0.10                     0.03                   0.00
# 2                0.06                     0.00                   0.00
# 3                0.08                     0.04                   0.00
# 4                0.11                     0.00                   0.00
# ..                ...                      ...                    ...
# 564              0.18                     0.06                   0.00
# 565              0.00                     0.16                   0.05
# 566              0.00                     0.00                   0.00
# 567              0.00                     0.00                   0.08
# 568              0.19                     0.06                   0.06
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 0                     0.15                   0.00                  0.00
# 1                     0.00                   0.00                  0.00
# 2                     0.00                   0.00                  0.00
# 3                     0.00                   0.00                  0.00
# 4                     0.04                   0.00                  0.00
# ..                     ...                    ...                   ...
# 564                   0.18                   0.12                  0.00
# 565                   0.05                   0.00                  0.00
# 566                   0.17                   0.00                  0.00
# 567                   0.08                   0.00                  0.00
# 568                   0.51                   0.00                  0.06
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 0                0.00                      0.0                    0.0
# 1                0.03                      0.0                    0.0
# 2                0.00                      0.0                    0.0
# 3                0.00                      0.0                    0.0
# 4                0.00                      0.0                    0.0
# ..                ...                      ...                    ...
# 564              0.12                      0.0                    0.0
# 565              0.00                      0.0                    0.0
# 566              0.00                      0.0                    0.0
# 567              0.00                      0.0                    0.0
# 568              0.00                      0.0                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 0               450.0             581.0               77.5          7402.0
# 1              1552.0            1836.0               84.5         29618.0
# 2               615.0             797.0               77.2          9211.0
# 3               553.0             762.0               72.6         12370.0
# 4              1615.0            1781.0               90.7         29326.0
# ..                ...               ...                ...             ...
# 564             595.0             836.0               71.0          9726.0
# 565             932.0            1118.0               83.0         16513.0
# 566            1465.0            1674.0               88.0         32160.0
# 567             463.0             576.0               80.0          9154.0
# 568             487.0             664.0               73.0          7876.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 0            2789.0             220.0             248.0               88.7
# 1            9672.0             487.0             548.0               88.9
# 2            4552.0             351.0             394.0               89.1
# 3            4872.0             141.0             164.0               86.0
# 4            9174.0             601.0             650.0               92.5
# ..              ...               ...               ...                ...
# 564          3982.0             298.0             351.0               85.0
# 565          4733.0             397.0             433.0               92.0
# 566         13483.0             360.0             381.0               94.0
# 567          4116.0             144.0             164.0               88.0
# 568          3172.0             262.0             303.0               86.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 0                188.0              235.0                80.0
# 1                893.0              976.0                91.5
# 2                203.0              265.0                76.6
# 3                302.0              339.0                89.1
# 4                856.0              908.0                94.3
# ..                 ...                ...                 ...
# 564              231.0              312.0                74.0
# 565              428.0              502.0                85.0
# 566              805.0              875.0                92.0
# 567              270.0              301.0                90.0
# 568              166.0              219.0                76.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 0               34.0             63.0              54.0            0.07
# 1              141.0            252.0              56.0            0.00
# 2               37.0             79.0              46.8            0.06
# 3               99.0            225.0              44.0            0.00
# 4              132.0            179.0              73.7            0.04
# ..               ...              ...               ...             ...
# 564             50.0            108.0              46.0            0.24
# 565             79.0            142.0              56.0            0.05
# 566            277.0            381.0              73.0            0.00
# 567             46.0             99.0              46.0            0.08
# 568             45.0             88.0              51.0            0.32
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 0          0.06       0.07          0.01               0.51
# 1          0.01       0.02         -0.01               0.26
# 2          0.06       0.06          0.00               0.51
# 3          0.01       0.01         -0.01               0.12
# 4          0.07       0.05         -0.03               0.26
# ..          ...        ...           ...                ...
# 564        0.21       0.16          0.03               1.65
# 565        0.04       0.02          0.01               0.42
# 566        0.00       0.02         -0.00               0.10
# 567        0.05       0.02          0.03               0.40
# 568        0.20       0.15          0.12               1.53
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 0                 1.82                        0.95
# 1                 4.17                        0.10
# 2                 1.28                        0.45
# 3                 2.37                        0.08
# 4                 2.19                        0.19
# ..                 ...                         ...
# 564               2.18                        1.24
# 565               3.12                        0.21
# 566               3.74                        0.44
# 567               3.10                        0.40
# 568               1.85                        1.85
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 0                           0.15                       3.14
# 1                           0.00                       4.43
# 2                           0.13                       2.12
# 3                           0.00                       1.91
# 4                           0.08                       3.28
# ..                           ...                        ...
# 564                         0.88                       3.82
# 565                         0.00                       2.92
# 566                         0.00                       4.25
# 567                         0.08                       3.10
# 568                         1.27                       3.31
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 0                      42.41                    33.07
# 1                      59.42                    53.40
# 2                      51.09                    40.26
# 3                      29.65                    27.39
# 4                      67.21                    64.87
# ..                       ...                      ...
# 564                    49.18                    40.00
# 565                    58.23                    52.34
# 566                    56.94                    53.88
# 567                    45.71                    42.78
# 568                    42.29                    32.48
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 0                       9.27                     0.80                  0.15
# 1                       5.76                     2.43                  0.06
# 2                      10.58                     0.45                  0.00
# 3                       2.14                     1.95                  0.00
# 4                       2.26                     1.62                  0.00
# ..                       ...                      ...                   ...
# 564                     8.88                     2.00                  0.06
# 565                     5.62                     0.83                  0.00
# 566                     2.96                     2.18                  0.03
# 567                     2.94                     1.35                  0.08
# 568                     9.75                     0.45                  0.00
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 0               0.22            0.95                    8.47
# 1               0.42            0.10                    0.94
# 2               0.19            1.67                   10.13
# 3               0.66            0.08                    0.16
# 4               0.42            0.34                    0.30
# ..               ...             ...                     ...
# 564             0.12            5.94                    4.94
# 565             0.16            0.52                    4.79
# 566             0.41            0.10                    0.44
# 567             0.08            0.32                    1.51
# 568             0.00            5.48                    8.15
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 0                   0.00                    0.00                     0.00
# 1                   0.00                    0.00                     0.00
# 2                   0.00                    0.00                     0.00
# 3                   0.00                    0.00                     0.00
# 4                   0.00                    0.00                     0.00
# ..                   ...                     ...                      ...
# 564                 1.94                    0.53                     0.88
# 565                 0.00                    0.00                     0.00
# 566                 0.00                    0.00                     0.00
# 567                 0.00                    0.00                     0.00
# 568                 1.15                    0.00                     0.89
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 0                       0.00              32.85               0.07
# 1                       0.00              50.23               0.26
# 2                       0.00              39.42               0.26
# 3                       0.00              21.52               0.12
# 4                       0.00              60.94               0.08
# ..                       ...                ...                ...
# 564                     0.00              35.00               0.29
# 565                     0.00              48.54               0.26
# 566                     0.00              49.83               0.10
# 567                     0.00              36.75               0.00
# 568                     0.06              31.02               0.06
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 0                     1.68               0.15                   0.00
# 1                     0.65               0.68                   0.23
# 2                     1.47               0.26                   0.00
# 3                     0.39               0.39                   0.12
# 4                     0.19               0.57                   0.23
# ..                     ...                ...                    ...
# 564                   1.53               1.00                   0.06
# 565                   0.52               0.42                   0.05
# 566                   0.24               0.10                   0.03
# 567                   0.79               0.56                   0.16
# 568                   1.91               0.76                   0.32
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 0              0.00                      0.00           0.02     0.0
# 1              0.14                      0.43           0.13     0.6
# 2              0.00                      0.00           0.03    -0.1
# 3              0.00                      0.00           0.05    -0.5
# 4              0.20                      0.50           0.11     1.4
# ..              ...                       ...            ...     ...
# 564            0.00                      0.00           0.06    -1.0
# 565            0.00                      0.00           0.04    -0.3
# 566            0.00                      0.00           0.23    -0.7
# 567            0.14                      0.50           0.06     0.6
# 568            0.17                      0.40           0.04     1.5
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 0         0.0                       31.3                 0.07
# 1         0.4                       62.2                 0.16
# 2        -0.1                       58.3                 0.19
# 3        -0.5                       52.0                 0.39
# 4         1.4                       65.4                 0.04
# ..        ...                        ...                  ...
# 564      -1.0                       40.0                 0.41
# 565      -0.3                       63.0                 0.42
# 566      -0.7                       58.0                 0.24
# 567       0.6                       61.0                 0.40
# 568       1.5                       32.0                 0.25
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 0                0.00                       0.00                    0.88
# 1                0.00                       0.00                    0.84
# 2                0.00                       0.00                    1.03
# 3                0.00                       0.00                    1.28
# 4                0.00                       0.00                    0.72
# ..                ...                        ...                     ...
# 564              0.06                       0.00                    0.82
# 565              0.05                       0.00                    1.46
# 566              0.00                       0.00                    0.95
# 567              0.08                       0.08                    0.95
# 568              0.00                       0.00                    1.21
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 0                  1.90             0.15                  0.58
# 1                  0.39             0.00                  1.26
# 2                  0.13             0.13                  0.96
# 3                  0.89             0.04                  0.89
# 4                  0.91             0.11                  1.21
# ..                  ...              ...                   ...
# 564                1.53             0.24                  1.24
# 565                2.24             0.05                  1.82
# 566                0.58             0.03                  0.54
# 567                0.63             0.08                  1.51
# 568                1.02             0.00                  0.32
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 0                  1.39                       0.0
# 1                  1.13                       0.0
# 2                  1.22                       0.0
# 3                  0.74                       0.0
# 4                  0.49                       0.0
# ..                  ...                       ...
# 564                1.65                       0.0
# 565                1.72                       0.0
# 566                0.65                       0.0
# 567                0.95                       0.0
# 568                1.15                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 0                             0.07                    5.47
# 1                             0.00                    4.82
# 2                             0.06                    5.06
# 3                             0.08                    4.24
# 4                             0.00                    3.85
# ..                             ...                     ...
# 564                           0.06                    5.65
# 565                           0.05                    7.29
# 566                           0.00                    5.88
# 567                           0.00                    4.68
# 568                           0.00                    3.63
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Tackles_per_90  \
# 0                  0.36                 0.80            2.12
# 1                  1.97                 1.20            2.07
# 2                  0.90                 0.64            1.60
# 3                  1.52                 1.40            1.36
# 4                  2.64                 1.40            0.83
# ..                  ...                  ...             ...
# 564                1.12                 1.71            3.41
# 565                1.15                 0.68            2.76
# 566                0.75                 0.54            0.82
# 567                2.46                 1.59            1.43
# 568                0.70                 1.46            1.66
#
#      Tackles_Def_3rd_per_90  Tackles_Mid_3rd_per_90  Tackles_Att_3rd_per_90  \
# 0                      1.46                    0.51                    0.15
# 1                      1.17                    0.74                    0.16
# 2                      0.96                    0.58                    0.06
# 3                      1.09                    0.19                    0.08
# 4                      0.60                    0.23                    0.00
# ..                      ...                     ...                     ...
# 564                    1.88                    1.18                    0.35
# 565                    1.77                    0.94                    0.05
# 566                    0.44                    0.37                    0.00
# 567                    0.95                    0.32                    0.16
# 568                    0.70                    0.89                    0.06
#
#      Dribblers_Tackled_per_90  Dribblers_Challenged_per_90  \
# 0                        1.46                         2.48
# 1                        0.84                         1.46
# 2                        1.09                         2.18
# 3                        0.82                         1.36
# 4                        0.42                         0.53
# ..                        ...                          ...
# 564                      1.88                         3.35
# 565                      1.98                         2.60
# 566                      0.48                         0.85
# 567                      0.48                         1.19
# 568                      0.70                         1.66
#
#      Dribblers_Tackle_Lost_per_90  Blocks_per_90  Shots_Blocked_per_90  \
# 0                            1.02           0.66                  0.36
# 1                            0.61           1.65                  1.04
# 2                            1.09           1.47                  0.32
# 3                            0.54           1.21                  1.01
# 4                            0.11           0.75                  0.49
# ..                            ...            ...                   ...
# 564                          1.47           1.94                  0.35
# 565                          0.62           1.35                  0.52
# 566                          0.37           1.29                  0.95
# 567                          0.71           1.11                  0.56
# 568                          0.96           0.96                  0.32
#
#      Tackles+Interceptions_per_90  Clearances_per_90  Errors_Shots_per_90  \
# 0                            2.70               1.97                 0.00
# 1                            3.33               3.53                 0.06
# 2                            2.56               3.97                 0.00
# 3                            2.26               4.47                 0.00
# 4                            2.04               2.91                 0.04
# ..                            ...                ...                  ...
# 564                          4.65               2.82                 0.06
# 565                          4.58               2.60                 0.00
# 566                          1.36               4.29                 0.07
# 567                          2.94               4.44                 0.00
# 568                          1.97               2.04                 0.06
#
#      Dribblers_Tackle_W%
# 0                   58.8
# 1                   57.8
# 2                   50.0
# 3                   60.0
# 4                   78.6
# ..                   ...
# 564                 56.0
# 565                 76.0
# 566                 56.0
# 567                 40.0
# 568                 42.0
#
# [569 rows x 131 columns]

# %%
Trent=defense_players[defense_players['Player']=='Trent Alexander-Arnold']
Trent
# Out:
#      Unnamed: 0                  Player   Nation Pos      Squad  \
# 218         597  Trent Alexander-Arnold  eng ENG  DF  Liverpool
#
#                    Comp   Age    Born     MP  Starts   Min   90s  Goals_per90  \
# 218  eng Premier League  24.0  1998.0  105.0   100.0  8807  97.9         0.06
#
#      G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  \
# 218       0.35        0.06          0.35      0.07          0.41        0.07
#
#      npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  \
# 218            0.41               145.0           81.0            56.0
#
#      Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 218              62.0               43.0           97.39
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 218                    2.38                   20.82                   46.07
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 218                   31.23                    2.12
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 218                      97.39                       1.48
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 218                  0.83                     0.63           53.87
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 218                 224.69                               118.26
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 218                        1.98                1.93
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 218                         0.47                1.09                 0.63
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 218                   62.73                                6.02
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 218                        4.24                     0.49
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 218                   2.66                   1.24                  0.12
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 218              0.19                     0.02                   2.66
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 218                   0.36                   0.08                  0.02
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 218              0.03                      0.0                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 218            6472.0            8684.0               75.0        122421.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 218         47760.0            2905.0            3271.0               89.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 218             2530.0             3238.0                78.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 218            931.0           1823.0              51.0             0.0
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 218        0.33        0.3         -0.04               2.43
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 218               6.92                        2.74
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 218                         0.84                       7.69
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 218                     88.7                    72.66
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 218                    15.78                     2.23                   0.5
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 218             1.87            8.39                   10.12
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 218                 3.42                    0.62                     2.29
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 218                     0.03              66.11               0.27
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 218                   1.26               1.49                   0.36
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 218            1.31                      5.44           1.61    -1.4
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 218      -1.4                       47.0                 0.09
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 218               0.0                        0.0                    0.56
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 218                0.22             0.21                  1.38
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 218                0.98                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 218                           0.01                    7.48
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Seasons at top 5  Seasons in PL  \
# 218                0.44                  0.5                 3              3
#
#      Seasons in Liga  Seasons in Serie A  Seasons in Ligue 1  \
# 218                0                   0                   0
#
#      Seasons in Bundesliga
# 218                      0

# %%
import pandas as pd





params=['Goals_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90', 'xG_per90', 'xG+xAG_per90', 'npxG_per90',
        'npxG+xAG_per90', 'Take_Ons_Attempted', 'Take_Ons_Succ', 'Take_Ons_Succ%', 'Tackled_Take_Ons', 
        'Tackled_Take_Ons%', 'Touches_per_90', 'Touches_Def_Pen_per_90', 'Touches_Def_3rd_per_90', 
        'Touches_Mid_3rd_per_90', 'Touches_Att_3rd_per_90', 'Touches_Att_Pen_per_90', 'Tocuhes_Live_Balls_per_90',
        'Take_Ons_Attempted_per_90', 'Take_Ons_Succ_per_90', 'Tackled_Take_Ons_per_90', 'Carries_per_90', 
        'Total_Distance_per_90', 'Progressive_Distance_Carried_per_90', 'Progressive_Carries_per_90', 
        '1/3_Carries_per_90', 'Carries_Penalty_Area_per_90', 'Miscontrols_per_90', 'Dispossessed_per_90', 
        'Passes_Received_per_90', 'Progressive_Passes_Received_per_90', 'Shot_Creating_Action_per90', 
        'Goal_Creating_Action_90', 'Pass_Live_Shot_per_90', 'Pass_Dead_Shot_per_90', 'Take_Ons_Shot_per_90', 
        'Shot-Shot_per_90', 'Fouls_drawn_Shot_per_90', 'Defensive_Shot_per_90', 'Pass_Live_Goal_per_90',
        'Pass_Dead_Goal_per_90', 'Take_Ons_Goal_per_90', 'Shot_Goal_per_90', 'Fouls_Drawn_Goal_per_90', 
        'Defensive_Goal_per_90', 'Passes_Total_Cmp', 'Passes_Total_Att', 'Passes_Total_Cmp%', 'Passes_TotDist', 
        'Passes_PrgDist', 'Passes_Short_Cmp', 'Passes_Short_Att', 'Passes_Short_Cmp%', 'Passes_Medium_Cmp', 
        'Passes_Medium_Att', 'Passes_Medium_Cmp%', 'Passes_Long_Cmp', 'Passes_Long_Att', 'Passes_Long_Cmp%', 
        'Assists_per_90', 'xAG_per_90', 'xA_per_90', 'A-xAG_per_90', 'Key_Passes_per_90', 'Passes_1/3_per_90', 
        'Passes_Penalty_Area_per_90', 'Crosses_Penalty_Area_per_90', 'Progressive_Passes_per_90', 
        'Passes_Attempted_per_90', 'Live_Ball_Passes_per_90', 'Dead_Ball_Passes_per_90', 'Free_Kick_Passes_per_90',
        'Through_Balls_per_90', 'Switches_per_90', 'Crosses_per_90', 'Throw_Ins_Taken_per_90', 
        'Corner_Kicks_per_90', 'In_Corner_Kicks_per_90', 'Out_Corner_Kicks_per_90', 'Str_Corner_Kicks_per_90',
        'Passes_Cmp_per_90', 'Passes_Off_per_90', 'Passes_Blocked_per_90', 'Shots_total_per90', 
        'Shots_on_target_per90', 'Goals_per_shot', 'Goals_per_shot_on_target', 'Npxg_per_shot', 'Xg_net', 
        'Npxg_net', 'Percentage_of_Aerials_Won', 'Yellow_Cards_per_90', 'Red_Cards_per_90', 
        'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90', 'Fouls_Drawn_per_90', 'Offsides_per_90', 
        'Interceptions_per_90', 'Tackles_Won_per_90', 'Penalty_Kicks_Won_per_90', 'Penalty_Kicks_Conceded_per_90',
        'Ball_Recoveries_per_90', 'Aerials_Won_per_90', 'Aerials_Lost_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = defense_players[params].rank(pct=True) * 100

# Get the row of trent's stats from the percentile ranks DataFrame
trent_percentile_ranks = round(players_percentile_ranks.iloc[[218]],0)

# Print the percentile ranks for trent
trent_percentile_ranks
# Out:
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 218         69.0       99.0        70.0          99.0      79.0         100.0
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 218        80.0           100.0                95.0           95.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 218            47.0              94.0               68.0           100.0
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 218                     7.0                    31.0                    96.0
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 218                   100.0                    93.0
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 218                      100.0                       79.0
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 218                  82.0                     78.0            94.0
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 218                   73.0                                 69.0
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 218                        75.0                88.0
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 218                         92.0                74.0                 83.0
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 218                    96.0                                94.0
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 218                        94.0                     96.0
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 218                   99.0                   99.0                  89.0
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 218              96.0                     43.0                   99.0
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 218                   99.0                   98.0                  91.0
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 218              88.0                     37.0                   46.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 218              99.0             100.0               20.0            99.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 218           100.0             100.0             100.0               49.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 218               93.0               99.0                18.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 218            100.0            100.0              35.0            47.0
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 218       100.0      100.0          10.0              100.0
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 218               99.0                       100.0
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 218                         98.0                       99.0
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 218                    100.0                     95.0
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 218                     99.0                     92.0                 100.0
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 218            100.0            99.0                    97.0
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 218                 99.0                    97.0                    100.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 218                     99.0               94.0               90.0
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 218                   79.0               92.0                   89.0
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 218            59.0                      61.0           57.0    16.0
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 218      15.0                       19.0                 11.0
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 218              29.0                       40.0                     9.0
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 218                 4.0             96.0                  64.0
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 218                52.0                      40.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 218                           37.0                    97.0
#
#      Aerials_Won_per_90  Aerials_Lost_per_90
# 218                 4.0                  2.0

# %%
# Extract the percentile ranks, transpose, and sort them in descending order
trent_percentile_ranks_percentile_ranks_sorted = trent_percentile_ranks.T.sort_values(by=218, ascending=False)

# Get the top 20 parameters
top_20_params = trent_percentile_ranks_percentile_ranks_sorted.index[:30]
top_20_params_values = trent_percentile_ranks_percentile_ranks_sorted[218].head(30)

# Display the top 20 parameters and their values
print("Top 20 Parameters:")
print(top_20_params)
print("Values:")
print(top_20_params_values)
# Out:
# Top 20 Parameters:
# Index(['Passes_Short_Att', 'Touches_per_90', 'xAG_per_90', 'xA_per_90',
#        'Switches_per_90', 'Key_Passes_per_90', 'Passes_Penalty_Area_per_90',
#        'Tocuhes_Live_Balls_per_90', 'Through_Balls_per_90',
#        'Touches_Att_3rd_per_90', 'Passes_Long_Att', 'Passes_Long_Cmp',
#        'Passes_Total_Att', 'Out_Corner_Kicks_per_90', 'npxG+xAG_per90',
#        'Passes_Attempted_per_90', 'xG+xAG_per90', 'Passes_PrgDist',
#        'Passes_Short_Cmp', 'Passes_Medium_Att', 'Str_Corner_Kicks_per_90',
#        'Passes_Total_Cmp', 'Defensive_Shot_per_90', 'Corner_Kicks_per_90',
#        'Pass_Dead_Shot_per_90', 'Pass_Live_Shot_per_90', 'Passes_TotDist',
#        'Pass_Live_Goal_per_90', 'Crosses_per_90', 'Progressive_Passes_per_90'],
#       dtype='object')
# Values:
# Passes_Short_Att              100.0
# Touches_per_90                100.0
# xAG_per_90                    100.0
# xA_per_90                     100.0
# Switches_per_90               100.0
# Key_Passes_per_90             100.0
# Passes_Penalty_Area_per_90    100.0
# Tocuhes_Live_Balls_per_90     100.0
# Through_Balls_per_90          100.0
# Touches_Att_3rd_per_90        100.0
# Passes_Long_Att               100.0
# Passes_Long_Cmp               100.0
# Passes_Total_Att              100.0
# Out_Corner_Kicks_per_90       100.0
# npxG+xAG_per90                100.0
# Passes_Attempted_per_90       100.0
# xG+xAG_per90                  100.0
# Passes_PrgDist                100.0
# Passes_Short_Cmp              100.0
# Passes_Medium_Att              99.0
# Str_Corner_Kicks_per_90        99.0
# Passes_Total_Cmp               99.0
# Defensive_Shot_per_90          99.0
# Corner_Kicks_per_90            99.0
# Pass_Dead_Shot_per_90          99.0
# Pass_Live_Shot_per_90          99.0
# Passes_TotDist                 99.0
# Pass_Live_Goal_per_90          99.0
# Crosses_per_90                 99.0
# Progressive_Passes_per_90      99.0
# Name: 218, dtype: float64

# %%
import pandas as pd








params=['G+A-PK_per90', 'npxG+xAG_per90','Key_Passes_per_90',  'Goal_Creating_Action_90',
        'Shot_Creating_Action_per90','Shots_on_target_per90', 'Crosses_per_90',
        'xA_per_90','Passes_Penalty_Area_per_90', 'Ball_Recoveries_per_90',
        'Progressive_Passes_per_90', 'Progressive_Carries_per_90','Shot_Creating_Action_per90', 
        'Touches_Att_3rd_per_90', 'Through_Balls_per_90']



# Calculate percentile ranks for the goalkeepers in the larger DataFrame
players_percentile_ranks = defense_players[params].rank(pct=True) * 100

# Get the row of André Onana's stats from the percentile ranks DataFrame
trent_percentile_ranks = round(players_percentile_ranks.iloc[[218]],0)

# Print the percentile ranks for Declan Rice
trent_percentile_ranks
# Out:
#      G+A-PK_per90  npxG+xAG_per90  Key_Passes_per_90  Goal_Creating_Action_90  \
# 218          99.0           100.0              100.0                     96.0
#
#      Shot_Creating_Action_per90  Shots_on_target_per90  Crosses_per_90  \
# 218                        94.0                   89.0            99.0
#
#      xA_per_90  Passes_Penalty_Area_per_90  Ball_Recoveries_per_90  \
# 218      100.0                       100.0                    97.0
#
#      Progressive_Passes_per_90  Progressive_Carries_per_90  \
# 218                       99.0                        75.0
#
#      Shot_Creating_Action_per90  Touches_Att_3rd_per_90  Through_Balls_per_90
# 218                        94.0                   100.0                 100.0

# %%
len(params)
# Out:
# 15

# %%
trent_percentile_ranks_list = trent_percentile_ranks.values.flatten().tolist()

trent_percentile_ranks_list
# Out:
# [99.0,
#  100.0,
#  100.0,
#  96.0,
#  94.0,
#  89.0,
#  99.0,
#  100.0,
#  100.0,
#  97.0,
#  99.0,
#  75.0,
#  94.0,
#  100.0,
#  100.0]

# %%
image_path = "Trent.jpeg"
fdj_cropped = Image.open(image_path)

# %%
params=['Goals_+_Assists_per90', 'NonPenaltyxG_+_Expected_Assisted_Goals_per90','Key_Passes_per_90',  'Goal_Creating_Action_90',
        'Shot_Creating_Action_per90','Shots_on_target_per90', 'Crosses_per_90',
        'Expected_Assists_per_90','Passes_Penalty_Area_per_90', 'Ball_Recoveries_per_90',
        'Progressive_Passes_per_90', 'Progressive_Carries_per_90','Shot_Creating_Action_per90', 
        'Touches_Attacking_Third_per_90', 'Through_Balls_per_90']

split_params = [param.replace('_', '\n') for param in params]

# %%
params=['G+A-PK_per90', 'npxG+xAG_per90','Key_Passes_per_90',  'Goal_Creating_Action_90',
        'Shot_Creating_Action_per90','Shots_on_target_per90', 'Crosses_per_90',
        'xA_per_90','Passes_Penalty_Area_per_90', 'Ball_Recoveries_per_90',
        'Progressive_Passes_per_90', 'Progressive_Carries_per_90','Shot_Creating_Action_per90', 
        'Touches_Att_3rd_per_90', 'Through_Balls_per_90']

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    trent_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Trent Alexander-Arnold - FC Liverpool", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Premier League Stats Percentile Rank vs Top-Five Leagues Defenders | Last 4 Seasons",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Trent_Percentile.png',dpi=500,bbox_inches = 'tight')  # save as png

# %%
from sklearn.decomposition import PCA
import numpy as np

# Identify features to minimize
negative_features = ['Yellow_Cards_per_90', 'Red_Cards_per_90', 'Second_Yellow_Card_per_90', 'Fouls_Committed_per_90',
                     'Aerials_Lost_per_90','Miscontrols_per_90','Dispossessed_per_90', 'Penalty_Kicks_Conceded_per_90']

# Reverse the sign of negative features
for feature in negative_features:
    if feature in defense_players.columns:
        defense_players[feature] = -defense_players[feature]
        player_2024[feature]=-player_2024[feature]

# %%
# Normalize data
numerical_defense_players = defense_players[params].replace([np.inf, -np.inf], 0)
normalized_defense_players = (numerical_defense_players - numerical_defense_players.mean()) / numerical_defense_players.std()

# Apply PCA
pca = PCA()
pca.fit(normalized_defense_players)
explained_variances = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variances >= 0.95) + 1

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
transformed_players = pca.fit_transform(normalized_defense_players)

# Convert transformed data back to DataFrame
transformed_df = pd.DataFrame(transformed_players, index=defense_players.index)

# %%
# Get trent's row and compute cosine similarity
trent_index = defense_players.index[defense_players['Player'] == 'Trent Alexander-Arnold'][0]
trent_data = transformed_df.loc[trent_index].values.reshape(1, -1)

# Remove trent from the dataset for comparison
transformed_df = transformed_df.drop(index=trent_index)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(transformed_df, trent_data).flatten()
transformed_df['similarity_to_trent'] = similarity_scores

# Get top 10 players most similar to de Ligt
top_similar_players_indices = transformed_df.sort_values('similarity_to_trent', ascending=False).index
top_similar_players = defense_players.loc[top_similar_players_indices]

# %%
# Visualize the results
defense_players['similarity_to_trent'] = transformed_df['similarity_to_trent']
defense_players_sorted = defense_players.sort_values(by='similarity_to_trent', ascending=False)
defense_players_sorted
# Out:
#      Unnamed: 0                  Player   Nation Pos  \
# 146         422         Kieran Trippier  eng ENG  DF
# 142         403          Simone Bastoni   it ITA  DF
# 435         300             Neto Borges   br BRA  DF
# 314         869         Gonzalo Montiel   ar ARG  DF
# 52          136           Dani Carvajal   es ESP  DF
# ..          ...                     ...      ...  ..
# 400        1077     Ohis Felix Uduokhai   de GER  DF
# 436         322          Juan Brandáriz   es ESP  DF
# 70          182              Max Kilman  eng ENG  DF
# 279         770            Nehuén Pérez   ar ARG  DF
# 218         597  Trent Alexander-Arnold  eng ENG  DF
#
#                                              Squad  \
# 146  Atlético Madrid+Newcastle Utd+Atlético Madrid
# 142                                         Spezia
# 435                                  Clermont Foot
# 314                                        Sevilla
# 52                                     Real Madrid
# ..                                             ...
# 400                                       Augsburg
# 436                                        Almería
# 70                                          Wolves
# 279                                        Udinese
# 218                                      Liverpool
#
#                                          Comp   Age    Born     MP  Starts  \
# 146  es La Liga+eng Premier League+es La Liga  32.0  1990.0   87.0    83.0
# 142                                it Serie A  26.0  1996.0   72.0    60.0
# 435                                fr Ligue 1  25.0  1996.0   33.0    33.0
# 314                                es La Liga  24.0  1997.0   46.0    32.0
# 52                                 es La Liga  31.0  1992.0   64.0    48.0
# ..                                        ...   ...     ...    ...     ...
# 400                             de Bundesliga  22.0  1997.0   48.0    45.0
# 436                                es La Liga  23.0  1999.0   21.0    15.0
# 70                         eng Premier League  26.0  1997.0   85.0    81.0
# 279                                it Serie A  21.0  2000.0   54.0    52.0
# 218                        eng Premier League  24.0  1998.0  105.0   100.0
#
#         Min   90s  Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  \
# 146  435792  80.2         0.04       0.20        0.04          0.20      0.01
# 142    4999  55.5         0.11       0.36        0.11          0.36      0.07
# 435    2833  31.5         0.10       0.13        0.10          0.13      0.10
# 314    2590  28.7         0.03       0.21        0.03          0.21      0.03
# 52     4285  47.6         0.02       0.17        0.02          0.17      0.04
# ..      ...   ...          ...        ...         ...           ...       ...
# 400    4060  45.1         0.02       0.04        0.02          0.04      0.05
# 436    1489  16.5         0.06       0.06        0.06          0.06      0.02
# 70     7304  81.2         0.01       0.02        0.01          0.02      0.04
# 279    4510  50.1         0.04       0.06        0.04          0.06      0.04
# 218    8807  97.9         0.06       0.35        0.06          0.35      0.07
#
#      xG+xAG_per90  npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  \
# 146          0.23        0.01            0.23                75.0
# 142          0.23        0.07            0.23               128.0
# 435          0.19        0.10            0.18                94.0
# 314          0.17        0.03            0.17                31.0
# 52           0.14        0.04            0.14                49.0
# ..            ...         ...             ...                 ...
# 400          0.06        0.05            0.06                31.0
# 436          0.03        0.02            0.03                16.0
# 70           0.05        0.04            0.05                53.0
# 279          0.07        0.04            0.07                26.0
# 218          0.41        0.07            0.41               145.0
#
#      Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  \
# 146           46.0            61.0              25.0               33.0
# 142           74.0            58.0              51.0               40.0
# 435           47.0            50.0              40.0               42.6
# 314           13.0            42.0              17.0               55.0
# 52            27.0            55.0              19.0               39.0
# ..             ...             ...               ...                ...
# 400           20.0            65.0               9.0               29.0
# 436            7.0            43.8               9.0               56.3
# 70            43.0            81.0              10.0               19.0
# 279           12.0            46.0              14.0               54.0
# 218           81.0            56.0              62.0               43.0
#
#      Touches_per_90  Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  \
# 146           79.26                    3.15                   20.55
# 142           64.27                    2.53                   17.10
# 435           59.33                    3.30                   17.97
# 314           62.93                    2.83                   18.43
# 52            80.25                    4.24                   22.90
# ..              ...                     ...                     ...
# 400           61.75                    8.40                   33.75
# 436           58.79                    6.36                   31.45
# 70            63.95                    8.80                   34.13
# 279           61.97                    7.28                   29.66
# 218           97.39                    2.38                   20.82
#
#      Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 146                   33.82                   25.37                    0.60
# 142                   28.22                   20.11                    1.41
# 435                   24.10                   18.29                    2.19
# 314                   27.11                   17.84                    1.74
# 52                    31.89                   25.97                    1.97
# ..                      ...                     ...                     ...
# 400                   26.21                    2.31                    0.91
# 436                   22.00                    5.64                    0.48
# 70                    27.70                    2.56                    0.70
# 279                   28.12                    4.65                    0.82
# 218                   46.07                   31.23                    2.12
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 146                      79.26                       0.93
# 142                      64.27                       2.31
# 435                      59.33                       2.98
# 314                      62.93                       1.08
# 52                       80.25                       1.03
# ..                         ...                        ...
# 400                      61.75                       0.69
# 436                      58.79                       0.97
# 70                       63.95                       0.65
# 279                      61.97                       0.52
# 218                      97.39                       1.48
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 146                  0.57                     0.31           35.14
# 142                  1.33                     0.92           33.28
# 435                  1.49                     1.27           38.00
# 314                  0.45                     0.59           31.95
# 52                   0.56                     0.40           44.33
# ..                    ...                      ...             ...
# 400                  0.45                     0.20           34.01
# 436                  0.42                     0.55           32.24
# 70                   0.53                     0.12           37.34
# 279                  0.24                     0.28           33.01
# 218                  0.83                     0.63           53.87
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 146                 128.29                                69.15
# 142                 189.17                                98.88
# 435                 221.81                               106.92
# 314                 153.28                                87.98
# 52                  173.51                                85.27
# ..                     ...                                  ...
# 400                 184.55                                99.69
# 436                 147.21                                64.06
# 70                  197.05                               117.41
# 279                 170.86                                99.62
# 218                 224.69                               118.26
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 146                        1.30                1.27
# 142                        2.18                1.84
# 435                        2.19                1.81
# 314                        2.20                1.54
# 52                         1.51                1.64
# ..                          ...                 ...
# 400                        0.73                0.22
# 436                        0.79                0.36
# 70                         0.89                0.56
# 279                        0.78                0.66
# 218                        1.98                1.93
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 146                         0.06               -0.74                -0.26
# 142                         0.18               -1.97                -1.17
# 435                         0.41               -1.40                -0.67
# 314                         0.25               -1.29                -0.48
# 52                          0.29               -1.39                -0.40
# ..                           ...                 ...                  ...
# 400                         0.09               -0.60                -0.33
# 436                         0.06               -0.67                -0.48
# 70                          0.02               -0.49                -0.20
# 279                         0.04               -0.56                -0.26
# 218                         0.47               -1.09                -0.63
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 146                   44.33                                5.30
# 142                   37.01                                4.18
# 435                   33.33                                6.00
# 314                   37.63                                5.75
# 52                    53.80                                6.66
# ..                      ...                                 ...
# 400                   35.23                                0.40
# 436                   34.97                                0.61
# 70                    43.69                                0.17
# 279                   37.03                                0.68
# 218                   62.73                                6.02
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 146                        6.77                     0.30
# 142                        2.85                     0.29
# 435                        2.45                     0.29
# 314                        2.22                     0.32
# 52                         2.04                     0.25
# ..                          ...                      ...
# 400                        0.64                     0.07
# 436                        0.66                     0.00
# 70                         0.51                     0.06
# 279                        0.89                     0.08
# 218                        4.24                     0.49
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 146                   1.92                   1.54                  0.01
# 142                   1.73                   0.78                  0.15
# 435                   2.13                   0.06                  0.10
# 314                   1.88                   0.21                  0.04
# 52                    1.85                   0.00                  0.06
# ..                     ...                    ...                   ...
# 400                   0.56                   0.02                  0.00
# 436                   0.55                   0.00                  0.06
# 70                    0.40                   0.00                  0.01
# 279                   0.72                   0.12                  0.02
# 218                   2.66                   1.24                  0.12
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 146              0.03                     0.04                   1.92
# 142              0.15                     0.02                   1.73
# 435              0.06                     0.10                   0.00
# 314              0.03                     0.03                   1.88
# 52               0.04                     0.02                   1.85
# ..                ...                      ...                    ...
# 400              0.04                     0.00                   0.56
# 436              0.00                     0.06                   0.00
# 70               0.05                     0.01                   0.40
# 279              0.02                     0.00                   0.72
# 218              0.19                     0.02                   2.66
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 146                   0.20                   0.05                  0.00
# 142                   0.18                   0.07                  0.02
# 435                   0.19                   0.00                  0.00
# 314                   0.32                   0.00                  0.00
# 52                    0.23                   0.00                  0.02
# ..                     ...                    ...                   ...
# 400                   0.07                   0.00                  0.00
# 436                   0.00                   0.00                  0.00
# 70                    0.04                   0.00                  0.00
# 279                   0.06                   0.02                  0.00
# 218                   0.36                   0.08                  0.02
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 146              0.00                     0.00                    0.0
# 142              0.02                     0.00                    0.0
# 435              0.03                     0.06                    0.0
# 314              0.00                     0.00                    0.0
# 52               0.00                     0.00                    0.0
# ..                ...                      ...                    ...
# 400              0.00                     0.00                    0.0
# 436              0.00                     0.00                    0.0
# 70               0.02                     0.00                    0.0
# 279              0.00                     0.00                    0.0
# 218              0.03                     0.00                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 146            4197.0            5673.0               74.0         74466.0
# 142            2037.0            2888.0               71.0         35001.0
# 435            1163.0            1496.0               77.7         18327.0
# 314            1185.0            1535.0               77.0         18447.0
# 52             2826.0            3336.0               85.0         46768.0
# ..                ...               ...                ...             ...
# 400            1773.0            2225.0               80.0         34125.0
# 436             664.0             806.0               82.4         11229.0
# 70             3725.0            4399.0               85.0         69781.0
# 279            2131.0            2581.0               83.0         41658.0
# 218            6472.0            8684.0               75.0        122421.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 146         31633.0            2008.0            2253.0               89.0
# 142         13533.0            1022.0            1160.0               88.0
# 435          6651.0             602.0             687.0               87.6
# 314          6658.0             616.0             699.0               88.0
# 52          11315.0            1457.0            1594.0               91.0
# ..              ...               ...               ...                ...
# 400         11751.0             639.0             747.0               86.0
# 436          4521.0             313.0             339.0               92.3
# 70          25222.0            1403.0            1523.0               92.0
# 279         15402.0             805.0             880.0               91.0
# 218         47760.0            2905.0            3271.0               89.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 146             1501.0             1964.0                76.0
# 142              719.0              987.0                73.0
# 435              480.0              610.0                78.7
# 314              473.0              593.0                80.0
# 52              1072.0             1239.0                87.0
# ..                 ...                ...                 ...
# 400              930.0             1044.0                89.0
# 436              291.0              335.0                86.9
# 70              1920.0             2093.0                92.0
# 279              995.0             1132.0                88.0
# 218             2530.0             3238.0                78.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 146            561.0           1116.0              50.0             0.0
# 142            241.0            508.0              47.0             0.0
# 435             59.0            119.0              49.6             0.0
# 314             64.0            147.0              44.0             0.0
# 52             240.0            340.0              71.0             0.0
# ..               ...              ...               ...             ...
# 400            189.0            359.0              53.0             0.0
# 436             47.0             96.0              49.0             0.0
# 70             351.0            665.0              53.0             0.0
# 279            288.0            483.0              60.0             0.0
# 218            931.0           1823.0              51.0             0.0
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 146        0.21       0.21         -0.05               1.97
# 142        0.16       0.13          0.08               1.69
# 435        0.09       0.11         -0.05               0.89
# 314        0.14       0.13          0.03               1.08
# 52         0.11       0.12          0.04               1.17
# ..          ...        ...           ...                ...
# 400        0.01       0.03          0.01               0.13
# 436        0.01       0.01         -0.01               0.12
# 70         0.01       0.02         -0.00               0.15
# 279        0.02       0.02         -0.00               0.32
# 218        0.33       0.30         -0.04               2.43
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 146               4.17                        2.32
# 142               3.53                        1.26
# 435               1.87                        1.37
# 314               3.00                        0.84
# 52                2.92                        1.22
# ..                 ...                         ...
# 400               2.37                        0.15
# 436               2.12                        0.18
# 70                3.40                        0.15
# 279               3.00                        0.18
# 218               6.92                        2.74
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 146                         0.47                       6.56
# 142                         0.56                       4.22
# 435                         0.48                       3.17
# 314                         0.41                       3.48
# 52                          0.46                       3.76
# ..                           ...                        ...
# 400                         0.05                       3.24
# 436                         0.12                       1.94
# 70                          0.02                       3.30
# 279                         0.06                       2.82
# 218                         0.84                       7.69
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 146                    70.74                    55.43
# 142                    52.04                    42.49
# 435                    47.49                    38.35
# 314                    53.49                    44.98
# 52                     70.08                    60.97
# ..                       ...                      ...
# 400                    49.33                    46.78
# 436                    48.85                    42.24
# 70                     54.18                    53.09
# 279                    51.52                    44.93
# 218                    88.70                    72.66
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 146                    15.00                     2.81                  0.28
# 142                     9.26                     1.95                  0.18
# 435                     9.02                     0.67                  0.13
# 314                     8.16                     0.41                  0.11
# 52                      8.93                     0.93                  0.10
# ..                       ...                      ...                   ...
# 400                     2.39                     1.84                  0.00
# 436                     6.48                     1.70                  0.00
# 70                      0.94                     0.69                  0.00
# 279                     6.49                     1.76                  0.00
# 218                    15.78                     2.23                  0.50
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 146             0.40            6.97                    8.77
# 142             0.38            5.57                    5.15
# 435             0.03            2.67                    8.13
# 314             0.18            2.51                    7.63
# 52              0.59            2.52                    8.00
# ..               ...             ...                     ...
# 400             0.47            0.13                    0.53
# 436             0.18            0.48                    4.55
# 70              0.58            0.09                    0.25
# 279             1.50            0.40                    4.51
# 218             1.87            8.39                   10.12
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 146                 3.43                    1.19                     1.55
# 142                 2.16                    0.72                     1.21
# 435                 0.00                    0.00                     0.00
# 314                 0.11                    0.00                     0.07
# 52                  0.00                    0.00                     0.00
# ..                   ...                     ...                      ...
# 400                 0.00                    0.00                     0.00
# 436                 0.00                    0.00                     0.00
# 70                  0.00                    0.00                     0.00
# 279                 0.00                    0.00                     0.00
# 218                 3.42                    0.62                     2.29
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 146                     0.27              52.33               0.30
# 142                     0.00              36.70               0.29
# 435                     0.00              36.92               0.13
# 314                     0.00              41.29               0.35
# 52                      0.00              59.37               0.19
# ..                       ...                ...                ...
# 400                     0.00              39.32               0.16
# 436                     0.00              40.24               0.12
# 70                      0.00              45.87               0.15
# 279                     0.00              42.54               0.10
# 218                     0.03              66.11               0.27
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 146                   1.22               0.60                   0.18
# 142                   1.98               1.28                   0.31
# 435                   1.27               0.73                   0.22
# 314                   1.46               0.45                   0.07
# 52                    1.28               0.65                   0.09
# ..                     ...                ...                    ...
# 400                   0.73               0.38                   0.09
# 436                   0.85               0.18                   0.06
# 70                    0.47               0.42                   0.07
# 279                   0.46               0.52                   0.18
# 218                   1.26               1.49                   0.36
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 146            1.26                      4.10           0.42     1.7
# 142            1.51                      5.98           0.94     2.2
# 435            0.13                      0.43           0.13    -0.1
# 314            1.06                      6.74           1.02    -0.1
# 52             0.51                      3.33           0.85    -0.8
# ..              ...                       ...            ...     ...
# 400            1.24                      5.44           2.95    -1.0
# 436            0.33                      1.00           0.13     0.6
# 70             0.69                      3.32           2.61    -2.2
# 279            1.81                      6.06           1.99    -0.1
# 218            1.31                      5.44           1.61    -1.4
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 146       1.7                       62.0                -0.07
# 142       2.2                       58.0                -0.34
# 435      -0.1                       61.0                -0.13
# 314      -0.1                       50.0                -0.52
# 52       -0.8                       56.0                -0.29
# ..        ...                        ...                  ...
# 400      -1.0                       60.0                -0.18
# 436       0.6                       47.8                -0.30
# 70       -2.2                       62.0                -0.12
# 279      -0.1                       52.0                -0.26
# 218      -1.4                       47.0                -0.09
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 146             -0.00                      -0.00                   -1.18
# 142             -0.02                      -0.00                   -1.69
# 435             -0.06                      -0.03                   -0.67
# 314             -0.04                      -0.00                   -0.97
# 52              -0.02                      -0.02                   -1.22
# ..                ...                        ...                     ...
# 400             -0.02                      -0.00                   -0.97
# 436             -0.00                      -0.00                   -0.61
# 70              -0.00                      -0.00                   -0.68
# 279             -0.02                      -0.00                   -1.18
# 218             -0.00                      -0.00                   -0.56
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 146                0.66             0.21                  1.28
# 142                1.34             0.09                  0.97
# 435                1.46             0.16                  1.30
# 314                0.77             0.52                  1.01
# 52                 0.76             0.10                  1.01
# ..                  ...              ...                   ...
# 400                0.84             0.00                  1.84
# 436                0.18             0.00                  0.91
# 70                 0.33             0.00                  1.02
# 279                0.40             0.00                  1.12
# 218                0.22             0.21                  1.38
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 146                1.37                      0.00
# 142                1.57                      0.00
# 435                1.43                      0.06
# 314                0.66                      0.00
# 52                 1.39                      0.00
# ..                  ...                       ...
# 400                0.98                      0.00
# 436                0.97                      0.00
# 70                 0.74                      0.00
# 279                1.22                      0.00
# 218                0.98                      0.00
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 146                          -0.01                    6.17
# 142                          -0.02                    7.10
# 435                          -0.03                    5.90
# 314                          -0.00                    5.85
# 52                           -0.06                    5.63
# ..                             ...                     ...
# 400                          -0.02                    5.05
# 436                          -0.00                    5.27
# 70                           -0.02                    5.39
# 279                          -0.02                    4.99
# 218                          -0.01                    7.48
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Seasons at top 5  Seasons in PL  \
# 146                1.58                -0.96                 3              2
# 142                1.15                -0.85                 3              0
# 435                1.14                -0.73                 1              0
# 314                0.80                -0.80                 2              0
# 52                 0.80                -0.63                 3              0
# ..                  ...                  ...               ...            ...
# 400                3.17                -2.15                 2              0
# 436                0.67                -0.73                 1              0
# 70                 2.12                -1.30                 3              3
# 279                1.26                -1.15                 2              0
# 218                0.44                -0.50                 3              3
#
#      Seasons in Liga  Seasons in Serie A  Seasons in Ligue 1  \
# 146                2                   0                   0
# 142                0                   3                   0
# 435                0                   0                   1
# 314                2                   0                   0
# 52                 3                   0                   0
# ..               ...                 ...                 ...
# 400                0                   0                   0
# 436                1                   0                   0
# 70                 0                   0                   0
# 279                0                   2                   0
# 218                0                   0                   0
#
#      Seasons in Bundesliga  similarity_to_trent
# 146                      0             0.970146
# 142                      0             0.929364
# 435                      0             0.915859
# 314                      0             0.903856
# 52                       0             0.899845
# ..                     ...                  ...
# 400                      2            -0.875130
# 436                      0            -0.877835
# 70                       0            -0.878018
# 279                      0            -0.906759
# 218                      0                  NaN
#
# [554 rows x 125 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# Load the font
font_path = '../../Fonts/Ubuntu/Ubuntu-Medium.ttf'
font_prop = fm.FontProperties(fname=font_path, size=12)

# Use a dark background
plt.style.use('dark_background')

# Sort the defense_players DataFrame by similarity_to_trent in descending order
defense_players_sorted = defense_players.sort_values(by='similarity_to_trent', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart, but reverse the order of the data
bars = ax.barh(defense_players_sorted['Player'].head(15)[::-1], (defense_players_sorted['similarity_to_trent'].head(15)*100)[::-1],
               color=plt.cm.viridis(np.linspace(0, 1, 10)))

# Add labels and title
ax.set_xlabel('Similarity Percentage', fontproperties=font_prop)
ax.set_ylabel('Player', fontproperties=font_prop)
ax.set_title('Who is most similar to Trent from top 5 leagues based on the last 4 seasons ?', fontproperties=font_prop)

# Set the y-axis tick labels with the custom font
ax.set_yticklabels(defense_players_sorted['Player'].head(15)[::-1], fontproperties=font_prop)

# Remove gridlines
ax.grid(False)

# Make the top and right spines invisible
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make the left and bottom spines white
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')

# Change the color of ticks to white
ax.tick_params(colors='white')

# Change the color of labels to white
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')

# Add percentage labels to the bars
for bar in bars:
    width = bar.get_width()
    y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, y_pos, f'{width:.1f}%', ha='left', va='center',
            color='white', fontproperties=font_prop)


# Save the figure
plt.savefig('Similar.png' ,dpi=500,bbox_inches = 'tight',transparent=False)

plt.show()

# %%
Martinez=defense_players[defense_players['Player']=='Arnau Martinez']
Martinez
# Out:
#      Unnamed: 0          Player  Nation Pos   Squad        Comp   Age    Born  \
# 494        1402  Arnau Martinez  es ESP  DF  Girona  es La Liga  19.0  2003.0
#
#        MP  Starts   Min   90s  Goals_per90  G+A_per90  G-PK_per90  \
# 494  33.0    32.0  2732  30.4          0.1       0.23         0.1
#
#      G+A-PK_per90  xG_per90  xG+xAG_per90  npxG_per90  npxG+xAG_per90  \
# 494          0.23      0.06          0.21        0.06            0.21
#
#      Take_Ons_Attempted  Take_Ons_Succ  Take_Ons_Succ%  Tackled_Take_Ons  \
# 494                48.0           24.0            50.0              19.0
#
#      Tackled_Take_Ons%  Touches_per_90  Touches_Def_Pen_per_90  \
# 494               39.6           62.57                    3.22
#
#      Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  Touches_Att_3rd_per_90  \
# 494                   20.76                   28.32                   14.05
#
#      Touches_Att_Pen_per_90  Tocuhes_Live_Balls_per_90  \
# 494                    1.74                      62.57
#
#      Take_Ons_Attempted_per_90  Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  \
# 494                       1.58                  0.79                     0.62
#
#      Carries_per_90  Total_Distance_per_90  \
# 494           31.81                 172.43
#
#      Progressive_Distance_Carried_per_90  Progressive_Carries_per_90  \
# 494                                99.18                        2.11
#
#      1/3_Carries_per_90  Carries_Penalty_Area_per_90  Miscontrols_per_90  \
# 494                1.02                          0.3               -1.18
#
#      Dispossessed_per_90  Passes_Received_per_90  \
# 494                -0.56                   36.71
#
#      Progressive_Passes_Received_per_90  Shot_Creating_Action_per90  \
# 494                                3.22                        2.47
#
#      Goal_Creating_Action_90  Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  \
# 494                      0.3                   2.14                    0.0
#
#      Take_Ons_Shot_per_90  Shot-Shot_per_90  Fouls_drawn_Shot_per_90  \
# 494                  0.07               0.1                     0.16
#
#      Defensive_Shot_per_90  Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  \
# 494                    0.0                   0.23                    0.0
#
#      Take_Ons_Goal_per_90  Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  \
# 494                   0.0               0.0                     0.07
#
#      Defensive_Goal_per_90  Passes_Total_Cmp  Passes_Total_Att  \
# 494                    0.0            1303.0            1599.0
#
#      Passes_Total_Cmp%  Passes_TotDist  Passes_PrgDist  Passes_Short_Cmp  \
# 494               81.5         19900.0          7034.0             745.0
#
#      Passes_Short_Att  Passes_Short_Cmp%  Passes_Medium_Cmp  \
# 494             818.0               91.1              448.0
#
#      Passes_Medium_Att  Passes_Medium_Cmp%  Passes_Long_Cmp  Passes_Long_Att  \
# 494              533.0                84.1             82.0            161.0
#
#      Passes_Long_Cmp%  Assists_per_90  xAG_per_90  xA_per_90  A-xAG_per_90  \
# 494              50.9             0.0        0.14       0.11         -0.01
#
#      Key_Passes_per_90  Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 494               1.32               2.63                        0.92
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 494                         0.59                       3.72
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 494                     52.6                    41.78
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 494                    10.49                     1.58                   0.1
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 494             0.23            1.97                    8.91
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 494                  0.0                     0.0                      0.0
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 494                      0.0              42.86               0.33
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 494                   1.09               0.66                    0.1
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 494            0.15                       1.0            0.1     1.1
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 494       1.1                       56.1                -0.36
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 494              -0.0                       -0.0                   -1.18
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 494                2.17              0.2                  0.82
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 494                1.48                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 494                          -0.03                    5.62
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Seasons at top 5  Seasons in PL  \
# 494                1.05                -0.82                 1              0
#
#      Seasons in Liga  Seasons in Serie A  Seasons in Ligue 1  \
# 494                1                   0                   0
#
#      Seasons in Bundesliga  similarity_to_trent
# 494                      0             0.883774

# %%
# Calculate percentile ranks for players in the larger DataFrame
players_percentile_ranks = defense_players[params].rank(pct=True) * 100

# Get the row of Ndayishimiye's stats from the percentile ranks DataFrame
Martinez_percentile_ranks = round(players_percentile_ranks.iloc[[494]], 0)

# Print the percentile ranks for schlotterbeck
Martinez_percentile_ranks
# Out:
#      G+A-PK_per90  npxG+xAG_per90  Key_Passes_per_90  Goal_Creating_Action_90  \
# 494          94.0            93.0               94.0                     88.0
#
#      Shot_Creating_Action_per90  Shots_on_target_per90  Crosses_per_90  \
# 494                        84.0                   34.0            70.0
#
#      xA_per_90  Passes_Penalty_Area_per_90  Ball_Recoveries_per_90  \
# 494       87.0                        79.0                    54.0
#
#      Progressive_Passes_per_90  Progressive_Carries_per_90  \
# 494                       63.0                        79.0
#
#      Shot_Creating_Action_per90  Touches_Att_3rd_per_90  Through_Balls_per_90
# 494                        84.0                    71.0                  92.0

# %%
Martinez_percentile_ranks_list = Martinez_percentile_ranks.values.flatten().tolist()

Martinez_percentile_ranks_list
# Out:
# [94.0,
#  93.0,
#  94.0,
#  88.0,
#  84.0,
#  34.0,
#  70.0,
#  87.0,
#  79.0,
#  54.0,
#  63.0,
#  79.0,
#  84.0,
#  71.0,
#  92.0]

# %%
image_path = "Martinez.png"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    Martinez_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Arnau Martinez - Girona FC", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"La Liga Stats Percentile Rank vs Top-Five Leagues Defenders | Last Seasons",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Martinez_Percentile.png',dpi=500, bbox_inches='tight', facecolor=fig.get_facecolor(), edgecolor='none')  # save as png

# %%
Molina=defense_players[defense_players['Player']=='Nahuel Molina']
Molina
# Out:
#      Unnamed: 0         Player  Nation Pos                    Squad  \
# 106         296  Nahuel Molina  ar ARG  DF  Udinese+Atlético Madrid
#
#                       Comp   Age    Born    MP  Starts   Min   90s  \
# 106  it Serie A+es La Liga  25.0  1998.0  97.0    82.0  7333  81.5
#
#      Goals_per90  G+A_per90  G-PK_per90  G+A-PK_per90  xG_per90  xG+xAG_per90  \
# 106         0.16       0.27        0.16          0.27       0.1          0.22
#
#      npxG_per90  npxG+xAG_per90  Take_Ons_Attempted  Take_Ons_Succ  \
# 106         0.1            0.22               114.0           56.0
#
#      Take_Ons_Succ%  Tackled_Take_Ons  Tackled_Take_Ons%  Touches_per_90  \
# 106            49.0              52.0               46.0           60.59
#
#      Touches_Def_Pen_per_90  Touches_Def_3rd_per_90  Touches_Mid_3rd_per_90  \
# 106                    2.55                   16.99                   23.21
#
#      Touches_Att_3rd_per_90  Touches_Att_Pen_per_90  \
# 106                   20.85                    1.67
#
#      Tocuhes_Live_Balls_per_90  Take_Ons_Attempted_per_90  \
# 106                      60.59                        1.4
#
#      Take_Ons_Succ_per_90  Tackled_Take_Ons_per_90  Carries_per_90  \
# 106                  0.69                     0.64           30.11
#
#      Total_Distance_per_90  Progressive_Distance_Carried_per_90  \
# 106                 141.03                                83.94
#
#      Progressive_Carries_per_90  1/3_Carries_per_90  \
# 106                        2.06                1.32
#
#      Carries_Penalty_Area_per_90  Miscontrols_per_90  Dispossessed_per_90  \
# 106                         0.32               -1.19                -0.33
#
#      Passes_Received_per_90  Progressive_Passes_Received_per_90  \
# 106                   36.87                                6.98
#
#      Shot_Creating_Action_per90  Goal_Creating_Action_90  \
# 106                        2.86                     0.32
#
#      Pass_Live_Shot_per_90  Pass_Dead_Shot_per_90  Take_Ons_Shot_per_90  \
# 106                   2.37                   0.23                  0.11
#
#      Shot-Shot_per_90  Fouls_drawn_Shot_per_90  Defensive_Shot_per_90  \
# 106              0.08                     0.05                   2.37
#
#      Pass_Live_Goal_per_90  Pass_Dead_Goal_per_90  Take_Ons_Goal_per_90  \
# 106                   0.26                   0.01                  0.02
#
#      Shot_Goal_per_90  Fouls_Drawn_Goal_per_90  Defensive_Goal_per_90  \
# 106              0.01                     0.01                    0.0
#
#      Passes_Total_Cmp  Passes_Total_Att  Passes_Total_Cmp%  Passes_TotDist  \
# 106            3081.0            4167.0               74.0         46403.0
#
#      Passes_PrgDist  Passes_Short_Cmp  Passes_Short_Att  Passes_Short_Cmp%  \
# 106         18069.0            1786.0            2023.0               88.0
#
#      Passes_Medium_Cmp  Passes_Medium_Att  Passes_Medium_Cmp%  \
# 106              970.0             1359.0                71.0
#
#      Passes_Long_Cmp  Passes_Long_Att  Passes_Long_Cmp%  Assists_per_90  \
# 106            214.0            478.0              45.0             0.0
#
#      xAG_per_90  xA_per_90  A-xAG_per_90  Key_Passes_per_90  \
# 106        0.13       0.11         -0.02               1.21
#
#      Passes_1/3_per_90  Passes_Penalty_Area_per_90  \
# 106               2.39                        1.48
#
#      Crosses_Penalty_Area_per_90  Progressive_Passes_per_90  \
# 106                         0.69                       3.46
#
#      Passes_Attempted_per_90  Live_Ball_Passes_per_90  \
# 106                    51.13                    43.12
#
#      Dead_Ball_Passes_per_90  Free_Kick_Passes_per_90  Through_Balls_per_90  \
# 106                     7.89                     0.41                  0.13
#
#      Switches_per_90  Crosses_per_90  Throw_Ins_Taken_per_90  \
# 106             0.15            3.95                    7.19
#
#      Corner_Kicks_per_90  In_Corner_Kicks_per_90  Out_Corner_Kicks_per_90  \
# 106                 0.29                    0.12                     0.13
#
#      Str_Corner_Kicks_per_90  Passes_Cmp_per_90  Passes_Off_per_90  \
# 106                      0.0               37.8               0.12
#
#      Passes_Blocked_per_90  Shots_total_per90  Shots_on_target_per90  \
# 106                   1.52               0.99                   0.35
#
#      Goals_per_shot  Goals_per_shot_on_target  Npxg_per_shot  Xg_net  \
# 106            4.48                      12.7           2.64     5.2
#
#      Npxg_net  Percentage_of_Aerials_Won  Yellow_Cards_per_90  \
# 106       5.2                       40.0                -0.18
#
#      Red_Cards_per_90  Second_Yellow_Card_per_90  Fouls_Committed_per_90  \
# 106             -0.02                      -0.01                   -0.85
#
#      Fouls_Drawn_per_90  Offsides_per_90  Interceptions_per_90  \
# 106                0.53              0.1                  0.75
#
#      Tackles_Won_per_90  Penalty_Kicks_Won_per_90  \
# 106                1.04                       0.0
#
#      Penalty_Kicks_Conceded_per_90  Ball_Recoveries_per_90  \
# 106                          -0.02                    5.18
#
#      Aerials_Won_per_90  Aerials_Lost_per_90  Seasons at top 5  Seasons in PL  \
# 106                0.53                -0.78                 3              0
#
#      Seasons in Liga  Seasons in Serie A  Seasons in Ligue 1  \
# 106                1                   2                   0
#
#      Seasons in Bundesliga  similarity_to_trent
# 106                      0             0.880518

# %%
# Calculate percentile ranks for players in the larger DataFrame
players_percentile_ranks = defense_players[params].rank(pct=True) * 100

# Get the row of Ndayishimiye's stats from the percentile ranks DataFrame
Molina_percentile_ranks = round(players_percentile_ranks.iloc[[106]], 0)

# Print the percentile ranks for schlotterbeck
Molina_percentile_ranks
# Out:
#      G+A-PK_per90  npxG+xAG_per90  Key_Passes_per_90  Goal_Creating_Action_90  \
# 106          96.0            94.0               92.0                     91.0
#
#      Shot_Creating_Action_per90  Shots_on_target_per90  Crosses_per_90  \
# 106                        89.0                   88.0            91.0
#
#      xA_per_90  Passes_Penalty_Area_per_90  Ball_Recoveries_per_90  \
# 106       87.0                        96.0                    35.0
#
#      Progressive_Passes_per_90  Progressive_Carries_per_90  \
# 106                       55.0                        77.0
#
#      Shot_Creating_Action_per90  Touches_Att_3rd_per_90  Through_Balls_per_90
# 106                        89.0                    93.0                  96.0

# %%
Molina_percentile_ranks_list = Molina_percentile_ranks.values.flatten().tolist()

Molina_percentile_ranks_list
# Out:
# [96.0,
#  94.0,
#  92.0,
#  91.0,
#  89.0,
#  88.0,
#  91.0,
#  87.0,
#  96.0,
#  35.0,
#  55.0,
#  77.0,
#  89.0,
#  93.0,
#  96.0]

# %%
image_path = "Molina.jpg"
fdj_cropped = Image.open(image_path)

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza

slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 5 + ["#D70232"] * 5
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 5

baker = PyPizza(
params=split_params, # list of parameters
background_color="#EBEBE9", # background color
straight_line_color="#EBEBE9", # color for straight lines
straight_line_lw=1, # linewidth for straight lines
last_circle_lw=0, # linewidth of last circle
other_circle_lw=0, # linewidth for other circles
inner_circle_size=20 # size of inner circle
)

fig, ax = baker.make_pizza(
    Molina_percentile_ranks_list,  # list of values
    figsize=(8, 8.5),  # adjust figsize according to your need
    color_blank_space="same",  # use same color to fill blank space
    slice_colors=slice_colors,  # color for individual slices
    value_colors=text_colors,  # color for the value-text
    value_bck_colors=slice_colors,  # color for the blank spaces
    blank_alpha=0.4,  # alpha for blank-space colors
    param_location=115,  # move param labels further out
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),  # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        va="center"  # ha is removed here
    ),  # values to be used when adding parameters
    kwargs_values=dict(
        color="#000000", fontsize=11,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )  # values to be used when adding parameter-values
)


fig.text(
0.515, 0.975, "Nahuel Molina", size=16,
ha="center", color="#000000"
)


fig.text(
0.515, 0.953,
"Serie A & La Liga Stats Percentile Rank vs Top-Five Leagues Defenders | Last Seasons",
size=13,
ha="center", color="#000000"
)


CREDIT_1 = "@Hamdanov98 data: statsbomb viz fbref"
CREDIT_2 = "inspired by: @Worville, @FootballSlices, @somazerofc & @Soumyaj15209314"

fig.text(
0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
color="#000000",
ha="right"
)





ax_image = add_image(
fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
) # these values might differ when you are plotting

#plt.show()
plt.savefig('Molina_Percentile.png',dpi=500, bbox_inches='tight', facecolor=fig.get_facecolor(), edgecolor='none')  # save as png
